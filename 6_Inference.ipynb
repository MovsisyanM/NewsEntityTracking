# %% [markdown]
# # Inferring sentiment for the rest of the articles

# %%
import numpy as np
import pandas as pd
import re
import sqlite3
from digest_utils import strpdict
from itertools import chain
from collections import Counter
import requests
from tqdm import tqdm
import pickle
from pathlib import Path

np.random.seed(173)

# %%
# Connect to local db
db_armenpress = sqlite3.connect("Armenpress/scraping.db")
db_newsam = sqlite3.connect("Newsam/scraping.db")
db_tertam = sqlite3.connect("Tertam/scraping.db")

# loading data into dataframes
df_armenpress = pd.read_sql_query("select * from article", db_armenpress)
df_newsam = pd.read_sql_query("select * from article", db_newsam)
df_tertam = pd.read_sql_query("select * from article", db_tertam)

# parsing datetimes
df_tertam.time = pd.to_datetime(df_tertam.time)
df_newsam.time = pd.to_datetime(df_newsam.time)
df_armenpress.time = pd.to_datetime(df_armenpress.time)

# %%
# join all datasets
df = pd.concat([df[["time", "feedback", "content"]] for df in [df_armenpress, df_newsam, df_tertam]], axis=0)
df.feedback.str.replace("\n", "")
(df_feedback := df[~df.feedback.isna()].copy())
# Out:
#                      time                                           feedback  \
# 0     2009-06-08 00:00:00  {\n  "entities": [\n    {\n      "name": "Serz...
# 1     2009-06-08 00:00:00  {\n  "entities": [\n    {\n      "name": "Davi...
# 2     2009-06-04 00:00:00  {"entities": [\n  {"name": "World Bank", "sent...
# 3     2008-12-30 00:00:00  {\n  "entities": [\n    {"name": "CoE Congress...
# 4     2009-06-01 00:00:00  {\n  "entities": [\n    {\n      "name": "Matt...
# ...                   ...                                                ...
# 84103 2022-01-20 13:03:00  {\n  "entities": [\n    {\n      "name": "EBRD...
# 84114 2022-03-10 16:40:00  {\n  "entities": [\n    {\n      "name": "Dmyt...
# 84204 2022-11-17 13:23:00  {\n  "entities": [\n    {\n      "name": "Phil...
# 84216 2022-12-13 13:48:00  {\n  "entities": [\n    {\n      "name": "Aray...
# 84376 2023-11-23 15:16:00  {\n  "entities": [\n    {\n      "name": "Yers...
#
#                                                  content
# 0      YEREVAN, JUNE 9, ARMENPRESS:Armenian President...
# 1      YEREVAN, JUNE 9, ARMENPRESS:Director of the Co...
# 2      YEREVAN, JUNE 5, ARMENPRESS:The credit agreeme...
# 3      YEREVAN, JUNE 1, ARMENPRESS:The observing miss...
# 4      BAKU, JUNE 1, ARMENPRESS:OSCE Minsk group is o...
# ...                                                  ...
# 84103  The European Bank for Reconstruction and Devel...
# 84114  Ukrainian Foreign Minister Dmytro Kuleba says ...
# 84204  U.S. Secretary of State's adviser on Caucasus ...
# 84216  On December 13, President of the Artsakh Repub...
# 84376  At the beginning of November, Tert.am reported...
#
# [36827 rows x 3 columns]

# %%
# parse feedbacks
df_feedback.feedback = df_feedback.feedback.apply(strpdict)
# Out:
# unexpected indent (<unknown>, line 20)
# '{' was never closed (<unknown>, line 33)
# '{' was never closed (<unknown>, line 18)
# '{' was never closed (<unknown>, line 18)
# '[' was never closed (<unknown>, line 2)
# '{' was never closed (<unknown>, line 28)
# '{' was never closed (<unknown>, line 8)
# '{' was never closed (<unknown>, line 13)
# '{' was never closed (<unknown>, line 13)

# %%
# filter down to usable feedbacks
(df_feedback := df_feedback[
    ~df_feedback.feedback.isna() & (
        df_feedback.feedback.apply(
            lambda x: hasattr(x, "keys") and "entities" in x.keys()
            )
        )
    ]
)
# Out:
#                      time                                           feedback  \
# 0     2009-06-08 00:00:00  {'entities': [{'name': 'Serzh Sargsyan', 'sent...
# 1     2009-06-08 00:00:00  {'entities': [{'name': 'David Hakhverdyan', 's...
# 2     2009-06-04 00:00:00  {'entities': [{'name': 'World Bank', 'sentimen...
# 3     2008-12-30 00:00:00  {'entities': [{'name': 'CoE Congress of Local ...
# 4     2009-06-01 00:00:00  {'entities': [{'name': 'Matthew Bryza', 'senti...
# ...                   ...                                                ...
# 84103 2022-01-20 13:03:00  {'entities': [{'name': 'EBRD', 'sentiment': 'p...
# 84114 2022-03-10 16:40:00  {'entities': [{'name': 'Dmytro Kuleba', 'senti...
# 84204 2022-11-17 13:23:00  {'entities': [{'name': 'Philip Reeker', 'senti...
# 84216 2022-12-13 13:48:00  {'entities': [{'name': 'Arayik Harutyunyan', '...
# 84376 2023-11-23 15:16:00  {'entities': [{'name': 'Yershova', 'sentiment'...
#
#                                                  content
# 0      YEREVAN, JUNE 9, ARMENPRESS:Armenian President...
# 1      YEREVAN, JUNE 9, ARMENPRESS:Director of the Co...
# 2      YEREVAN, JUNE 5, ARMENPRESS:The credit agreeme...
# 3      YEREVAN, JUNE 1, ARMENPRESS:The observing miss...
# 4      BAKU, JUNE 1, ARMENPRESS:OSCE Minsk group is o...
# ...                                                  ...
# 84103  The European Bank for Reconstruction and Devel...
# 84114  Ukrainian Foreign Minister Dmytro Kuleba says ...
# 84204  U.S. Secretary of State's adviser on Caucasus ...
# 84216  On December 13, President of the Artsakh Repub...
# 84376  At the beginning of November, Tert.am reported...
#
# [36610 rows x 3 columns]

# %%
# words to count for bag of words
words_to_count = Counter()
ent_name = df_feedback.feedback.iloc[0]["entities"][0]["name"]
feedback = df_feedback.feedback.iloc[0]["entities"][0]["explanation"]
article_sentences = list(chain.from_iterable(
    [partition.split(".") for partition in df_feedback.content.iloc[0].split(":")]
))
article_sentences = [s.replace(",", "").lower() for s in article_sentences]
relevant_sentances = [feedback] + [
    sent
    for sent
    in article_sentences
    if ent_name.lower() in sent
]

relevant_words = list(
    chain.from_iterable(
        [re.findall(r"\w+", sent) for sent in relevant_sentances]
    )
)

# Split the sentances that mentio the entity into words
words_to_count += Counter(relevant_words)
words_to_count
# Out:
# Counter({'the': 10,
#          'of': 4,
#          'as': 3,
#          'received': 2,
#          'armenian': 2,
#          'president': 2,
#          'serzh': 2,
#          'sargsyan': 2,
#          'director': 2,
#          'france': 2,
#          'telecom': 2,
#          'orange': 2,
#          'company': 2,
#          'that': 2,
#          'in': 2,
#          'mentioned': 1,
#          'Armenian': 1,
#          'President': 1,
#          'who': 1,
#          'executives': 1,
#          'today': 1,
#          'olaf': 1,
#          'swantee': 1,
#          'executive': 1,
#          'vice': 1,
#          'and': 1,
#          'bruno': 1,
#          'dutua': 1,
#          'chief': 1,
#          'armenia': 1,
#          'we': 1,
#          'are': 1,
#          'interested': 1,
#          'one': 1,
#          'world': 1,
#          's': 1,
#          'leading': 1,
#          'operators': 1,
#          'telecommunication': 1,
#          'sphere': 1,
#          'starts': 1,
#          'its': 1,
#          'activity': 1,
#          'our': 1,
#          'state': 1,
#          'soon': 1,
#          'possible': 1,
#          'pointed': 1,
#          'out': 1,
#          'noting': 1,
#          'government': 1,
#          'is': 1,
#          'ready': 1,
#          'to': 1,
#          'assist': 1,
#          'solution': 1,
#          'issues': 1,
#          'which': 1,
#          'will': 1,
#          'arouse': 1,
#          'during': 1,
#          'works': 1})

# %% [markdown]
# Ignoring stopwords

# %%
(english_stopwords := requests.get(
    "https://gist.githubusercontent.com"
    "/sebleier/554280/raw/7e0e4a1ce04c2bb7bd41089"
    "c9821dbcf6d0c786c/NLTK's%2520list%2520of%252"
    "0english%2520stopwords"
).content.decode().split("\n"))[40:50]
# Out:
# ['was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do']

# %%
{
    k.lower(): v
    for k, v in words_to_count.items()
    if (
        k.lower() not in english_stopwords
    ) and (
        k.lower() not in ent_name.lower()
    )
}
# Out:
# {'mentioned': 1,
#  'armenian': 2,
#  'president': 2,
#  'received': 2,
#  'executives': 1,
#  'today': 1,
#  'olaf': 1,
#  'swantee': 1,
#  'executive': 1,
#  'vice': 1,
#  'director': 2,
#  'france': 2,
#  'telecom': 2,
#  'orange': 2,
#  'company': 2,
#  'bruno': 1,
#  'dutua': 1,
#  'chief': 1,
#  'armenia': 1,
#  'interested': 1,
#  'one': 1,
#  'world': 1,
#  'leading': 1,
#  'operators': 1,
#  'telecommunication': 1,
#  'sphere': 1,
#  'starts': 1,
#  'activity': 1,
#  'state': 1,
#  'soon': 1,
#  'possible': 1,
#  'pointed': 1,
#  'noting': 1,
#  'government': 1,
#  'ready': 1,
#  'assist': 1,
#  'solution': 1,
#  'issues': 1,
#  'arouse': 1,
#  'works': 1}

# %% [markdown]
# Wrapping it all in a function

# %%
words_to_count = {
    "positive": Counter(),
    "negative": Counter(),
    "neutral": Counter(),
}

ent_datas = df_feedback.feedback.iloc[0]["entities"]
def extract_word_counts(obs: dict, content: str):
    """To be applied (not the built-in way) on a pandas series of
    dictionaries containing entity data. Counts the words around
    the mentioned entity and while keeping track of the sentiment

    Args:
        obs (dict): observation that has the key `entities` which
        is a list of dicts that have the keys `name`, `sentiment`,
        and `explanation`.
        content (str): the text of the article.
    """
    if "entities" not in obs:
        print("Obs. missing key entities")

    for ent_data in obs["entities"]:
        if (type(ent_data) is not dict) or any(
            [k not in ent_data for k in ["name", "sentiment"]]
        ) or (
            ent_data["sentiment"].lower() not in ["positive", "negative", "neutral"]
        ):
            continue
        

        ent_name = ent_data["name"].lower()
        feedback = ent_data["explanation"].lower() if "explanation" in ent_data else ""
        sentiment = ent_data["sentiment"].lower()

        # splitting articles into sentences
        article_sentences = list(chain.from_iterable(
            [partition.split(".") for partition in content.split(":")]
        ))
        article_sentences = [s.replace(",", "").lower() for s in article_sentences]
        
        # selecting relevant sentences
        relevant_sentances = [feedback] + [
            sent
            for sent
            in article_sentences
            if ent_name in sent
        ]

        # Splitting into words
        relevant_words = list(
            chain.from_iterable(
                [re.findall(r"\w+", sent) for sent in relevant_sentances]
            )
        )

        # filtering stopwords and entity names
        relevant_words = [
            w for w in relevant_words
            if (w not in english_stopwords) and (
                w not in ent_name
            )
        ]

        # Split the sentances that mentio the entity into words
        words_to_count[sentiment] += Counter(relevant_words)

# %%
for i, obs in tqdm(df_feedback.iterrows()):
    extract_word_counts(obs["feedback"], obs["content"])
# Out:
# 36610it [08:07, 75.09it/s]

# %%
with open(Path("cache") / "words_count.Counter.pkl", "wb") as f:
    pickle.dump(words_to_count, f)

# %%
with open(Path("cache") / "words_count.Counter.pkl", "rb") as f:
    word_sentiments = pickle.load(f)

# %%
words = set(
    list(word_sentiments["positive"].keys()) + 
    list(word_sentiments["negative"].keys()) + 
    list(word_sentiments["neutral"].keys())
)

term_sentiment = {}

for word in words:
    term_sentiment[word] = {
        sent: word_sentiments[sent][word] if word in word_sentiments[sent] else 0
        for sent in ["positive", "negative", "neutral"]
    }

term_sentiment
# Out:
# {'lcoc1': {'positive': 5, 'negative': 2, 'neutral': 5},
#  'title': {'positive': 209, 'negative': 31, 'neutral': 164},
#  'stepnoi': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'fenton': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'medieval': {'positive': 32, 'negative': 21, 'neutral': 23},
#  'hasbun': {'positive': 2, 'negative': 2, 'neutral': 0},
#  'esai': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'stinks': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'zinichev': {'positive': 15, 'negative': 2, 'neutral': 8},
#  'mulling': {'positive': 1, 'negative': 7, 'neutral': 9},
#  'historysuren': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'expeditiously': {'positive': 8, 'negative': 1, 'neutral': 12},
#  'guangcheng': {'positive': 0, 'negative': 3, 'neutral': 0},
#  'enactor': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'mcgown': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'borussiadortmund': {'positive': 2, 'negative': 0, 'neutral': 0},
#  '1500': {'positive': 34, 'negative': 28, 'neutral': 65},
#  'pottermania': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'artaskh': {'positive': 1, 'negative': 1, 'neutral': 3},
#  'attended': {'positive': 604, 'negative': 75, 'neutral': 837},
#  'politican': {'positive': 2, 'negative': 0, 'neutral': 2},
#  'futurism': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'copycatting': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'pambak': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'bakkie': {'positive': 8, 'negative': 0, 'neutral': 2},
#  'malyutin': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'yohann': {'positive': 0, 'negative': 0, 'neutral': 6},
#  'outlandish': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'secretly': {'positive': 6, 'negative': 27, 'neutral': 48},
#  'allieswould': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'definite': {'positive': 4, 'negative': 9, 'neutral': 16},
#  'perseveres': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'apostolakis': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'val': {'positive': 2, 'negative': 0, 'neutral': 5},
#  'scuttles': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'reprising': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'coxsackievirus': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'deal': {'positive': 885, 'negative': 1220, 'neutral': 3173},
#  'lifeblood': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'plundering': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'nakopia': {'positive': 0, 'negative': 0, 'neutral': 6},
#  'khourshoudyan': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'averaged': {'positive': 0, 'negative': 2, 'neutral': 9},
#  'subjecting': {'positive': 3, 'negative': 17, 'neutral': 7},
#  'yongpyong': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'hoarse': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'former': {'positive': 1155, 'negative': 1588, 'neutral': 3040},
#  'antiship': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'torrential': {'positive': 0, 'negative': 5, 'neutral': 0},
#  'thenorthrop': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'davtian': {'positive': 8, 'negative': 0, 'neutral': 1},
#  'ledtothat': {'positive': 0, 'negative': 3, 'neutral': 1},
#  'markaryan': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'izmail': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'termination': {'positive': 12, 'negative': 69, 'neutral': 50},
#  'lobov': {'positive': 3, 'negative': 0, 'neutral': 2},
#  'neighbouring': {'positive': 8, 'negative': 35, 'neutral': 37},
#  'deadliest': {'positive': 2, 'negative': 33, 'neutral': 22},
#  'chon': {'positive': 0, 'negative': 0, 'neutral': 1},
#  '19252': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'defused': {'positive': 9, 'negative': 5, 'neutral': 14},
#  'cooperative': {'positive': 111, 'negative': 10, 'neutral': 53},
#  'rosia': {'positive': 5, 'negative': 0, 'neutral': 9},
#  'dorenko': {'positive': 0, 'negative': 1, 'neutral': 4},
#  'khramichikhin': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'reinvent': {'positive': 0, 'negative': 2, 'neutral': 2},
#  'sergeikopyrkin': {'positive': 0, 'negative': 0, 'neutral': 6},
#  'hydraulic': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'newsrussia': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'atrophied': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'talkative': {'positive': 0, 'negative': 3, 'neutral': 13},
#  'anzali': {'positive': 2, 'negative': 0, 'neutral': 3},
#  'dying': {'positive': 15, 'negative': 28, 'neutral': 14},
#  'quilts': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'perceptible': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'pirlo': {'positive': 4, 'negative': 0, 'neutral': 1},
#  'vladi': {'positive': 0, 'negative': 2, 'neutral': 3},
#  'purposely': {'positive': 2, 'negative': 1, 'neutral': 0},
#  'jrakn': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'uae': {'positive': 114, 'negative': 69, 'neutral': 208},
#  'kimono': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'adelfia': {'positive': 0, 'negative': 0, 'neutral': 6},
#  'ivashevka': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'indifferent': {'positive': 15, 'negative': 16, 'neutral': 47},
#  'statesjoined': {'positive': 0, 'negative': 0, 'neutral': 7},
#  'fingers': {'positive': 2, 'negative': 0, 'neutral': 3},
#  'tomcats': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'medveded': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'celog': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'iwd': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'complexity': {'positive': 2, 'negative': 20, 'neutral': 46},
#  'sandri': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'pretended': {'positive': 0, 'negative': 12, 'neutral': 7},
#  'motta': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'lousavorich': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'dw': {'positive': 21, 'negative': 66, 'neutral': 97},
#  'rusisian': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'grace': {'positive': 242, 'negative': 18, 'neutral': 51},
#  'confectionary': {'positive': 1, 'negative': 2, 'neutral': 1},
#  'penza': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'sayed': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'afterwords': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'hindering': {'positive': 9, 'negative': 58, 'neutral': 23},
#  'siege': {'positive': 9, 'negative': 75, 'neutral': 35},
#  'huseynli': {'positive': 0, 'negative': 4, 'neutral': 5},
#  'ashuluk': {'positive': 3, 'negative': 0, 'neutral': 5},
#  'kutoyan': {'positive': 1, 'negative': 0, 'neutral': 10},
#  'vladivastok': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'gazexport': {'positive': 0, 'negative': 0, 'neutral': 1},
#  '487': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'silenced': {'positive': 3, 'negative': 9, 'neutral': 2},
#  'lesiak': {'positive': 1, 'negative': 1, 'neutral': 2},
#  'blackmailing': {'positive': 1, 'negative': 24, 'neutral': 14},
#  'vodolatsky': {'positive': 5, 'negative': 7, 'neutral': 4},
#  'naroyan': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'ompromise': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'gorgisyan': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'igniting': {'positive': 1, 'negative': 4, 'neutral': 4},
#  'treaties': {'positive': 38, 'negative': 42, 'neutral': 100},
#  'unfinished': {'positive': 1, 'negative': 6, 'neutral': 9},
#  'proficient': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'sakvarelidze': {'positive': 1, 'negative': 1, 'neutral': 2},
#  'quesiton': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'fadi': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'everywhere': {'positive': 26, 'negative': 22, 'neutral': 18},
#  'mher': {'positive': 119, 'negative': 21, 'neutral': 284},
#  'berkshire': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'licence': {'positive': 0, 'negative': 2, 'neutral': 7},
#  'tashci': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'stitch': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'snubbed': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'kiraz': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'andonian': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'vahe': {'positive': 61, 'negative': 14, 'neutral': 81},
#  'inflammatory': {'positive': 4, 'negative': 9, 'neutral': 27},
#  'doosti': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'lenaslittle': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'raisa': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'stallone': {'positive': 3, 'negative': 0, 'neutral': 3},
#  'kazamias': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'low': {'positive': 120, 'negative': 206, 'neutral': 312},
#  'jury': {'positive': 43, 'negative': 31, 'neutral': 29},
#  'eugenia': {'positive': 0, 'negative': 4, 'neutral': 1},
#  'chita': {'positive': 2, 'negative': 6, 'neutral': 15},
#  '86': {'positive': 17, 'negative': 15, 'neutral': 30},
#  'rightful': {'positive': 13, 'negative': 30, 'neutral': 22},
#  'coachella': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'eradicating': {'positive': 4, 'negative': 8, 'neutral': 3},
#  'zoos': {'positive': 2, 'negative': 0, 'neutral': 8},
#  'davet': {'positive': 3, 'negative': 5, 'neutral': 3},
#  'finch': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'lkaygündoğan': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'rocholl': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'mhp': {'positive': 1, 'negative': 6, 'neutral': 8},
#  'opportunitieselisabeth': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'danilov': {'positive': 3, 'negative': 9, 'neutral': 13},
#  'purged': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'cucumbers': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'schnier': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'refu': {'positive': 1, 'negative': 0, 'neutral': 0},
#  '272': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'responsibili': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'hoshyar': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'steepest': {'positive': 0, 'negative': 4, 'neutral': 1},
#  'hadja': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'grievance': {'positive': 2, 'negative': 5, 'neutral': 2},
#  'sherman': {'positive': 259, 'negative': 112, 'neutral': 155},
#  'milestone': {'positive': 111, 'negative': 8, 'neutral': 23},
#  'unthinkable': {'positive': 1, 'negative': 6, 'neutral': 14},
#  'url': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'erna': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'anderson': {'positive': 0, 'negative': 1, 'neutral': 8},
#  'bodies': {'positive': 166, 'negative': 195, 'neutral': 408},
#  'abcnews': {'positive': 0, 'negative': 4, 'neutral': 4},
#  'greenland': {'positive': 2, 'negative': 9, 'neutral': 42},
#  'quadruple': {'positive': 0, 'negative': 1, 'neutral': 6},
#  'sbeloved': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'stepanaket': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'liquor': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'vaccinations': {'positive': 7, 'negative': 6, 'neutral': 17},
#  'reactws': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'chegoggin': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'russianfederation': {'positive': 1, 'negative': 2, 'neutral': 2},
#  'scope': {'positive': 118, 'negative': 40, 'neutral': 167},
#  'novoa': {'positive': 5, 'negative': 0, 'neutral': 0},
#  'judges': {'positive': 25, 'negative': 23, 'neutral': 52},
#  'azeraijani': {'positive': 0, 'negative': 0, 'neutral': 7},
#  'stubbornlyentrenched': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'ofmilitants': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'ss': {'positive': 2, 'negative': 2, 'neutral': 2},
#  'proceeding': {'positive': 22, 'negative': 35, 'neutral': 87},
#  '55am': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'anra': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'trending': {'positive': 1, 'negative': 1, 'neutral': 2},
#  'narcotic': {'positive': 1, 'negative': 6, 'neutral': 10},
#  '396': {'positive': 1, 'negative': 4, 'neutral': 1},
#  'franciszek': {'positive': 0, 'negative': 0, 'neutral': 5},
#  'merzliakov': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'trade': {'positive': 2824, 'negative': 1055, 'neutral': 2953},
#  'cargos': {'positive': 0, 'negative': 3, 'neutral': 6},
#  'rafting': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'esmeralda': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'molot': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'ashkharh': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'bucharest': {'positive': 10, 'negative': 11, 'neutral': 39},
#  'lemkin': {'positive': 38, 'negative': 29, 'neutral': 13},
#  'super': {'positive': 35, 'negative': 31, 'neutral': 62},
#  'ossetins': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'alrosa': {'positive': 12, 'negative': 0, 'neutral': 7},
#  'supplier': {'positive': 57, 'negative': 56, 'neutral': 163},
#  'babchenko': {'positive': 1, 'negative': 0, 'neutral': 5},
#  'jesus': {'positive': 10, 'negative': 4, 'neutral': 21},
#  'lantus': {'positive': 3, 'negative': 0, 'neutral': 2},
#  'osorio': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'cyber': {'positive': 38, 'negative': 210, 'neutral': 156},
#  'blossomed': {'positive': 6, 'negative': 0, 'neutral': 5},
#  'subentity': {'positive': 0, 'negative': 3, 'neutral': 8},
#  'hristov': {'positive': 4, 'negative': 0, 'neutral': 2},
#  'programmes': {'positive': 6, 'negative': 18, 'neutral': 24},
#  'topass': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'novel': {'positive': 290, 'negative': 186, 'neutral': 273},
#  'kurtov': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'yılmaz': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'sherbakov': {'positive': 6, 'negative': 0, 'neutral': 1},
#  'putney': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'juts': {'positive': 0, 'negative': 3, 'neutral': 2},
#  'abdicate': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'vis': {'positive': 9, 'negative': 28, 'neutral': 51},
#  'headmasters': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'owned': {'positive': 67, 'negative': 220, 'neutral': 302},
#  'azeris': {'positive': 25, 'negative': 41, 'neutral': 77},
#  'harkens': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'petruchenko': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'korelskiy': {'positive': 3, 'negative': 0, 'neutral': 2},
#  'tegenu': {'positive': 0, 'negative': 0, 'neutral': 6},
#  'nanotechnology': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'handsomely': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'flip': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'remembers': {'positive': 16, 'negative': 16, 'neutral': 11},
#  'diesel': {'positive': 8, 'negative': 35, 'neutral': 59},
#  'emergence': {'positive': 10, 'negative': 21, 'neutral': 33},
#  'sanahin': {'positive': 15, 'negative': 0, 'neutral': 2},
#  'mediate': {'positive': 28, 'negative': 22, 'neutral': 116},
#  'yudin': {'positive': 0, 'negative': 3, 'neutral': 0},
#  'kenyans': {'positive': 1, 'negative': 0, 'neutral': 3},
#  'maiquetía': {'positive': 0, 'negative': 1, 'neutral': 2},
#  '60000km': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'yalpin': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'srecent': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'frequently': {'positive': 20, 'negative': 37, 'neutral': 64},
#  '1599': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'thenortheastern': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'mizar': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'pioneering': {'positive': 26, 'negative': 0, 'neutral': 8},
#  'polymers': {'positive': 1, 'negative': 2, 'neutral': 4},
#  'norad': {'positive': 5, 'negative': 2, 'neutral': 6},
#  'bosov': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'lamoda': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'autonomies': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'elham': {'positive': 0, 'negative': 3, 'neutral': 1},
#  'sunan': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'stoltenbergtouched': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'zirve': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'lazarus': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'liqueurs': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'havana': {'positive': 47, 'negative': 6, 'neutral': 67},
#  'bribed': {'positive': 0, 'negative': 5, 'neutral': 0},
#  'afterhenri': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'papal': {'positive': 5, 'negative': 0, 'neutral': 7},
#  'yoshihide': {'positive': 0, 'negative': 4, 'neutral': 4},
#  'concil': {'positive': 0, 'negative': 0, 'neutral': 5},
#  'stipulate': {'positive': 1, 'negative': 2, 'neutral': 9},
#  'benotman': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'climatic': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'billed': {'positive': 2, 'negative': 2, 'neutral': 12},
#  'colleyville': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'allegiance': {'positive': 9, 'negative': 25, 'neutral': 17},
#  'petikyan': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'contradiction': {'positive': 9, 'negative': 20, 'neutral': 12},
#  'legere': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'circumstance': {'positive': 13, 'negative': 7, 'neutral': 50},
#  'lozansky': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'repots': {'positive': 3, 'negative': 0, 'neutral': 3},
#  'ratcheted': {'positive': 0, 'negative': 12, 'neutral': 9},
#  'monopoly': {'positive': 29, 'negative': 49, 'neutral': 93},
#  'conspirator': {'positive': 0, 'negative': 3, 'neutral': 0},
#  'clarifying': {'positive': 14, 'negative': 13, 'neutral': 71},
#  'ken': {'positive': 23, 'negative': 26, 'neutral': 14},
#  'hakkari': {'positive': 0, 'negative': 3, 'neutral': 2},
#  'decries': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'dodgy': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'sugiyama': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'haqq': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'absorbing': {'positive': 2, 'negative': 0, 'neutral': 2},
#  'nupen': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'ententeof': {'positive': 1, 'negative': 0, 'neutral': 3},
#  'chhange': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'haleu': {'positive': 0, 'negative': 0, 'neutral': 4},
#  '4530': {'positive': 0, 'negative': 3, 'neutral': 2},
#  'dzhabrail': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'langdonseries': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'romer': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'antinyan': {'positive': 1, 'negative': 2, 'neutral': 1},
#  'capitalization': {'positive': 2, 'negative': 3, 'neutral': 3},
#  'markosyan': {'positive': 0, 'negative': 2, 'neutral': 14},
#  'stéphane': {'positive': 89, 'negative': 7, 'neutral': 278},
#  'cher': {'positive': 9, 'negative': 4, 'neutral': 8},
#  'roberta': {'positive': 6, 'negative': 3, 'neutral': 5},
#  'beautifully': {'positive': 2, 'negative': 1, 'neutral': 1},
#  'alexandroupolis': {'positive': 2, 'negative': 0, 'neutral': 5},
#  'usdtea': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'saxophone': {'positive': 0, 'negative': 0, 'neutral': 9},
#  'bottles': {'positive': 0, 'negative': 13, 'neutral': 16},
#  'dwon': {'positive': 1, 'negative': 3, 'neutral': 0},
#  'secretaryof': {'positive': 6, 'negative': 1, 'neutral': 10},
#  'averaging': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'simferopol': {'positive': 3, 'negative': 20, 'neutral': 33},
#  '5921': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'version': {'positive': 96, 'negative': 92, 'neutral': 178},
#  'plagued': {'positive': 3, 'negative': 9, 'neutral': 2},
#  'suns': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'applicant': {'positive': 3, 'negative': 1, 'neutral': 8},
#  'azadi': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'zhuravlevka': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'multiwavelength': {'positive': 7, 'negative': 0, 'neutral': 5},
#  'about1': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'accept': {'positive': 147, 'negative': 227, 'neutral': 402},
#  'dramatise': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'oaklawn': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'integrative': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'kochetkov': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'ngt747': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'languagetravel': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'toher': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'steaua': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'oce': {'positive': 0, 'negative': 2, 'neutral': 3},
#  'tallest': {'positive': 1, 'negative': 2, 'neutral': 2},
#  'dzopelaro': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'roulette': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'br': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'citingsportskeeda': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'vachik': {'positive': 0, 'negative': 1, 'neutral': 8},
#  'unmask': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'astride': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'wand': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'poisk': {'positive': 0, 'negative': 0, 'neutral': 12},
#  'serdar': {'positive': 7, 'negative': 5, 'neutral': 28},
#  'neurosurgery': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'stewardship': {'positive': 9, 'negative': 1, 'neutral': 8},
#  'ignorant': {'positive': 0, 'negative': 8, 'neutral': 1},
#  'sargssan': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'jubilees': {'positive': 11, 'negative': 0, 'neutral': 0},
#  'hesitant': {'positive': 1, 'negative': 4, 'neutral': 21},
#  'enlighten': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'intensification': {'positive': 48, 'negative': 35, 'neutral': 60},
#  'hardline': {'positive': 4, 'negative': 22, 'neutral': 25},
#  'tutelage': {'positive': 1, 'negative': 1, 'neutral': 1},
#  'indescently': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'lapsha': {'positive': 0, 'negative': 2, 'neutral': 2},
#  'outlooks': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'overdrive': {'positive': 2, 'negative': 1, 'neutral': 0},
#  'dios': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'obamatold': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'drize': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'sirunyan': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'heald': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'biomimetics': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'kamchatsky': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'uofsc': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'çağdaş': {'positive': 0, 'negative': 5, 'neutral': 3},
#  'exposé': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'azeripress': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'bvb': {'positive': 33, 'negative': 5, 'neutral': 38},
#  'dependence': {'positive': 88, 'negative': 146, 'neutral': 181},
#  'reliance': {'positive': 27, 'negative': 34, 'neutral': 52},
#  'shortsightedness': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'confessors': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'kubnews': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'mourchidates': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'acult': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'come': {'positive': 477, 'negative': 496, 'neutral': 1184},
#  'plowing': {'positive': 0, 'negative': 3, 'neutral': 0},
#  '8a': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'elevations': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'unopposed': {'positive': 5, 'negative': 1, 'neutral': 0},
#  'obfuscated': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'lumber': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'minuscule': {'positive': 0, 'negative': 1, 'neutral': 5},
#  'alike': {'positive': 31, 'negative': 19, 'neutral': 29},
#  '52m': {'positive': 4, 'negative': 0, 'neutral': 3},
#  'supposes': {'positive': 6, 'negative': 3, 'neutral': 22},
#  '51km': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'nazi': {'positive': 31, 'negative': 69, 'neutral': 69},
#  'excellent': {'positive': 91, 'negative': 10, 'neutral': 28},
#  'osmanism': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'quota': {'positive': 4, 'negative': 0, 'neutral': 10},
#  'txznjt9l26': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'grigorian': {'positive': 25, 'negative': 0, 'neutral': 8},
#  'outbreaks': {'positive': 6, 'negative': 13, 'neutral': 29},
#  'spektr': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'accumulating': {'positive': 1, 'negative': 6, 'neutral': 6},
#  'vingapurovsky': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'with289': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'xinuha': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'productivity': {'positive': 10, 'negative': 6, 'neutral': 2},
#  'commercialize': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'nikolo': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'pastthree': {'positive': 0, 'negative': 1, 'neutral': 4},
#  'intents': {'positive': 0, 'negative': 3, 'neutral': 4},
#  'sensationalist': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'laitinen': {'positive': 4, 'negative': 4, 'neutral': 7},
#  'catering': {'positive': 4, 'negative': 0, 'neutral': 7},
#  'pavol': {'positive': 0, 'negative': 3, 'neutral': 0},
#  'wantonly': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'victorious': {'positive': 17, 'negative': 9, 'neutral': 11},
#  'influenza': {'positive': 3, 'negative': 3, 'neutral': 4},
#  'fuentes': {'positive': 3, 'negative': 2, 'neutral': 2},
#  'nds': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'gerasim': {'positive': 3, 'negative': 0, 'neutral': 2},
#  'safiran': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'returningvietnam': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'paradigms': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'yirdaw': {'positive': 0, 'negative': 0, 'neutral': 1},
#  '194095': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'ravanchi': {'positive': 1, 'negative': 2, 'neutral': 15},
#  'espinoza': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'pimping': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'shrines': {'positive': 3, 'negative': 0, 'neutral': 2},
#  'reentry': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'adopting': {'positive': 61, 'negative': 42, 'neutral': 89},
#  'oppressor': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'starkest': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'azerbijan': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'apologise': {'positive': 0, 'negative': 3, 'neutral': 4},
#  '75b': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'nationalization': {'positive': 1, 'negative': 3, 'neutral': 5},
#  'screened': {'positive': 19, 'negative': 0, 'neutral': 20},
#  'pontifcal': {'positive': 4, 'negative': 0, 'neutral': 12},
#  'euvsdisinfo': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'ofmusicalcultureon': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'disgraceful': {'positive': 2, 'negative': 19, 'neutral': 7},
#  'pinchas': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'efj': {'positive': 0, 'negative': 1, 'neutral': 8},
#  'mug': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'spasski': {'positive': 5, 'negative': 0, 'neutral': 0},
#  'nongovernmental': {'positive': 9, 'negative': 7, 'neutral': 8},
#  'paet': {'positive': 13, 'negative': 0, 'neutral': 11},
#  'subbotu': {'positive': 2, 'negative': 0, 'neutral': 9},
#  '106500': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'manifest': {'positive': 6, 'negative': 9, 'neutral': 12},
#  'memorable': {'positive': 17, 'negative': 0, 'neutral': 3},
#  'estimate': {'positive': 17, 'negative': 17, 'neutral': 33},
#  'kogelo': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'vella': {'positive': 5, 'negative': 0, 'neutral': 0},
#  'overestimated': {'positive': 0, 'negative': 2, 'neutral': 4},
#  'institutefor': {'positive': 1, 'negative': 3, 'neutral': 1},
#  'konstantinovka': {'positive': 0, 'negative': 1, 'neutral': 5},
#  'islandaryan': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'sezgin': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'rosbank': {'positive': 0, 'negative': 7, 'neutral': 1},
#  'giri': {'positive': 51, 'negative': 1, 'neutral': 26},
#  'equalised': {'positive': 2, 'negative': 1, 'neutral': 1},
#  '801': {'positive': 0, 'negative': 4, 'neutral': 0},
#  'andryan': {'positive': 5, 'negative': 0, 'neutral': 11},
#  'marginalised': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'knife': {'positive': 0, 'negative': 12, 'neutral': 14},
#  'mkhitarashen': {'positive': 1, 'negative': 5, 'neutral': 0},
#  'auspice': {'positive': 4, 'negative': 0, 'neutral': 4},
#  'funnyman': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'federationimplements': {'positive': 0, 'negative': 0, 'neutral': 2},
#  '1612': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'azrertac': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'oblast': {'positive': 46, 'negative': 69, 'neutral': 152},
#  'indignity': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'starit': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'hatted': {'positive': 3, 'negative': 0, 'neutral': 0},
#  'outlet': {'positive': 12, 'negative': 45, 'neutral': 186},
#  'characters': {'positive': 9, 'negative': 6, 'neutral': 22},
#  'competeafter': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'pic': {'positive': 3, 'negative': 6, 'neutral': 8},
#  'lightsaber': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'halla': {'positive': 4, 'negative': 0, 'neutral': 2},
#  'strivings': {'positive': 1, 'negative': 1, 'neutral': 1},
#  'газета': {'positive': 2, 'negative': 0, 'neutral': 5},
#  'lobbing': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'potentate': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'curricular': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'pakdasht': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'greenpeace': {'positive': 14, 'negative': 7, 'neutral': 19},
#  'lacerating': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'confidentiality': {'positive': 1, 'negative': 1, 'neutral': 11},
#  'ineefective': {'positive': 2, 'negative': 1, 'neutral': 0},
#  'multilayer': {'positive': 6, 'negative': 0, 'neutral': 0},
#  'counterbalance': {'positive': 9, 'negative': 16, 'neutral': 22},
#  'azteca': {'positive': 4, 'negative': 0, 'neutral': 0},
#  'ofopenness': {'positive': 1, 'negative': 1, 'neutral': 1},
#  'multipolar': {'positive': 12, 'negative': 2, 'neutral': 8},
#  'rejuvenate': {'positive': 3, 'negative': 1, 'neutral': 2},
#  'tskhinvali': {'positive': 1, 'negative': 31, 'neutral': 6},
#  'landslide': {'positive': 11, 'negative': 18, 'neutral': 27},
#  'sleaders': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'observer': {'positive': 82, 'negative': 29, 'neutral': 150},
#  'nordsjælland': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'urals': {'positive': 6, 'negative': 18, 'neutral': 22},
#  'brezhneva': {'positive': 8, 'negative': 0, 'neutral': 0},
#  'aghasandyan': {'positive': 4, 'negative': 0, 'neutral': 4},
#  'jasina': {'positive': 0, 'negative': 0, 'neutral': 5},
#  'groundbreaking': {'positive': 44, 'negative': 6, 'neutral': 8},
#  'cards': {'positive': 43, 'negative': 39, 'neutral': 58},
#  'insecurity': {'positive': 5, 'negative': 25, 'neutral': 6},
#  'manhole': {'positive': 0, 'negative': 4, 'neutral': 4},
#  'semerikovtemporarily': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'humoral': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'tourism': {'positive': 867, 'negative': 103, 'neutral': 276},
#  'navies': {'positive': 3, 'negative': 3, 'neutral': 12},
#  'boca': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'mvp': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'restaurants': {'positive': 21, 'negative': 10, 'neutral': 21},
#  'abkhazians': {'positive': 2, 'negative': 4, 'neutral': 6},
#  'evseev': {'positive': 7, 'negative': 2, 'neutral': 12},
#  'deferential': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'freizer': {'positive': 5, 'negative': 3, 'neutral': 11},
#  '3s': {'positive': 1, 'negative': 0, 'neutral': 0},
#  '29986': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'occupational': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'lotte': {'positive': 2, 'negative': 1, 'neutral': 7},
#  'bulldog': {'positive': 1, 'negative': 0, 'neutral': 4},
#  '192': {'positive': 0, 'negative': 4, 'neutral': 8},
#  'greaneyrecently': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'gorbatyuk': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'kent': {'positive': 48, 'negative': 9, 'neutral': 18},
#  'levandowski': {'positive': 10, 'negative': 0, 'neutral': 2},
#  'cataloged': {'positive': 1, 'negative': 1, 'neutral': 1},
#  'broekers': {'positive': 2, 'negative': 0, 'neutral': 3},
#  'borderand': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'briz': {'positive': 4, 'negative': 0, 'neutral': 3},
#  'pieces': {'positive': 30, 'negative': 14, 'neutral': 56},
#  'maksim': {'positive': 48, 'negative': 6, 'neutral': 53},
#  'charite': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'notching': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'notaries': {'positive': 2, 'negative': 0, 'neutral': 2},
#  'ceremonial': {'positive': 10, 'negative': 3, 'neutral': 14},
#  'urbanize': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'received': {'positive': 2314, 'negative': 492, 'neutral': 2789},
#  '308': {'positive': 1, 'negative': 1, 'neutral': 1},
#  'ukhtadzor': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'inundated': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'tchaikovsky': {'positive': 17, 'negative': 1, 'neutral': 2},
#  'agroexpress': {'positive': 3, 'negative': 0, 'neutral': 0},
#  'baca': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'dalli': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'fairness': {'positive': 4, 'negative': 6, 'neutral': 12},
#  'imbedded': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'kazimirov': {'positive': 17, 'negative': 28, 'neutral': 77},
#  '8641': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'mapped': {'positive': 0, 'negative': 4, 'neutral': 5},
#  'sarmada': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'games': {'positive': 200, 'negative': 134, 'neutral': 324},
#  'suspicious': {'positive': 7, 'negative': 30, 'neutral': 20},
#  'tertzakian': {'positive': 5, 'negative': 0, 'neutral': 0},
#  'rambler': {'positive': 2, 'negative': 0, 'neutral': 2},
#  'fm': {'positive': 796, 'negative': 396, 'neutral': 1740},
#  'iwould': {'positive': 4, 'negative': 0, 'neutral': 2},
#  'unrolling': {'positive': 3, 'negative': 0, 'neutral': 4},
#  'slanderous': {'positive': 0, 'negative': 3, 'neutral': 1},
#  'stymied': {'positive': 2, 'negative': 2, 'neutral': 1},
#  'mayorca': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'shipton': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'astafyev': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'lutsenko': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'silicon': {'positive': 41, 'negative': 4, 'neutral': 21},
#  'bandit': {'positive': 0, 'negative': 9, 'neutral': 0},
#  'akunk': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'vagahrshapat': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'fdr': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'views': {'positive': 360, 'negative': 291, 'neutral': 1033},
#  'authorizing': {'positive': 5, 'negative': 19, 'neutral': 31},
#  'vilified': {'positive': 0, 'negative': 3, 'neutral': 1},
#  '34th': {'positive': 8, 'negative': 0, 'neutral': 7},
#  'porta': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'infra': {'positive': 1, 'negative': 0, 'neutral': 3},
#  '165929': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'willingness': {'positive': 816, 'negative': 122, 'neutral': 534},
#  'avan': {'positive': 0, 'negative': 2, 'neutral': 4},
#  '714000': {'positive': 0, 'negative': 0, 'neutral': 6},
#  'brest': {'positive': 3, 'negative': 2, 'neutral': 28},
#  'halajyan': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'yerkir': {'positive': 15, 'negative': 4, 'neutral': 22},
#  'peoplehavemetthe': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'withpatriotic': {'positive': 2, 'negative': 0, 'neutral': 2},
#  'ww2': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'airbridge': {'positive': 0, 'negative': 3, 'neutral': 2},
#  'wih': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'authenticated': {'positive': 1, 'negative': 1, 'neutral': 0},
#  '182': {'positive': 4, 'negative': 5, 'neutral': 3},
#  'marquez': {'positive': 5, 'negative': 2, 'neutral': 4},
#  'andamnesty': {'positive': 1, 'negative': 0, 'neutral': 3},
#  'barbadian': {'positive': 0, 'negative': 0, 'neutral': 6},
#  'baselessly': {'positive': 0, 'negative': 4, 'neutral': 1},
#  'applying': {'positive': 46, 'negative': 68, 'neutral': 108},
#  '50251': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'mukanov': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'revive': {'positive': 48, 'negative': 18, 'neutral': 80},
#  'zakatala': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'bay': {'positive': 24, 'negative': 14, 'neutral': 45},
#  'merzlyakov': {'positive': 19, 'negative': 1, 'neutral': 86},
#  'soyak': {'positive': 0, 'negative': 2, 'neutral': 5},
#  'insect': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'lukin': {'positive': 14, 'negative': 6, 'neutral': 18},
#  'reps': {'positive': 12, 'negative': 3, 'neutral': 5},
#  'aghamaly': {'positive': 0, 'negative': 2, 'neutral': 0},
#  '0730': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'minaev': {'positive': 0, 'negative': 0, 'neutral': 6},
#  'ibm': {'positive': 14, 'negative': 1, 'neutral': 5},
#  'zangazur': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'baronov': {'positive': 0, 'negative': 0, 'neutral': 7},
#  'nominee': {'positive': 56, 'negative': 60, 'neutral': 157},
#  'extraordinaryand': {'positive': 12, 'negative': 0, 'neutral': 2},
#  'kerobyan': {'positive': 76, 'negative': 4, 'neutral': 54},
#  'despite': {'positive': 607, 'negative': 845, 'neutral': 1163},
#  'instantaneous': {'positive': 0, 'negative': 1, 'neutral': 0},
#  '1531224': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'prolific': {'positive': 21, 'negative': 2, 'neutral': 8},
#  'advisor': {'positive': 284, 'negative': 110, 'neutral': 585},
#  'speier': {'positive': 430, 'negative': 32, 'neutral': 65},
#  'balzac': {'positive': 1, 'negative': 0, 'neutral': 4},
#  'keoshgerian': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'ngaorno': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'rafales': {'positive': 1, 'negative': 3, 'neutral': 1},
#  'amrenia': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'pronichev': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'lindseygrahamsc': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'matisse': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'suryakin': {'positive': 0, 'negative': 0, 'neutral': 8},
#  'rubinrecalled': {'positive': 1, 'negative': 0, 'neutral': 4},
#  'muammar': {'positive': 5, 'negative': 25, 'neutral': 44},
#  'fringes': {'positive': 1, 'negative': 2, 'neutral': 11},
#  'gianni': {'positive': 1, 'negative': 4, 'neutral': 4},
#  'robben': {'positive': 3, 'negative': 0, 'neutral': 1},
#  'thepermanent': {'positive': 0, 'negative': 2, 'neutral': 4},
#  'invading': {'positive': 5, 'negative': 49, 'neutral': 23},
#  'badger': {'positive': 0, 'negative': 0, 'neutral': 1},
#  '4744961': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'controversies': {'positive': 5, 'negative': 13, 'neutral': 26},
#  'tsaarukyan': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'hear': {'positive': 67, 'negative': 57, 'neutral': 104},
#  'fortuitous': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'borrowed': {'positive': 2, 'negative': 4, 'neutral': 6},
#  'committeeinformed': {'positive': 0, 'negative': 0, 'neutral': 6},
#  'olaf': {'positive': 11, 'negative': 18, 'neutral': 60},
#  'delete': {'positive': 1, 'negative': 5, 'neutral': 4},
#  'males': {'positive': 1, 'negative': 1, 'neutral': 1},
#  'pacifism': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'legitimately': {'positive': 0, 'negative': 2, 'neutral': 6},
#  'implicates': {'positive': 1, 'negative': 9, 'neutral': 3},
#  'issg': {'positive': 0, 'negative': 0, 'neutral': 10},
#  'painless': {'positive': 0, 'negative': 1, 'neutral': 4},
#  'atomstroyexpo': {'positive': 0, 'negative': 0, 'neutral': 2},
#  '4985': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'farchy': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'levitin': {'positive': 54, 'negative': 2, 'neutral': 51},
#  'assemblies': {'positive': 19, 'negative': 3, 'neutral': 19},
#  'jagellonia': {'positive': 3, 'negative': 0, 'neutral': 2},
#  '171253': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'diabolical': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'concurred': {'positive': 24, 'negative': 4, 'neutral': 6},
#  'ofsanctions': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'yizhou': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'kilisali': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'ucu': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'medellin': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'territoryand': {'positive': 0, 'negative': 3, 'neutral': 0},
#  'xp': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'gorin': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'ehn': {'positive': 0, 'negative': 0, 'neutral': 8},
#  'ghaem': {'positive': 0, 'negative': 0, 'neutral': 4},
#  '47th': {'positive': 10, 'negative': 2, 'neutral': 6},
#  'wechat': {'positive': 0, 'negative': 8, 'neutral': 0},
#  'peaked': {'positive': 0, 'negative': 2, 'neutral': 4},
#  'u23s': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'dilyana': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'parseghian': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'russianofficials': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'wasbankrolled': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'shonin': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'recognizes': {'positive': 135, 'negative': 81, 'neutral': 189},
#  'auxiliary': {'positive': 3, 'negative': 6, 'neutral': 7},
#  'lecture': {'positive': 47, 'negative': 19, 'neutral': 46},
#  'inwhich': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'advancements': {'positive': 41, 'negative': 6, 'neutral': 9},
#  'provided': {'positive': 845, 'negative': 283, 'neutral': 2389},
#  'tadf': {'positive': 0, 'negative': 3, 'neutral': 2},
#  'jumbo': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'asmap': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'batwin': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'rom': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'rebar': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'krivopuskovthe': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'warsaw': {'positive': 66, 'negative': 36, 'neutral': 103},
#  'kebusie': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'inslee': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'coverred': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'politics': {'positive': 97, 'negative': 142, 'neutral': 271},
#  'angelini': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'saperstien': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'aboutarmenia': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'thesweeping': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'mardakerd': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'obviously': {'positive': 37, 'negative': 89, 'neutral': 119},
#  'ursula': {'positive': 15, 'negative': 31, 'neutral': 35},
#  'hunkered': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'copies': {'positive': 65, 'negative': 9, 'neutral': 38},
#  'тogether': {'positive': 2, 'negative': 1, 'neutral': 0},
#  'balls': {'positive': 3, 'negative': 0, 'neutral': 4},
#  'alizade': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'safian': {'positive': 12, 'negative': 0, 'neutral': 0},
#  '5848': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'overtone': {'positive': 0, 'negative': 3, 'neutral': 0},
#  'raising': {'positive': 270, 'negative': 209, 'neutral': 216},
#  'precedential': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'suzan': {'positive': 56, 'negative': 0, 'neutral': 0},
#  'presecnce': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'indefinite': {'positive': 10, 'negative': 14, 'neutral': 32},
#  'yeganian': {'positive': 5, 'negative': 0, 'neutral': 5},
#  'margarita': {'positive': 4, 'negative': 12, 'neutral': 41},
#  'unrecognized': {'positive': 44, 'negative': 24, 'neutral': 54},
#  'chernikov': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'hett': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'sausage': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'logically': {'positive': 6, 'negative': 21, 'neutral': 21},
#  'anarmenian': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'suing': {'positive': 2, 'negative': 18, 'neutral': 6},
#  'ofhelping': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'us': {'positive': 7649, 'negative': 7821, 'neutral': 15573},
#  'fizzed': {'positive': 0, 'negative': 3, 'neutral': 0},
#  'smoothening': {'positive': 0, 'negative': 0, 'neutral': 1},
#  '27927': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'ofunionveterans': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'cows': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'subjugate': {'positive': 1, 'negative': 6, 'neutral': 1},
#  'bloodbath': {'positive': 0, 'negative': 4, 'neutral': 3},
#  'einulla': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'inpace': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'carve': {'positive': 1, 'negative': 6, 'neutral': 9},
#  'spiteful': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'chewing': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'fff': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'udumyan': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'tamas': {'positive': 3, 'negative': 0, 'neutral': 1},
#  '200s': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'idiots': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'neutralization': {'positive': 3, 'negative': 0, 'neutral': 11},
#  'leopard': {'positive': 12, 'negative': 1, 'neutral': 28},
#  'pohgosyan': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'boosters': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'mri': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'cube': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'passions': {'positive': 3, 'negative': 8, 'neutral': 9},
#  'areclearly': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'carlito': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'avia': {'positive': 8, 'negative': 2, 'neutral': 5},
#  '59th': {'positive': 1, 'negative': 0, 'neutral': 7},
#  'boggle': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'intended': {'positive': 99, 'negative': 122, 'neutral': 301},
#  'rebounds': {'positive': 3, 'negative': 0, 'neutral': 0},
#  'yixin': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'paso': {'positive': 0, 'negative': 4, 'neutral': 5},
#  'musings': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'melo': {'positive': 2, 'negative': 1, 'neutral': 9},
#  'forfor': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'formulated': {'positive': 6, 'negative': 1, 'neutral': 8},
#  'subjection': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'contaminate': {'positive': 0, 'negative': 1, 'neutral': 0},
#  '47095': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'repairs': {'positive': 2, 'negative': 10, 'neutral': 19},
#  'lessons': {'positive': 80, 'negative': 24, 'neutral': 58},
#  'taurida': {'positive': 4, 'negative': 0, 'neutral': 0},
#  'advancement': {'positive': 177, 'negative': 27, 'neutral': 48},
#  'predators': {'positive': 0, 'negative': 4, 'neutral': 4},
#  'loved': {'positive': 36, 'negative': 18, 'neutral': 20},
#  'tifa': {'positive': 47, 'negative': 0, 'neutral': 28},
#  'leagues': {'positive': 2, 'negative': 0, 'neutral': 4},
#  'parting': {'positive': 1, 'negative': 4, 'neutral': 4},
#  'itera': {'positive': 6, 'negative': 6, 'neutral': 8},
#  'valiollah': {'positive': 0, 'negative': 4, 'neutral': 0},
#  'bismarckian': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'pyjamasin': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'astanization': {'positive': 0, 'negative': 0, 'neutral': 7},
#  'beauchamp': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'rasa': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'prometey': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'vaccinated': {'positive': 40, 'negative': 5, 'neutral': 29},
#  'engels': {'positive': 0, 'negative': 3, 'neutral': 4},
#  'carobus': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'pbs': {'positive': 4, 'negative': 4, 'neutral': 9},
#  'dispatches': {'positive': 1, 'negative': 2, 'neutral': 1},
#  'hadmade': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'voiced': {'positive': 152, 'negative': 275, 'neutral': 318},
#  '50': {'positive': 234, 'negative': 221, 'neutral': 330},
#  '1992': {'positive': 168, 'negative': 71, 'neutral': 239},
#  'assumptions': {'positive': 2, 'negative': 19, 'neutral': 14},
#  'misanthropic': {'positive': 0, 'negative': 3, 'neutral': 1},
#  'veniamin': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'raze': {'positive': 0, 'negative': 3, 'neutral': 0},
#  'berliner': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'ozder': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'sprayed': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'bogged': {'positive': 0, 'negative': 1, 'neutral': 7},
#  'alina': {'positive': 3, 'negative': 3, 'neutral': 7},
#  'likhachev': {'positive': 14, 'negative': 6, 'neutral': 6},
#  'parasite': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'borrussia': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'polit': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'luiz': {'positive': 1, 'negative': 2, 'neutral': 4},
#  'sperm': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'arlacchi': {'positive': 0, 'negative': 2, 'neutral': 0},
#  '73m': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'haber': {'positive': 2, 'negative': 14, 'neutral': 25},
#  'marry': {'positive': 7, 'negative': 0, 'neutral': 6},
#  'chausovsky': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'alimov': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'bulgargaz': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'aparan': {'positive': 0, 'negative': 2, 'neutral': 4},
#  'trustee': {'positive': 7, 'negative': 1, 'neutral': 3},
#  'snaffled': {'positive': 2, 'negative': 1, 'neutral': 0},
#  'belligerence': {'positive': 0, 'negative': 22, 'neutral': 4},
#  'signatoriesof': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'shepard': {'positive': 6, 'negative': 0, 'neutral': 0},
#  'mahfouz': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'boxers': {'positive': 13, 'negative': 1, 'neutral': 14},
#  'monster': {'positive': 0, 'negative': 7, 'neutral': 2},
#  'chakhalyan': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'inaccurate': {'positive': 7, 'negative': 18, 'neutral': 14},
#  'keeney': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'boggs': {'positive': 0, 'negative': 4, 'neutral': 3},
#  'turkish': {'positive': 1873, 'negative': 3953, 'neutral': 6790},
#  'rusagrotranstold': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'ofsettling': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'constructive': {'positive': 583, 'negative': 173, 'neutral': 500},
#  'mobilized': {'positive': 12, 'negative': 15, 'neutral': 15},
#  '2800th': {'positive': 8, 'negative': 0, 'neutral': 4},
#  'dubrovina': {'positive': 5, 'negative': 0, 'neutral': 0},
#  'conversational': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'societal': {'positive': 7, 'negative': 5, 'neutral': 6},
#  'seats': {'positive': 21, 'negative': 28, 'neutral': 92},
#  'gadamis': {'positive': 0, 'negative': 3, 'neutral': 0},
#  'directorandbest': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'avakimyan': {'positive': 6, 'negative': 0, 'neutral': 0},
#  'conjuncturalinterests': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'farkhad': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'wires': {'positive': 0, 'negative': 10, 'neutral': 3},
#  'sensitivenuclear': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'kyureghyan': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'inducing': {'positive': 1, 'negative': 2, 'neutral': 2},
#  'zada': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'block': {'positive': 89, 'negative': 218, 'neutral': 241},
#  'caliber': {'positive': 10, 'negative': 33, 'neutral': 50},
#  'tycoon': {'positive': 23, 'negative': 37, 'neutral': 63},
#  'incentivizing': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'wrangled': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'maligning': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'empowers': {'positive': 4, 'negative': 5, 'neutral': 3},
#  'romanovsky': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'agenocide': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'discredits': {'positive': 0, 'negative': 5, 'neutral': 0},
#  'wind': {'positive': 7, 'negative': 19, 'neutral': 28},
#  'perceivable': {'positive': 9, 'negative': 2, 'neutral': 9},
#  'gavrilo': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'tumanyan': {'positive': 3, 'negative': 0, 'neutral': 7},
#  'sighted': {'positive': 1, 'negative': 6, 'neutral': 3},
#  'rabenn': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'compensating': {'positive': 7, 'negative': 6, 'neutral': 8},
#  'knowhow': {'positive': 5, 'negative': 0, 'neutral': 1},
#  'habervesaire': {'positive': 0, 'negative': 2, 'neutral': 2},
#  'kherdian': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'ios': {'positive': 1, 'negative': 1, 'neutral': 6},
#  '1572775': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'tuxedo': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'alimony': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'tide': {'positive': 4, 'negative': 12, 'neutral': 16},
#  'flurry': {'positive': 2, 'negative': 9, 'neutral': 16},
#  'raised': {'positive': 292, 'negative': 464, 'neutral': 550},
#  'parachutist': {'positive': 1, 'negative': 0, 'neutral': 3},
#  'wafers': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'organised': {'positive': 2, 'negative': 3, 'neutral': 19},
#  'çavuşoğluannounced': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'tanzila': {'positive': 3, 'negative': 0, 'neutral': 4},
#  'hayots': {'positive': 9, 'negative': 10, 'neutral': 41},
#  'ushba': {'positive': 0, 'negative': 0, 'neutral': 15},
#  '68000': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'llilit': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'intourist': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'tipster': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'alqa': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'koren': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'cheetahs': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'evn': {'positive': 12, 'negative': 1, 'neutral': 3},
#  'quo': {'positive': 31, 'negative': 84, 'neutral': 209},
#  'boloton': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'shirimyan': {'positive': 1, 'negative': 4, 'neutral': 2},
#  'vanounts': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'ransom': {'positive': 3, 'negative': 12, 'neutral': 8},
#  'adilkhanyan': {'positive': 1, 'negative': 0, 'neutral': 0},
#  '2503': {'positive': 2, 'negative': 0, 'neutral': 5},
#  'sideswiped': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'qadri': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'prides': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'recalled': {'positive': 154, 'negative': 187, 'neutral': 380},
#  'sobre': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'robbie': {'positive': 5, 'negative': 0, 'neutral': 3},
#  'accomplices': {'positive': 1, 'negative': 38, 'neutral': 15},
#  'demounted': {'positive': 1, 'negative': 1, 'neutral': 1},
#  'pattie': {'positive': 3, 'negative': 0, 'neutral': 10},
#  'commonspace': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'kramer': {'positive': 2, 'negative': 10, 'neutral': 5},
#  '145': {'positive': 7, 'negative': 14, 'neutral': 15},
#  'intricate': {'positive': 11, 'negative': 7, 'neutral': 10},
#  'leyva': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'hudak': {'positive': 4, 'negative': 0, 'neutral': 4},
#  'theyerevan': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'airdromes': {'positive': 0, 'negative': 1, 'neutral': 4},
#  'soil': {'positive': 32, 'negative': 56, 'neutral': 68},
#  'intelsat': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'gloucester': {'positive': 1, 'negative': 3, 'neutral': 2},
#  'ramin': {'positive': 0, 'negative': 9, 'neutral': 8},
#  'siirt': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'akhalkalaki': {'positive': 0, 'negative': 0, 'neutral': 7},
#  'salyukov': {'positive': 1, 'negative': 1, 'neutral': 1},
#  'authenticity': {'positive': 8, 'negative': 7, 'neutral': 12},
#  'innocuous': {'positive': 2, 'negative': 2, 'neutral': 2},
#  'alaraby': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'draught': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'karekin': {'positive': 116, 'negative': 5, 'neutral': 98},
#  'gideon': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'professing': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'lof': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'acquaintances': {'positive': 2, 'negative': 2, 'neutral': 6},
#  'donating': {'positive': 22, 'negative': 1, 'neutral': 12},
#  'schoolgirl': {'positive': 1, 'negative': 1, 'neutral': 3},
#  'mehtiev': {'positive': 1, 'negative': 0, 'neutral': 2},
#  '500': {'positive': 104, 'negative': 91, 'neutral': 186},
#  'crumbling': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'disillusionment': {'positive': 1, 'negative': 7, 'neutral': 3},
#  'khadija': {'positive': 18, 'negative': 20, 'neutral': 3},
#  'ves': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'giti': {'positive': 5, 'negative': 0, 'neutral': 0},
#  'shahumyan': {'positive': 10, 'negative': 35, 'neutral': 34},
#  'deaths': {'positive': 62, 'negative': 778, 'neutral': 280},
#  'marmaris': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'godzimirski': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'ofneed': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'dimitrios': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'kb': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'moldavia': {'positive': 0, 'negative': 0, 'neutral': 7},
#  'oulu': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'stint': {'positive': 7, 'negative': 0, 'neutral': 2},
#  'kicker': {'positive': 6, 'negative': 0, 'neutral': 2},
#  'onseptember': {'positive': 0, 'negative': 0, 'neutral': 5},
#  'mol': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'indissoluble': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'fanta': {'positive': 0, 'negative': 0, 'neutral': 11},
#  'fueling': {'positive': 4, 'negative': 37, 'neutral': 25},
#  'tall': {'positive': 7, 'negative': 3, 'neutral': 3},
#  'mingde': {'positive': 0, 'negative': 1, 'neutral': 1},
#  '65km': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'gundelik': {'positive': 0, 'negative': 3, 'neutral': 0},
#  'güneyligil': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'contexte': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'tenuous': {'positive': 3, 'negative': 12, 'neutral': 5},
#  'isaccea': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'toasts': {'positive': 3, 'negative': 0, 'neutral': 0},
#  '338349': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'mocking': {'positive': 3, 'negative': 8, 'neutral': 2},
#  'schuppe': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'heineken': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'amr': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'beatrice': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'sdhp': {'positive': 6, 'negative': 0, 'neutral': 1},
#  'glone': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'outmost': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'canceled': {'positive': 19, 'negative': 103, 'neutral': 172},
#  'naomi': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'musoyan': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'abdala': {'positive': 7, 'negative': 1, 'neutral': 0},
#  'jwi': {'positive': 0, 'negative': 2, 'neutral': 0},
#  '4124': {'positive': 2, 'negative': 0, 'neutral': 4},
#  '91204': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'ozal': {'positive': 0, 'negative': 1, 'neutral': 12},
#  'launching': {'positive': 164, 'negative': 164, 'neutral': 252},
#  'anew': {'positive': 5, 'negative': 2, 'neutral': 8},
#  'hksar': {'positive': 0, 'negative': 8, 'neutral': 0},
#  'prudent': {'positive': 11, 'negative': 6, 'neutral': 15},
#  'discourse': {'positive': 38, 'negative': 15, 'neutral': 46},
#  'dhahran': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'rearing': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'pastorals': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'tessler': {'positive': 1, 'negative': 1, 'neutral': 2},
#  'cmb': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'uncitral': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'leaker': {'positive': 4, 'negative': 8, 'neutral': 18},
#  ...}

# %%
df_feedback
# Out:
#                      time                                           feedback  \
# 0     2009-06-08 00:00:00  {'entities': [{'name': 'Serzh Sargsyan', 'sent...
# 1     2009-06-08 00:00:00  {'entities': [{'name': 'David Hakhverdyan', 's...
# 2     2009-06-04 00:00:00  {'entities': [{'name': 'World Bank', 'sentimen...
# 3     2008-12-30 00:00:00  {'entities': [{'name': 'CoE Congress of Local ...
# 4     2009-06-01 00:00:00  {'entities': [{'name': 'Matthew Bryza', 'senti...
# ...                   ...                                                ...
# 84103 2022-01-20 13:03:00  {'entities': [{'name': 'EBRD', 'sentiment': 'p...
# 84114 2022-03-10 16:40:00  {'entities': [{'name': 'Dmytro Kuleba', 'senti...
# 84204 2022-11-17 13:23:00  {'entities': [{'name': 'Philip Reeker', 'senti...
# 84216 2022-12-13 13:48:00  {'entities': [{'name': 'Arayik Harutyunyan', '...
# 84376 2023-11-23 15:16:00  {'entities': [{'name': 'Yershova', 'sentiment'...
#
#                                                  content
# 0      YEREVAN, JUNE 9, ARMENPRESS:Armenian President...
# 1      YEREVAN, JUNE 9, ARMENPRESS:Director of the Co...
# 2      YEREVAN, JUNE 5, ARMENPRESS:The credit agreeme...
# 3      YEREVAN, JUNE 1, ARMENPRESS:The observing miss...
# 4      BAKU, JUNE 1, ARMENPRESS:OSCE Minsk group is o...
# ...                                                  ...
# 84103  The European Bank for Reconstruction and Devel...
# 84114  Ukrainian Foreign Minister Dmytro Kuleba says ...
# 84204  U.S. Secretary of State's adviser on Caucasus ...
# 84216  On December 13, President of the Artsakh Repub...
# 84376  At the beginning of November, Tert.am reported...
#
# [36610 rows x 3 columns]

# %%
# def predict(content, entity_names)

with open(Path("cache") / "entties.dict.pkl", "rb") as f:
    entity_sentiments = pickle.load(f)

entity_names = list(entity_sentiments.keys())
out = []

for i, row in tqdm(df_feedback.iterrows()):
    article_sents = {}
    for ent in row.feedback["entities"]:
        if any([k not in ent for k in ["name", "sentiment"]]):
            continue

        name = ent["name"].lower()
        actual_sentiment = ent["sentiment"].lower()

        article_sentences = list(chain.from_iterable(
            [partition.split(".") for partition in row.content.lower().split(":")]
        ))
        article_sentences = [s.replace(",", "").lower() for s in article_sentences]
        
        # selecting relevant sentences
        relevant_sentances = [
            sent
            for sent
            in article_sentences
            if name in sent
        ]

        # Splitting into words
        relevant_words = list(
            chain.from_iterable(
                [re.findall(r"\w+", sent) for sent in relevant_sentances]
            )
        )

        # filtering stopwords and entity names
        relevant_words = [
            w for w in relevant_words
            if (w not in english_stopwords) and (
                w not in name
            )
        ]

        counts = [Counter(term_sentiment[w]) for w in relevant_words if w in term_sentiment]
        counter = Counter()
        for count in counts:
            counter += count
        
        article_sents[name] = counter
    out.append(article_sents)
# Out:
# 36610it [01:16, 477.08it/s]

# %%
df_feedback = df_feedback.copy()
df_feedback["predictions_raw"] = out
df_feedback
# Out:
#                      time                                           feedback  \
# 0     2009-06-08 00:00:00  {'entities': [{'name': 'Serzh Sargsyan', 'sent...
# 1     2009-06-08 00:00:00  {'entities': [{'name': 'David Hakhverdyan', 's...
# 2     2009-06-04 00:00:00  {'entities': [{'name': 'World Bank', 'sentimen...
# 3     2008-12-30 00:00:00  {'entities': [{'name': 'CoE Congress of Local ...
# 4     2009-06-01 00:00:00  {'entities': [{'name': 'Matthew Bryza', 'senti...
# ...                   ...                                                ...
# 84103 2022-01-20 13:03:00  {'entities': [{'name': 'EBRD', 'sentiment': 'p...
# 84114 2022-03-10 16:40:00  {'entities': [{'name': 'Dmytro Kuleba', 'senti...
# 84204 2022-11-17 13:23:00  {'entities': [{'name': 'Philip Reeker', 'senti...
# 84216 2022-12-13 13:48:00  {'entities': [{'name': 'Arayik Harutyunyan', '...
# 84376 2023-11-23 15:16:00  {'entities': [{'name': 'Yershova', 'sentiment'...
#
#                                                  content  \
# 0      YEREVAN, JUNE 9, ARMENPRESS:Armenian President...
# 1      YEREVAN, JUNE 9, ARMENPRESS:Director of the Co...
# 2      YEREVAN, JUNE 5, ARMENPRESS:The credit agreeme...
# 3      YEREVAN, JUNE 1, ARMENPRESS:The observing miss...
# 4      BAKU, JUNE 1, ARMENPRESS:OSCE Minsk group is o...
# ...                                                  ...
# 84103  The European Bank for Reconstruction and Devel...
# 84114  Ukrainian Foreign Minister Dmytro Kuleba says ...
# 84204  U.S. Secretary of State's adviser on Caucasus ...
# 84216  On December 13, President of the Artsakh Repub...
# 84376  At the beginning of November, Tert.am reported...
#
#                                          predictions_raw
# 0      {'serzh sargsyan': {'positive': 151383, 'negat...
# 1      {'david hakhverdyan': {'positive': 118572, 'ne...
# 2      {'world bank': {'positive': 46029, 'negative':...
# 3      {'coe congress of local and regional authoriti...
# 4      {'matthew bryza': {'positive': 66399, 'negativ...
# ...                                                  ...
# 84103  {'ebrd': {'positive': 231898, 'negative': 1515...
# 84114  {'dmytro kuleba': {'positive': 80926, 'negativ...
# 84204  {'philip reeker': {'positive': 86325, 'negativ...
# 84216  {'arayik harutyunyan': {'positive': 31357, 'ne...
# 84376  {'yershova': {'positive': 28165, 'negative': 3...
#
# [36610 rows x 4 columns]

# %%
(pred_tuples := df_feedback.apply(lambda x: [x.predictions_raw[ent["name"].lower()] for ent in x.feedback["entities"] if ("name" in ent) and ("sentiment" in ent)], axis=1))
# Out:
# 0        [{'positive': 151383, 'negative': 79200, 'neut...
# 1        [{'positive': 118572, 'negative': 57729, 'neut...
# 2        [{'positive': 46029, 'negative': 20284, 'neutr...
# 3        [{'positive': 20142, 'negative': 11838, 'neutr...
# 4        [{'positive': 66399, 'negative': 39051, 'neutr...
#                                ...
# 84103    [{'positive': 231898, 'negative': 151592, 'neu...
# 84114    [{'positive': 80926, 'negative': 57119, 'neutr...
# 84204    [{'positive': 86325, 'negative': 61237, 'neutr...
# 84216    [{'positive': 31357, 'negative': 21230, 'neutr...
# 84376    [{'positive': 28165, 'negative': 30966, 'neutr...
# Length: 36610, dtype: object

# %%
pred_tuples.iloc[0]
# Out:
# [Counter({'neutral': 235799, 'positive': 151383, 'negative': 79200}),
#  Counter({'neutral': 261583, 'positive': 168584, 'negative': 80362}),
#  Counter({'neutral': 130661, 'positive': 87477, 'negative': 38540}),
#  Counter({'neutral': 338797, 'positive': 233735, 'negative': 105654}),
#  Counter({'neutral': 129424, 'positive': 83159, 'negative': 42867}),
#  Counter({'neutral': 161330, 'positive': 113752, 'negative': 50056}),
#  Counter({'neutral': 89991, 'positive': 48603, 'negative': 26690})]

# %%
naive_method = pred_tuples.apply(lambda row: [ent.most_common(1)[0][0] if len(ent.most_common(1)) else None for ent in row])
df_feedback["naive_method"] = naive_method
df_feedback["naive_accuracy"] = df_feedback.apply(
    lambda row: np.sum(
        [
            (row.feedback["entities"][i]["sentiment"].lower() == row.naive_method[i])
            if ("entities" in row.feedback) and ("sentiment" in row.feedback["entities"][i])
            else False for i in range(len(row.naive_method))
        ]) / len(row.naive_method)
    , axis=1
)
# Out:
# C:\Users\mherm\AppData\Local\Temp\ipykernel_13492\3704098897.py:3: RuntimeWarning: invalid value encountered in scalar divide
#   df_feedback["naive_accuracy"] = df_feedback.apply(lambda row: np.sum([(row.feedback["entities"][i]["sentiment"].lower() == row.naive_method[i]) if ("entities" in row.feedback) and ("sentiment" in row.feedback["entities"][i]) else False for i in range(len(row.naive_method))]) / len(row.naive_method), axis=1)

# %%
df_feedback.naive_accuracy.mean()
# Out:
# 0.5092995121201346

# %%
total_sentiments = Counter()
for term, counts in term_sentiment.items():
    total_sentiments += counts

total_sentiments
# Out:
# Counter({'neutral': 3789399, 'positive': 1910713, 'negative': 1663099})

# %%
df_feedback["weighted_method"] = pred_tuples.apply(lambda row: [
    ["positive", "negative", "neutral"][np.argmax([
        int(ent["positive"]*730 / total_sentiments["positive"]),
        int(ent["negative"]*1000 / total_sentiments["negative"]),
        int(ent["neutral"]*1000 / total_sentiments["neutral"])
    ])] for ent in row
]) 

df_feedback["weighted_accuracy"] = df_feedback.apply(
    lambda row: np.sum(
        [
            (row.feedback["entities"][i]["sentiment"].lower() == row.weighted_method[i])
            if ("entities" in row.feedback) and ("sentiment" in row.feedback["entities"][i])
            else False for i in range(len(row.weighted_method))
        ]) / len(row.weighted_method)
    , axis=1
)

df_feedback
# Out:
# C:\Users\mherm\AppData\Local\Temp\ipykernel_13492\3744234344.py:10: RuntimeWarning: invalid value encountered in scalar divide
#   lambda row: np.sum(
#                      time                                           feedback  \
# 0     2009-06-08 00:00:00  {'entities': [{'name': 'Serzh Sargsyan', 'sent...
# 1     2009-06-08 00:00:00  {'entities': [{'name': 'David Hakhverdyan', 's...
# 2     2009-06-04 00:00:00  {'entities': [{'name': 'World Bank', 'sentimen...
# 3     2008-12-30 00:00:00  {'entities': [{'name': 'CoE Congress of Local ...
# 4     2009-06-01 00:00:00  {'entities': [{'name': 'Matthew Bryza', 'senti...
# ...                   ...                                                ...
# 84103 2022-01-20 13:03:00  {'entities': [{'name': 'EBRD', 'sentiment': 'p...
# 84114 2022-03-10 16:40:00  {'entities': [{'name': 'Dmytro Kuleba', 'senti...
# 84204 2022-11-17 13:23:00  {'entities': [{'name': 'Philip Reeker', 'senti...
# 84216 2022-12-13 13:48:00  {'entities': [{'name': 'Arayik Harutyunyan', '...
# 84376 2023-11-23 15:16:00  {'entities': [{'name': 'Yershova', 'sentiment'...
#
#                                                  content  \
# 0      YEREVAN, JUNE 9, ARMENPRESS:Armenian President...
# 1      YEREVAN, JUNE 9, ARMENPRESS:Director of the Co...
# 2      YEREVAN, JUNE 5, ARMENPRESS:The credit agreeme...
# 3      YEREVAN, JUNE 1, ARMENPRESS:The observing miss...
# 4      BAKU, JUNE 1, ARMENPRESS:OSCE Minsk group is o...
# ...                                                  ...
# 84103  The European Bank for Reconstruction and Devel...
# 84114  Ukrainian Foreign Minister Dmytro Kuleba says ...
# 84204  U.S. Secretary of State's adviser on Caucasus ...
# 84216  On December 13, President of the Artsakh Repub...
# 84376  At the beginning of November, Tert.am reported...
#
#                                          predictions_raw  \
# 0      {'serzh sargsyan': {'positive': 151383, 'negat...
# 1      {'david hakhverdyan': {'positive': 118572, 'ne...
# 2      {'world bank': {'positive': 46029, 'negative':...
# 3      {'coe congress of local and regional authoriti...
# 4      {'matthew bryza': {'positive': 66399, 'negativ...
# ...                                                  ...
# 84103  {'ebrd': {'positive': 231898, 'negative': 1515...
# 84114  {'dmytro kuleba': {'positive': 80926, 'negativ...
# 84204  {'philip reeker': {'positive': 86325, 'negativ...
# 84216  {'arayik harutyunyan': {'positive': 31357, 'ne...
# 84376  {'yershova': {'positive': 28165, 'negative': 3...
#
#                                             naive_method  naive_accuracy  \
# 0      [neutral, neutral, neutral, neutral, neutral, ...        0.571429
# 1             [neutral, neutral, None, neutral, neutral]        0.200000
# 2      [neutral, neutral, neutral, neutral, neutral, ...        0.117647
# 3      [neutral, neutral, neutral, neutral, neutral, ...        0.076923
# 4                      [neutral, neutral, None, neutral]        0.250000
# ...                                                  ...             ...
# 84103  [neutral, neutral, neutral, None, neutral, neu...        0.000000
# 84114               [neutral, neutral, neutral, neutral]        0.500000
# 84204  [neutral, neutral, neutral, neutral, neutral, ...        0.300000
# 84216               [neutral, neutral, neutral, neutral]        0.750000
# 84376                                    [neutral, None]        0.000000
#
#                                          weighted_method  weighted_accuracy
# 0      [neutral, neutral, neutral, positive, neutral,...           0.571429
# 1        [neutral, neutral, positive, positive, neutral]           0.400000
# 2      [positive, positive, neutral, neutral, positiv...           0.588235
# 3      [neutral, negative, neutral, neutral, neutral,...           0.076923
# 4                  [neutral, neutral, positive, neutral]           0.250000
# ...                                                  ...                ...
# 84103  [neutral, neutral, negative, positive, neutral...           0.285714
# 84114               [neutral, neutral, neutral, neutral]           0.500000
# 84204  [neutral, neutral, neutral, neutral, neutral, ...           0.300000
# 84216              [neutral, neutral, neutral, negative]           0.500000
# 84376                               [negative, positive]           0.500000
#
# [36610 rows x 8 columns]

# %%
df_feedback.weighted_accuracy.mean()
# Out:
# 0.5055900801824041
