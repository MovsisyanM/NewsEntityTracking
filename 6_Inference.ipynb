# %% [markdown]
# # Inferring sentiment for the rest of the articles

# %%
import numpy as np
import pandas as pd
import re
import sqlite3
from digest_utils import strpdict
from itertools import chain
from collections import Counter
import requests
from tqdm import tqdm
import pickle
from pathlib import Path

np.random.seed(173)

# %%
# Connect to local db
db_armenpress = sqlite3.connect("Armenpress/scraping.db")
db_newsam = sqlite3.connect("Newsam/scraping.db")
db_tertam = sqlite3.connect("Tertam/scraping.db")

# loading data into dataframes
df_armenpress = pd.read_sql_query("select * from article", db_armenpress)
df_newsam = pd.read_sql_query("select * from article", db_newsam)
df_tertam = pd.read_sql_query("select * from article", db_tertam)

# parsing datetimes
df_tertam.time = pd.to_datetime(df_tertam.time)
df_newsam.time = pd.to_datetime(df_newsam.time)
df_armenpress.time = pd.to_datetime(df_armenpress.time)

# %%
# join all datasets
df = pd.concat([df[["time", "feedback", "content"]] for df in [df_armenpress, df_newsam, df_tertam]], axis=0)
df.feedback.str.replace("\n", "")
(df_feedback := df[~df.feedback.isna()].copy())
# Out:
#                      time                                           feedback  \
# 0     2009-06-08 00:00:00  {\n  "entities": [\n    {\n      "name": "Serz...
# 1     2009-06-08 00:00:00  {\n  "entities": [\n    {\n      "name": "Davi...
# 2     2009-06-04 00:00:00  {"entities": [\n  {"name": "World Bank", "sent...
# 3     2008-12-30 00:00:00  {\n  "entities": [\n    {"name": "CoE Congress...
# 4     2009-06-01 00:00:00  {\n  "entities": [\n    {\n      "name": "Matt...
# ...                   ...                                                ...
# 84103 2022-01-20 13:03:00  {\n  "entities": [\n    {\n      "name": "EBRD...
# 84114 2022-03-10 16:40:00  {\n  "entities": [\n    {\n      "name": "Dmyt...
# 84204 2022-11-17 13:23:00  {\n  "entities": [\n    {\n      "name": "Phil...
# 84216 2022-12-13 13:48:00  {\n  "entities": [\n    {\n      "name": "Aray...
# 84376 2023-11-23 15:16:00  {\n  "entities": [\n    {\n      "name": "Yers...
#
#                                                  content
# 0      YEREVAN, JUNE 9, ARMENPRESS:Armenian President...
# 1      YEREVAN, JUNE 9, ARMENPRESS:Director of the Co...
# 2      YEREVAN, JUNE 5, ARMENPRESS:The credit agreeme...
# 3      YEREVAN, JUNE 1, ARMENPRESS:The observing miss...
# 4      BAKU, JUNE 1, ARMENPRESS:OSCE Minsk group is o...
# ...                                                  ...
# 84103  The European Bank for Reconstruction and Devel...
# 84114  Ukrainian Foreign Minister Dmytro Kuleba says ...
# 84204  U.S. Secretary of State's adviser on Caucasus ...
# 84216  On December 13, President of the Artsakh Repub...
# 84376  At the beginning of November, Tert.am reported...
#
# [36827 rows x 3 columns]

# %%
# parse feedbacks
df_feedback.feedback = df_feedback.feedback.apply(strpdict)
# Out:
# unexpected indent (<unknown>, line 20)
# '{' was never closed (<unknown>, line 33)
# '{' was never closed (<unknown>, line 18)
# '{' was never closed (<unknown>, line 18)
# '[' was never closed (<unknown>, line 2)
# '{' was never closed (<unknown>, line 28)
# '{' was never closed (<unknown>, line 8)
# '{' was never closed (<unknown>, line 13)
# '{' was never closed (<unknown>, line 13)

# %%
# filter down to usable feedbacks
(df_feedback := df_feedback[
    ~df_feedback.feedback.isna() & (
        df_feedback.feedback.apply(
            lambda x: hasattr(x, "keys") and "entities" in x.keys()
            )
        )
    ]
)
# Out:
#                      time                                           feedback  \
# 0     2009-06-08 00:00:00  {'entities': [{'name': 'Serzh Sargsyan', 'sent...
# 1     2009-06-08 00:00:00  {'entities': [{'name': 'David Hakhverdyan', 's...
# 2     2009-06-04 00:00:00  {'entities': [{'name': 'World Bank', 'sentimen...
# 3     2008-12-30 00:00:00  {'entities': [{'name': 'CoE Congress of Local ...
# 4     2009-06-01 00:00:00  {'entities': [{'name': 'Matthew Bryza', 'senti...
# ...                   ...                                                ...
# 84103 2022-01-20 13:03:00  {'entities': [{'name': 'EBRD', 'sentiment': 'p...
# 84114 2022-03-10 16:40:00  {'entities': [{'name': 'Dmytro Kuleba', 'senti...
# 84204 2022-11-17 13:23:00  {'entities': [{'name': 'Philip Reeker', 'senti...
# 84216 2022-12-13 13:48:00  {'entities': [{'name': 'Arayik Harutyunyan', '...
# 84376 2023-11-23 15:16:00  {'entities': [{'name': 'Yershova', 'sentiment'...
#
#                                                  content
# 0      YEREVAN, JUNE 9, ARMENPRESS:Armenian President...
# 1      YEREVAN, JUNE 9, ARMENPRESS:Director of the Co...
# 2      YEREVAN, JUNE 5, ARMENPRESS:The credit agreeme...
# 3      YEREVAN, JUNE 1, ARMENPRESS:The observing miss...
# 4      BAKU, JUNE 1, ARMENPRESS:OSCE Minsk group is o...
# ...                                                  ...
# 84103  The European Bank for Reconstruction and Devel...
# 84114  Ukrainian Foreign Minister Dmytro Kuleba says ...
# 84204  U.S. Secretary of State's adviser on Caucasus ...
# 84216  On December 13, President of the Artsakh Repub...
# 84376  At the beginning of November, Tert.am reported...
#
# [36610 rows x 3 columns]

# %%
# words to count for bag of words
words_to_count = Counter()
ent_name = df_feedback.feedback.iloc[0]["entities"][0]["name"]
feedback = df_feedback.feedback.iloc[0]["entities"][0]["explanation"]
article_sentences = list(chain.from_iterable(
    [partition.split(".") for partition in df_feedback.content.iloc[0].split(":")]
))
article_sentences = [s.replace(",", "").lower() for s in article_sentences]
relevant_sentances = [feedback] + [
    sent
    for sent
    in article_sentences
    if ent_name.lower() in sent
]

relevant_words = list(
    chain.from_iterable(
        [re.findall(r"\w+", sent) for sent in relevant_sentances]
    )
)

# Split the sentances that mentio the entity into words
words_to_count += Counter(relevant_words)
words_to_count
# Out:
# Counter({'the': 10,
#          'of': 4,
#          'as': 3,
#          'received': 2,
#          'armenian': 2,
#          'president': 2,
#          'serzh': 2,
#          'sargsyan': 2,
#          'director': 2,
#          'france': 2,
#          'telecom': 2,
#          'orange': 2,
#          'company': 2,
#          'that': 2,
#          'in': 2,
#          'mentioned': 1,
#          'Armenian': 1,
#          'President': 1,
#          'who': 1,
#          'executives': 1,
#          'today': 1,
#          'olaf': 1,
#          'swantee': 1,
#          'executive': 1,
#          'vice': 1,
#          'and': 1,
#          'bruno': 1,
#          'dutua': 1,
#          'chief': 1,
#          'armenia': 1,
#          'we': 1,
#          'are': 1,
#          'interested': 1,
#          'one': 1,
#          'world': 1,
#          's': 1,
#          'leading': 1,
#          'operators': 1,
#          'telecommunication': 1,
#          'sphere': 1,
#          'starts': 1,
#          'its': 1,
#          'activity': 1,
#          'our': 1,
#          'state': 1,
#          'soon': 1,
#          'possible': 1,
#          'pointed': 1,
#          'out': 1,
#          'noting': 1,
#          'government': 1,
#          'is': 1,
#          'ready': 1,
#          'to': 1,
#          'assist': 1,
#          'solution': 1,
#          'issues': 1,
#          'which': 1,
#          'will': 1,
#          'arouse': 1,
#          'during': 1,
#          'works': 1})

# %% [markdown]
# Ignoring stopwords

# %%
(english_stopwords := requests.get(
    "https://gist.githubusercontent.com"
    "/sebleier/554280/raw/7e0e4a1ce04c2bb7bd41089"
    "c9821dbcf6d0c786c/NLTK's%2520list%2520of%252"
    "0english%2520stopwords"
).content.decode().split("\n"))[40:50]
# Out:
# ['was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do']

# %%
{
    k.lower(): v
    for k, v in words_to_count.items()
    if (
        k.lower() not in english_stopwords
    ) and (
        k.lower() not in ent_name.lower()
    )
}
# Out:
# {'mentioned': 1,
#  'armenian': 2,
#  'president': 2,
#  'received': 2,
#  'executives': 1,
#  'today': 1,
#  'olaf': 1,
#  'swantee': 1,
#  'executive': 1,
#  'vice': 1,
#  'director': 2,
#  'france': 2,
#  'telecom': 2,
#  'orange': 2,
#  'company': 2,
#  'bruno': 1,
#  'dutua': 1,
#  'chief': 1,
#  'armenia': 1,
#  'interested': 1,
#  'one': 1,
#  'world': 1,
#  'leading': 1,
#  'operators': 1,
#  'telecommunication': 1,
#  'sphere': 1,
#  'starts': 1,
#  'activity': 1,
#  'state': 1,
#  'soon': 1,
#  'possible': 1,
#  'pointed': 1,
#  'noting': 1,
#  'government': 1,
#  'ready': 1,
#  'assist': 1,
#  'solution': 1,
#  'issues': 1,
#  'arouse': 1,
#  'works': 1}

# %% [markdown]
# Wrapping it all in a function

# %%
words_to_count = {
    "positive": Counter(),
    "negative": Counter(),
    "neutral": Counter(),
}

ent_datas = df_feedback.feedback.iloc[0]["entities"]
def extract_word_counts(obs: dict, content: str):
    """To be applied (not the built-in way) on a pandas series of
    dictionaries containing entity data. Counts the words around
    the mentioned entity and while keeping track of the sentiment

    Args:
        obs (dict): observation that has the key `entities` which
        is a list of dicts that have the keys `name`, `sentiment`,
        and `explanation`.
        content (str): the text of the article.
    """
    if "entities" not in obs:
        print("Obs. missing key entities")

    for ent_data in obs["entities"]:
        if (type(ent_data) is not dict) or any(
            [k not in ent_data for k in ["name", "sentiment"]]
        ) or (
            ent_data["sentiment"].lower() not in ["positive", "negative", "neutral"]
        ):
            continue
        

        ent_name = ent_data["name"].lower()
        feedback = ent_data["explanation"].lower() if "explanation" in ent_data else ""
        sentiment = ent_data["sentiment"].lower()

        # splitting articles into sentences
        article_sentences = list(chain.from_iterable(
            [partition.split(".") for partition in content.split(":")]
        ))
        article_sentences = [s.replace(",", "").lower() for s in article_sentences]
        
        # selecting relevant sentences
        relevant_sentances = [feedback] + [
            sent
            for sent
            in article_sentences
            if ent_name in sent
        ]

        # Splitting into words
        relevant_words = list(
            chain.from_iterable(
                [re.findall(r"\w+", sent) for sent in relevant_sentances]
            )
        )

        # filtering stopwords and entity names
        relevant_words = [
            w for w in relevant_words
            if (w not in english_stopwords) and (
                w not in ent_name
            )
        ]

        # Split the sentances that mentio the entity into words
        words_to_count[sentiment] += Counter(relevant_words)

# %%
for i, obs in tqdm(df_feedback.iterrows()):
    extract_word_counts(obs["feedback"], obs["content"])
# Out:
# 36610it [08:07, 75.09it/s]

# %%
with open(Path("cache") / "words_count.Counter.pkl", "wb") as f:
    pickle.dump(words_to_count, f)

# %%
with open(Path("cache") / "words_count.Counter.pkl", "rb") as f:
    word_sentiments = pickle.load(f)

# %%
words = set(
    list(word_sentiments["positive"].keys()) + 
    list(word_sentiments["negative"].keys()) + 
    list(word_sentiments["neutral"].keys())
)

term_sentiment = {}

for word in words:
    term_sentiment[word] = {
        sent: word_sentiments[sent][word] if word in word_sentiments[sent] else 0
        for sent in ["positive", "negative", "neutral"]
    }

term_sentiment
# Out:
# {'mortgaging': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'lowers': {'positive': 0, 'negative': 3, 'neutral': 1},
#  'round': {'positive': 348, 'negative': 168, 'neutral': 791},
#  'plunged': {'positive': 4, 'negative': 31, 'neutral': 28},
#  'samuelson': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'spectre': {'positive': 0, 'negative': 2, 'neutral': 2},
#  'hobbs': {'positive': 3, 'negative': 0, 'neutral': 0},
#  'diyarbekir': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'terrestrial': {'positive': 1, 'negative': 2, 'neutral': 0},
#  'grant': {'positive': 172, 'negative': 66, 'neutral': 176},
#  'stimulation': {'positive': 1, 'negative': 0, 'neutral': 3},
#  'entailing': {'positive': 0, 'negative': 2, 'neutral': 9},
#  'hematological': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'aftera': {'positive': 1, 'negative': 2, 'neutral': 0},
#  'abdelhak': {'positive': 3, 'negative': 0, 'neutral': 0},
#  'rout': {'positive': 2, 'negative': 3, 'neutral': 1},
#  '5222408': {'positive': 0, 'negative': 2, 'neutral': 2},
#  '19252': {'positive': 0, 'negative': 1, 'neutral': 3},
#  '576851': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'retailer': {'positive': 13, 'negative': 1, 'neutral': 5},
#  'teson': {'positive': 0, 'negative': 2, 'neutral': 3},
#  'shelf': {'positive': 10, 'negative': 1, 'neutral': 9},
#  'vanush': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'jackie': {'positive': 415, 'negative': 27, 'neutral': 65},
#  'euphemistic': {'positive': 0, 'negative': 3, 'neutral': 1},
#  'slower': {'positive': 3, 'negative': 9, 'neutral': 10},
#  'ministerfor': {'positive': 2, 'negative': 3, 'neutral': 4},
#  'inga': {'positive': 24, 'negative': 0, 'neutral': 0},
#  'paso': {'positive': 0, 'negative': 4, 'neutral': 5},
#  'nixed': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'hasse': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'aeros': {'positive': 2, 'negative': 0, 'neutral': 2},
#  'rustamova': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'asbroadcast': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'reverberating': {'positive': 2, 'negative': 2, 'neutral': 6},
#  'obama': {'positive': 800, 'negative': 926, 'neutral': 1809},
#  'chegoggin': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'aronina': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'tofacebook': {'positive': 4, 'negative': 0, 'neutral': 2},
#  'curtailment': {'positive': 1, 'negative': 3, 'neutral': 1},
#  'legaltools': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'brown': {'positive': 123, 'negative': 13, 'neutral': 72},
#  'interface': {'positive': 0, 'negative': 2, 'neutral': 2},
#  'photostart': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'merits': {'positive': 10, 'negative': 5, 'neutral': 11},
#  'ahrar': {'positive': 1, 'negative': 10, 'neutral': 11},
#  'taxing': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'eventuality': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'sabra': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'illustrative': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'gap': {'positive': 27, 'negative': 35, 'neutral': 58},
#  'irzhi': {'positive': 0, 'negative': 0, 'neutral': 1},
#  '1914': {'positive': 7, 'negative': 7, 'neutral': 20},
#  '92d': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'tpp': {'positive': 3, 'negative': 4, 'neutral': 17},
#  'inis': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'continuing': {'positive': 349, 'negative': 354, 'neutral': 535},
#  'chubarov': {'positive': 1, 'negative': 1, 'neutral': 4},
#  'brca': {'positive': 3, 'negative': 0, 'neutral': 0},
#  'toreport': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'gorsuch': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'villalobos': {'positive': 0, 'negative': 1, 'neutral': 0},
#  '40pm': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'retribution': {'positive': 1, 'negative': 12, 'neutral': 10},
#  'fishturning': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'cicumstances': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'clientele': {'positive': 3, 'negative': 0, 'neutral': 2},
#  'gnel': {'positive': 13, 'negative': 0, 'neutral': 9},
#  'tofik': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'migrations': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'ofunarmed': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'libyan': {'positive': 38, 'negative': 126, 'neutral': 164},
#  'mcmillan': {'positive': 3, 'negative': 0, 'neutral': 1},
#  'eod': {'positive': 5, 'negative': 0, 'neutral': 0},
#  'galustova': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'scientistse28099': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'strzhizhovsky': {'positive': 0, 'negative': 1, 'neutral': 4},
#  'method': {'positive': 30, 'negative': 22, 'neutral': 44},
#  '11000': {'positive': 4, 'negative': 5, 'neutral': 9},
#  'asco': {'positive': 3, 'negative': 0, 'neutral': 1},
#  'tungendhat': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'kmep': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'asus': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'firmly': {'positive': 57, 'negative': 44, 'neutral': 88},
#  'ofhostilities': {'positive': 3, 'negative': 0, 'neutral': 2},
#  'curfew': {'positive': 2, 'negative': 6, 'neutral': 4},
#  'kidnap': {'positive': 1, 'negative': 4, 'neutral': 2},
#  'iskandarian': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'onher': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'sensationalizing': {'positive': 0, 'negative': 0, 'neutral': 1},
#  '5635': {'positive': 0, 'negative': 2, 'neutral': 2},
#  'stacey': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'kaya': {'positive': 2, 'negative': 3, 'neutral': 1},
#  'blow': {'positive': 27, 'negative': 200, 'neutral': 115},
#  'greenpeace': {'positive': 14, 'negative': 7, 'neutral': 19},
#  'solving': {'positive': 159, 'negative': 57, 'neutral': 203},
#  'totravel': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'semyon': {'positive': 7, 'negative': 1, 'neutral': 9},
#  '1978': {'positive': 11, 'negative': 9, 'neutral': 18},
#  'islamicopus': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'agitate': {'positive': 0, 'negative': 2, 'neutral': 2},
#  'drank': {'positive': 2, 'negative': 1, 'neutral': 4},
#  'tovmasian': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'autonomous': {'positive': 40, 'negative': 189, 'neutral': 247},
#  'host': {'positive': 338, 'negative': 121, 'neutral': 568},
#  'bewilderment': {'positive': 0, 'negative': 24, 'neutral': 9},
#  'bloodiest': {'positive': 0, 'negative': 6, 'neutral': 3},
#  'precedents': {'positive': 1, 'negative': 3, 'neutral': 10},
#  'headlight': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'deepest': {'positive': 21, 'negative': 19, 'neutral': 43},
#  '13and14december': {'positive': 1, 'negative': 0, 'neutral': 3},
#  'enumerated': {'positive': 2, 'negative': 0, 'neutral': 4},
#  'bungalow': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'avispa': {'positive': 0, 'negative': 3, 'neutral': 1},
#  'twentieth': {'positive': 12, 'negative': 3, 'neutral': 10},
#  'mikhayil': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'masterpieces': {'positive': 3, 'negative': 3, 'neutral': 0},
#  'mispronounced': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'saw': {'positive': 99, 'negative': 169, 'neutral': 226},
#  'caucasuses': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'minorities': {'positive': 95, 'negative': 158, 'neutral': 120},
#  'innovative': {'positive': 166, 'negative': 7, 'neutral': 52},
#  'riddled': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'propganda': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'mobilizes': {'positive': 3, 'negative': 0, 'neutral': 2},
#  'failed': {'positive': 82, 'negative': 614, 'neutral': 613},
#  'mugrdechian': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'wegmans': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'quipping': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'travellers': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'launches': {'positive': 31, 'negative': 109, 'neutral': 123},
#  'pope': {'positive': 158, 'negative': 58, 'neutral': 162},
#  'laidback': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'modoyan': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'robinsonto': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'marine': {'positive': 49, 'negative': 24, 'neutral': 77},
#  'unctad': {'positive': 14, 'negative': 2, 'neutral': 7},
#  'glenday': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'freegans': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'tested': {'positive': 58, 'negative': 80, 'neutral': 137},
#  'mantras': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'tinie': {'positive': 2, 'negative': 0, 'neutral': 0},
#  '1973': {'positive': 8, 'negative': 1, 'neutral': 11},
#  'love': {'positive': 244, 'negative': 19, 'neutral': 160},
#  'withbelarus': {'positive': 1, 'negative': 0, 'neutral': 3},
#  'cjs': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'pleasant': {'positive': 38, 'negative': 6, 'neutral': 15},
#  'sang': {'positive': 15, 'negative': 2, 'neutral': 12},
#  'bayerische': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'omits': {'positive': 0, 'negative': 1, 'neutral': 4},
#  'afghanistanafter': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'nasheed': {'positive': 7, 'negative': 0, 'neutral': 3},
#  'ferrying': {'positive': 0, 'negative': 1, 'neutral': 7},
#  'homage': {'positive': 12, 'negative': 0, 'neutral': 6},
#  '11198': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'brief': {'positive': 56, 'negative': 66, 'neutral': 164},
#  'moisture': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'relativistic': {'positive': 4, 'negative': 0, 'neutral': 0},
#  'macherevich': {'positive': 0, 'negative': 5, 'neutral': 0},
#  'rourke': {'positive': 67, 'negative': 0, 'neutral': 0},
#  '980': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'menua': {'positive': 1, 'negative': 2, 'neutral': 3},
#  'svt': {'positive': 1, 'negative': 1, 'neutral': 3},
#  'gusev': {'positive': 0, 'negative': 1, 'neutral': 5},
#  'ok': {'positive': 71, 'negative': 7, 'neutral': 26},
#  'capitulation': {'positive': 4, 'negative': 14, 'neutral': 15},
#  'interval': {'positive': 4, 'negative': 0, 'neutral': 3},
#  'inertia': {'positive': 1, 'negative': 2, 'neutral': 1},
#  '8085': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'prostitution': {'positive': 12, 'negative': 10, 'neutral': 7},
#  'parallel': {'positive': 49, 'negative': 46, 'neutral': 82},
#  'advised': {'positive': 14, 'negative': 51, 'neutral': 76},
#  'volnovakha': {'positive': 3, 'negative': 3, 'neutral': 12},
#  'implies': {'positive': 294, 'negative': 1241, 'neutral': 377},
#  'securityfranz': {'positive': 0, 'negative': 0, 'neutral': 5},
#  'adelfia': {'positive': 0, 'negative': 0, 'neutral': 6},
#  'unmoved': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'nordsjælland': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'parites': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'mohamed': {'positive': 14, 'negative': 12, 'neutral': 34},
#  'starkest': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'oligarch': {'positive': 6, 'negative': 27, 'neutral': 27},
#  'posit': {'positive': 0, 'negative': 2, 'neutral': 5},
#  'sivacioglu': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'overflowing': {'positive': 0, 'negative': 2, 'neutral': 2},
#  'atpurdue': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'kazaryan': {'positive': 0, 'negative': 3, 'neutral': 2},
#  'hotting': {'positive': 0, 'negative': 1, 'neutral': 4},
#  'closely': {'positive': 321, 'negative': 146, 'neutral': 434},
#  'volcanic': {'positive': 3, 'negative': 5, 'neutral': 1},
#  'sida': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'sizzled': {'positive': 1, 'negative': 2, 'neutral': 1},
#  '19bn': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'dīvide': {'positive': 0, 'negative': 1, 'neutral': 0},
#  '651': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'salesman': {'positive': 1, 'negative': 2, 'neutral': 1},
#  'ema': {'positive': 3, 'negative': 0, 'neutral': 3},
#  'gassia': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'pearl': {'positive': 4, 'negative': 4, 'neutral': 4},
#  'flexner': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'vadim': {'positive': 33, 'negative': 24, 'neutral': 41},
#  'kabel': {'positive': 3, 'negative': 0, 'neutral': 0},
#  'humor': {'positive': 6, 'negative': 2, 'neutral': 7},
#  'zaurazizov': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'abramova': {'positive': 0, 'negative': 3, 'neutral': 4},
#  'epoch': {'positive': 2, 'negative': 0, 'neutral': 4},
#  'reportage': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'contradictive': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'daring': {'positive': 1, 'negative': 9, 'neutral': 3},
#  'felony': {'positive': 0, 'negative': 3, 'neutral': 2},
#  'kalamanov': {'positive': 0, 'negative': 0, 'neutral': 1},
#  '403': {'positive': 3, 'negative': 1, 'neutral': 3},
#  'louyotsays': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'series': {'positive': 168, 'negative': 210, 'neutral': 351},
#  'certitudes': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'harrowitz': {'positive': 1, 'negative': 0, 'neutral': 0},
#  '16thor': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'pasts': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'kosgrove': {'positive': 7, 'negative': 0, 'neutral': 2},
#  'carlson': {'positive': 3, 'negative': 2, 'neutral': 5},
#  'advisors': {'positive': 5, 'negative': 8, 'neutral': 20},
#  'scrupulous': {'positive': 1, 'negative': 1, 'neutral': 3},
#  'defending': {'positive': 83, 'negative': 58, 'neutral': 133},
#  'tiny': {'positive': 16, 'negative': 24, 'neutral': 33},
#  'café': {'positive': 2, 'negative': 13, 'neutral': 13},
#  'distress': {'positive': 6, 'negative': 63, 'neutral': 14},
#  'several': {'positive': 740, 'negative': 1023, 'neutral': 1697},
#  'maybe': {'positive': 33, 'negative': 39, 'neutral': 79},
#  'registrars': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'nudity': {'positive': 0, 'negative': 1, 'neutral': 4},
#  'volzsky': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'ibrahimbegov': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'imply': {'positive': 43, 'negative': 124, 'neutral': 549},
#  'walters': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'talents': {'positive': 16, 'negative': 0, 'neutral': 1},
#  'avoidable': {'positive': 1, 'negative': 1, 'neutral': 3},
#  'shopping': {'positive': 31, 'negative': 86, 'neutral': 78},
#  'chick': {'positive': 22, 'negative': 0, 'neutral': 0},
#  'tens': {'positive': 67, 'negative': 140, 'neutral': 128},
#  'reader': {'positive': 20, 'negative': 4, 'neutral': 22},
#  'hydroelectric': {'positive': 19, 'negative': 5, 'neutral': 8},
#  'navdex': {'positive': 3, 'negative': 0, 'neutral': 2},
#  'noticias': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'protectionism': {'positive': 3, 'negative': 4, 'neutral': 14},
#  'archive': {'positive': 26, 'negative': 20, 'neutral': 29},
#  'cypriot': {'positive': 13, 'negative': 17, 'neutral': 34},
#  'unavoidable': {'positive': 1, 'negative': 6, 'neutral': 2},
#  'retracted': {'positive': 0, 'negative': 3, 'neutral': 4},
#  'krasnogorsky': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'congeessman': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'ismaylova': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'darling': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'shown': {'positive': 266, 'negative': 113, 'neutral': 170},
#  'kovalevskaya': {'positive': 2, 'negative': 1, 'neutral': 1},
#  'frenchman': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'baghdassarian': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'basque': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'passageways': {'positive': 0, 'negative': 1, 'neutral': 1},
#  '8863': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'jihadism': {'positive': 0, 'negative': 3, 'neutral': 1},
#  'funcitioning': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'messenger': {'positive': 5, 'negative': 0, 'neutral': 21},
#  'kunalakis': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'figleaf': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'dankvert': {'positive': 0, 'negative': 2, 'neutral': 4},
#  'fabiano': {'positive': 49, 'negative': 0, 'neutral': 12},
#  'molnari': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'telstra': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'internationalassociation': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'planners': {'positive': 0, 'negative': 11, 'neutral': 8},
#  'objecting': {'positive': 2, 'negative': 14, 'neutral': 11},
#  'varujan': {'positive': 0, 'negative': 0, 'neutral': 5},
#  'ahmadinezhad': {'positive': 2, 'negative': 3, 'neutral': 4},
#  'petrovky': {'positive': 0, 'negative': 0, 'neutral': 5},
#  '13377': {'positive': 0, 'negative': 0, 'neutral': 6},
#  'koghb': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'purposeful': {'positive': 4, 'negative': 5, 'neutral': 7},
#  'seyran': {'positive': 163, 'negative': 24, 'neutral': 282},
#  'largely': {'positive': 77, 'negative': 133, 'neutral': 204},
#  'spivakova': {'positive': 2, 'negative': 0, 'neutral': 2},
#  'access': {'positive': 285, 'negative': 460, 'neutral': 530},
#  'fbi': {'positive': 30, 'negative': 100, 'neutral': 200},
#  'brushed': {'positive': 0, 'negative': 3, 'neutral': 12},
#  'disfigurement': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'mcreynolds': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'saxon': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'machyan': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'esp': {'positive': 0, 'negative': 0, 'neutral': 16},
#  'groundwork': {'positive': 19, 'negative': 18, 'neutral': 23},
#  'defend': {'positive': 184, 'negative': 206, 'neutral': 335},
#  'mathernová': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'afghani': {'positive': 6, 'negative': 1, 'neutral': 1},
#  'fars': {'positive': 14, 'negative': 11, 'neutral': 42},
#  'harityunyan': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'swell': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'gaia': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'dilettante': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'kama': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'iryani': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'contacted': {'positive': 8, 'negative': 29, 'neutral': 107},
#  'profound': {'positive': 39, 'negative': 37, 'neutral': 34},
#  'lace': {'positive': 5, 'negative': 0, 'neutral': 1},
#  'studiesinwashington': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'zeel': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'rescinded': {'positive': 0, 'negative': 0, 'neutral': 3},
#  '5300': {'positive': 0, 'negative': 4, 'neutral': 2},
#  'als': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'ars': {'positive': 8, 'negative': 0, 'neutral': 11},
#  'pitcher': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'beautified': {'positive': 3, 'negative': 0, 'neutral': 1},
#  'transdnestr': {'positive': 5, 'negative': 0, 'neutral': 12},
#  'ruhollah': {'positive': 0, 'negative': 3, 'neutral': 3},
#  'factsheet': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'rolandi': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'inferior': {'positive': 10, 'negative': 8, 'neutral': 12},
#  'amkar': {'positive': 0, 'negative': 0, 'neutral': 21},
#  'verum': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'mercurial': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'panarin': {'positive': 0, 'negative': 0, 'neutral': 7},
#  'kozhevnikova': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'step': {'positive': 1310, 'negative': 485, 'neutral': 1014},
#  'borussiadortmundfc': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'busta': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'провозглашении': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'unblocked': {'positive': 6, 'negative': 4, 'neutral': 5},
#  'wrestlers': {'positive': 5, 'negative': 0, 'neutral': 6},
#  'artem': {'positive': 12, 'negative': 6, 'neutral': 8},
#  'kupriyanov': {'positive': 0, 'negative': 0, 'neutral': 5},
#  'value': {'positive': 252, 'negative': 112, 'neutral': 216},
#  'metro': {'positive': 10, 'negative': 21, 'neutral': 30},
#  'missioneight': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'introduce': {'positive': 139, 'negative': 94, 'neutral': 173},
#  'inscription': {'positive': 7, 'negative': 3, 'neutral': 5},
#  '54435': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'daalder': {'positive': 0, 'negative': 2, 'neutral': 3},
#  'sittings': {'positive': 1, 'negative': 0, 'neutral': 3},
#  'gnomon': {'positive': 1, 'negative': 0, 'neutral': 3},
#  'fan': {'positive': 31, 'negative': 6, 'neutral': 34},
#  'unrelenting': {'positive': 2, 'negative': 11, 'neutral': 4},
#  'gdansk': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'ковчег': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'packing': {'positive': 0, 'negative': 2, 'neutral': 5},
#  'bolshoe': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'nestled': {'positive': 0, 'negative': 3, 'neutral': 1},
#  'gentleman': {'positive': 0, 'negative': 6, 'neutral': 6},
#  'thatthere': {'positive': 0, 'negative': 1, 'neutral': 7},
#  '317': {'positive': 3, 'negative': 3, 'neutral': 6},
#  'walks': {'positive': 2, 'negative': 4, 'neutral': 2},
#  'taschyan': {'positive': 16, 'negative': 0, 'neutral': 24},
#  'equip': {'positive': 8, 'negative': 4, 'neutral': 11},
#  'igorkutrovski': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'fragmented': {'positive': 1, 'negative': 2, 'neutral': 5},
#  'scaparrotti': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'bitlis': {'positive': 1, 'negative': 2, 'neutral': 2},
#  'timakova': {'positive': 1, 'negative': 1, 'neutral': 10},
#  'blacked': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'nicollier': {'positive': 2, 'negative': 3, 'neutral': 1},
#  'flipping': {'positive': 0, 'negative': 1, 'neutral': 0},
#  '1217': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'targamadze': {'positive': 0, 'negative': 3, 'neutral': 0},
#  'petrosian': {'positive': 21, 'negative': 12, 'neutral': 75},
#  'analogue': {'positive': 0, 'negative': 1, 'neutral': 5},
#  'unhelfpul': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'goblin': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'extra': {'positive': 30, 'negative': 36, 'neutral': 101},
#  'andrea': {'positive': 45, 'negative': 5, 'neutral': 19},
#  'thug': {'positive': 0, 'negative': 4, 'neutral': 2},
#  'forbest': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'aligns': {'positive': 46, 'negative': 3, 'neutral': 62},
#  'flip': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'iccpr': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'iaa': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'dimension': {'positive': 15, 'negative': 19, 'neutral': 32},
#  'count': {'positive': 22, 'negative': 60, 'neutral': 78},
#  'monroe': {'positive': 0, 'negative': 3, 'neutral': 0},
#  '1951': {'positive': 39, 'negative': 17, 'neutral': 25},
#  'armeinan': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'oltetsyan': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'enactments': {'positive': 3, 'negative': 0, 'neutral': 1},
#  'rustamyan': {'positive': 9, 'negative': 15, 'neutral': 59},
#  'bangash': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'compliance': {'positive': 80, 'negative': 117, 'neutral': 304},
#  'mustafayev': {'positive': 15, 'negative': 0, 'neutral': 51},
#  'marginal': {'positive': 1, 'negative': 6, 'neutral': 10},
#  'sassounian': {'positive': 16, 'negative': 54, 'neutral': 61},
#  'progresses': {'positive': 4, 'negative': 0, 'neutral': 4},
#  'giuliani': {'positive': 4, 'negative': 15, 'neutral': 16},
#  'westernregion': {'positive': 4, 'negative': 0, 'neutral': 0},
#  'merkenich': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'halverson': {'positive': 5, 'negative': 0, 'neutral': 4},
#  '10559': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'universally': {'positive': 10, 'negative': 6, 'neutral': 18},
#  'machkalyan': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'competingunionandconfederate': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'timo': {'positive': 1, 'negative': 1, 'neutral': 4},
#  'hepatitis': {'positive': 2, 'negative': 2, 'neutral': 14},
#  'rationing': {'positive': 1, 'negative': 13, 'neutral': 6},
#  'smorgasbord': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'nonito': {'positive': 2, 'negative': 0, 'neutral': 2},
#  'intrigued': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'daghlian': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'irrelevant': {'positive': 0, 'negative': 5, 'neutral': 7},
#  'enokyan': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'walham': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'julfa': {'positive': 4, 'negative': 7, 'neutral': 4},
#  'agosince': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'confirmedtwo': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'theterrible': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'ona': {'positive': 6, 'negative': 1, 'neutral': 11},
#  'resolutions': {'positive': 161, 'negative': 243, 'neutral': 304},
#  'kills': {'positive': 0, 'negative': 9, 'neutral': 9},
#  'andwhy': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'nesides': {'positive': 1, 'negative': 0, 'neutral': 3},
#  'asidein': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'kronos': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'nautical': {'positive': 0, 'negative': 7, 'neutral': 8},
#  'barreling': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'insyria': {'positive': 10, 'negative': 18, 'neutral': 48},
#  'mkhitaryans': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'square': {'positive': 128, 'negative': 123, 'neutral': 198},
#  'pyo': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'sixty': {'positive': 11, 'negative': 5, 'neutral': 15},
#  'paraglider': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'sebastien': {'positive': 0, 'negative': 1, 'neutral': 0},
#  '344481': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'shperov': {'positive': 5, 'negative': 0, 'neutral': 1},
#  'podoliyak': {'positive': 0, 'negative': 0, 'neutral': 11},
#  'use': {'positive': 865, 'negative': 1602, 'neutral': 2242},
#  'jtd': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'sahit': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'valais': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'mccollum': {'positive': 127, 'negative': 2, 'neutral': 7},
#  'zanganeh': {'positive': 14, 'negative': 3, 'neutral': 6},
#  'chaldranyan': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'part': {'positive': 2065, 'negative': 1556, 'neutral': 5935},
#  'matias': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'ag': {'positive': 8, 'negative': 8, 'neutral': 20},
#  'probed': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'enacted': {'positive': 12, 'negative': 14, 'neutral': 21},
#  'mogilevsky': {'positive': 5, 'negative': 0, 'neutral': 3},
#  'cashiers': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'anxiety': {'positive': 6, 'negative': 16, 'neutral': 12},
#  'gafur': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'outlined': {'positive': 73, 'negative': 33, 'neutral': 136},
#  'solvable': {'positive': 4, 'negative': 1, 'neutral': 5},
#  'inspection': {'positive': 28, 'negative': 29, 'neutral': 107},
#  'proposed': {'positive': 305, 'negative': 373, 'neutral': 1079},
#  'saxophonist': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'azarnia': {'positive': 3, 'negative': 0, 'neutral': 0},
#  'launcher': {'positive': 3, 'negative': 36, 'neutral': 19},
#  'compiling': {'positive': 2, 'negative': 2, 'neutral': 7},
#  'wilbur': {'positive': 3, 'negative': 3, 'neutral': 14},
#  'thaci': {'positive': 2, 'negative': 1, 'neutral': 3},
#  'mamikon': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'fugitives': {'positive': 1, 'negative': 2, 'neutral': 5},
#  'turkic': {'positive': 18, 'negative': 71, 'neutral': 56},
#  'foray': {'positive': 4, 'negative': 0, 'neutral': 4},
#  'altos': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'poetry': {'positive': 30, 'negative': 1, 'neutral': 2},
#  'theresa': {'positive': 13, 'negative': 53, 'neutral': 56},
#  'preacher': {'positive': 2, 'negative': 35, 'neutral': 28},
#  'ousted': {'positive': 1, 'negative': 57, 'neutral': 61},
#  'carrying': {'positive': 182, 'negative': 350, 'neutral': 537},
#  'kristalina': {'positive': 1, 'negative': 1, 'neutral': 6},
#  'produces': {'positive': 15, 'negative': 13, 'neutral': 44},
#  'crispness': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'freij': {'positive': 1, 'negative': 0, 'neutral': 11},
#  'identically': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'andthat': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'gorecki': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'trumpon': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'balgina': {'positive': 0, 'negative': 8, 'neutral': 1},
#  'decker': {'positive': 8, 'negative': 0, 'neutral': 1},
#  'hemmati': {'positive': 0, 'negative': 4, 'neutral': 0},
#  'sprayed': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'hormozgān': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'legoyda': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'kreml': {'positive': 2, 'negative': 0, 'neutral': 2},
#  'trampling': {'positive': 0, 'negative': 7, 'neutral': 1},
#  'panning': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'altyntas': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'staving': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'dagestankiye': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'refering': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'gilnegah': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'bazouks': {'positive': 1, 'negative': 2, 'neutral': 0},
#  'xia': {'positive': 0, 'negative': 9, 'neutral': 0},
#  'cowan': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'armeconobank': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'ssrs': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'forterrorism': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'hett': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'vardavar': {'positive': 3, 'negative': 0, 'neutral': 2},
#  'whichtook': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'theodore': {'positive': 4, 'negative': 0, 'neutral': 2},
#  '26689': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'zeleny': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'frustratingly': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'globe': {'positive': 91, 'negative': 64, 'neutral': 78},
#  'ernie': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'eucopresident': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'poured': {'positive': 5, 'negative': 9, 'neutral': 8},
#  'show': {'positive': 543, 'negative': 392, 'neutral': 835},
#  'kovalyov': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'seongju': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'weaponsif': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'maarrat': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'haunt': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'everyday': {'positive': 19, 'negative': 12, 'neutral': 18},
#  'ayda': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'recriminations': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'onthem': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'budak': {'positive': 0, 'negative': 5, 'neutral': 0},
#  'kasaev': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'iger': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'lagusev': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'dinosaur': {'positive': 4, 'negative': 0, 'neutral': 1},
#  'biographic': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'landlocked': {'positive': 12, 'negative': 15, 'neutral': 30},
#  'asbury': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'backlogs': {'positive': 0, 'negative': 3, 'neutral': 0},
#  'iskhanyan': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'faith': {'positive': 91, 'negative': 69, 'neutral': 117},
#  'early': {'positive': 349, 'negative': 563, 'neutral': 1050},
#  'kulikov': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'adıgüzel': {'positive': 2, 'negative': 3, 'neutral': 0},
#  'wintergames': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'rusair': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'jettisoned': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'transporters': {'positive': 0, 'negative': 3, 'neutral': 5},
#  'tarmac': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'generak': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'justices': {'positive': 0, 'negative': 4, 'neutral': 5},
#  'souin': {'positive': 4, 'negative': 0, 'neutral': 1},
#  'kovziridze': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'maafushi': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'twilight': {'positive': 4, 'negative': 0, 'neutral': 7},
#  'semite': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'hoping': {'positive': 33, 'negative': 29, 'neutral': 107},
#  'sanctuary': {'positive': 11, 'negative': 12, 'neutral': 14},
#  'until31july2016': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'arduous': {'positive': 3, 'negative': 0, 'neutral': 2},
#  'inparticular': {'positive': 5, 'negative': 1, 'neutral': 6},
#  'myrdalsjokull': {'positive': 0, 'negative': 0, 'neutral': 1},
#  '8643': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'alawite': {'positive': 0, 'negative': 2, 'neutral': 2},
#  'parsamyan': {'positive': 2, 'negative': 1, 'neutral': 2},
#  'sawa': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'aircraft': {'positive': 197, 'negative': 512, 'neutral': 1080},
#  'dissenters': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'communiqués': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'attributes': {'positive': 11, 'negative': 14, 'neutral': 115},
#  'tank': {'positive': 86, 'negative': 85, 'neutral': 223},
#  '1989': {'positive': 52, 'negative': 41, 'neutral': 85},
#  'sokurov': {'positive': 8, 'negative': 0, 'neutral': 3},
#  'cows': {'positive': 0, 'negative': 0, 'neutral': 2},
#  '16526': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'educator': {'positive': 6, 'negative': 0, 'neutral': 0},
#  'todorkovski': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'afoul': {'positive': 0, 'negative': 7, 'neutral': 6},
#  'docket': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'expanding': {'positive': 432, 'negative': 94, 'neutral': 229},
#  'yehudi': {'positive': 23, 'negative': 0, 'neutral': 0},
#  'germanyof': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'theimport': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'reapplied': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'nazanin': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'maquaponics': {'positive': 1, 'negative': 0, 'neutral': 0},
#  '82804': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'suzdaltsev': {'positive': 2, 'negative': 1, 'neutral': 6},
#  'zardanashen': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'endorsement': {'positive': 37, 'negative': 14, 'neutral': 48},
#  'naomi': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'confidence': {'positive': 608, 'negative': 162, 'neutral': 349},
#  'whenfacebookbought': {'positive': 4, 'negative': 0, 'neutral': 2},
#  'acknowledgement': {'positive': 44, 'negative': 27, 'neutral': 33},
#  'muhl': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'mcdonald': {'positive': 15, 'negative': 5, 'neutral': 16},
#  'avni': {'positive': 0, 'negative': 1, 'neutral': 2},
#  '4695': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'voluble': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'grigoryevich': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'sza': {'positive': 4, 'negative': 0, 'neutral': 0},
#  'caterpillar': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'pushkino': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'unasur': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'yuma': {'positive': 0, 'negative': 0, 'neutral': 6},
#  'kessel': {'positive': 3, 'negative': 0, 'neutral': 1},
#  'stones': {'positive': 40, 'negative': 30, 'neutral': 39},
#  '25815': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'gesellschaft': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'alexandria': {'positive': 9, 'negative': 6, 'neutral': 27},
#  'convinces': {'positive': 3, 'negative': 1, 'neutral': 1},
#  'alleviation': {'positive': 3, 'negative': 2, 'neutral': 2},
#  'kryshchenko': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'yushchenko': {'positive': 0, 'negative': 1, 'neutral': 6},
#  'art': {'positive': 215, 'negative': 39, 'neutral': 145},
#  'reflective': {'positive': 4, 'negative': 2, 'neutral': 13},
#  'devoting': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'azerbajani': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'strutting': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'flyweight': {'positive': 4, 'negative': 0, 'neutral': 2},
#  'republicillegally': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'abbotabad': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'lakesevanis': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'mink': {'positive': 4, 'negative': 2, 'neutral': 4},
#  'diaper': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'manuel': {'positive': 19, 'negative': 15, 'neutral': 41},
#  'caller': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'injirlik': {'positive': 3, 'negative': 3, 'neutral': 3},
#  'ofministryofemergency': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'pithy': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'buffett': {'positive': 11, 'negative': 4, 'neutral': 5},
#  'watkins': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'caribbean': {'positive': 22, 'negative': 18, 'neutral': 42},
#  'clam': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'ivanishin': {'positive': 2, 'negative': 0, 'neutral': 2},
#  'bidder': {'positive': 4, 'negative': 0, 'neutral': 3},
#  'lined': {'positive': 2, 'negative': 5, 'neutral': 6},
#  '2032': {'positive': 5, 'negative': 0, 'neutral': 1},
#  '362342': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'gni': {'positive': 0, 'negative': 3, 'neutral': 2},
#  'generaleric': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'isakov': {'positive': 6, 'negative': 2, 'neutral': 2},
#  'negationist': {'positive': 0, 'negative': 1, 'neutral': 6},
#  '8189': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'combination': {'positive': 31, 'negative': 24, 'neutral': 26},
#  'travelers': {'positive': 57, 'negative': 68, 'neutral': 78},
#  'ցthe': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'carmelo': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'questionnaires': {'positive': 2, 'negative': 0, 'neutral': 6},
#  'yesh': {'positive': 1, 'negative': 3, 'neutral': 5},
#  'sergo': {'positive': 23, 'negative': 1, 'neutral': 11},
#  'rode': {'positive': 3, 'negative': 0, 'neutral': 13},
#  'airliners': {'positive': 2, 'negative': 7, 'neutral': 15},
#  '2flu': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'pits': {'positive': 0, 'negative': 5, 'neutral': 2},
#  'scud': {'positive': 2, 'negative': 5, 'neutral': 1},
#  'colleyville': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'lawmaker': {'positive': 72, 'negative': 127, 'neutral': 246},
#  'e': {'positive': 37, 'negative': 15, 'neutral': 42},
#  'cohen': {'positive': 61, 'negative': 20, 'neutral': 27},
#  'solomon': {'positive': 7, 'negative': 16, 'neutral': 31},
#  'portions': {'positive': 3, 'negative': 9, 'neutral': 8},
#  'aversion': {'positive': 0, 'negative': 8, 'neutral': 1},
#  'ringing': {'positive': 4, 'negative': 1, 'neutral': 1},
#  'retroactive': {'positive': 3, 'negative': 1, 'neutral': 4},
#  'clientelism': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'squarelyacknowledgedthe': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'drums': {'positive': 10, 'negative': 3, 'neutral': 2},
#  'gishyan': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'byturkey': {'positive': 0, 'negative': 1, 'neutral': 7},
#  'ventilator': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'aiib': {'positive': 8, 'negative': 4, 'neutral': 4},
#  'newson': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'dik': {'positive': 0, 'negative': 0, 'neutral': 2},
#  '650bn': {'positive': 0, 'negative': 0, 'neutral': 2},
#  '29506': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'abouthow': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'damien': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'earns': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'muskoka': {'positive': 7, 'negative': 14, 'neutral': 34},
#  'transgender': {'positive': 5, 'negative': 5, 'neutral': 8},
#  'zhomart': {'positive': 2, 'negative': 0, 'neutral': 8},
#  'adriana': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'seventy': {'positive': 6, 'negative': 2, 'neutral': 15},
#  '5m': {'positive': 2, 'negative': 2, 'neutral': 7},
#  'disliked': {'positive': 0, 'negative': 1, 'neutral': 4},
#  'conference': {'positive': 2024, 'negative': 683, 'neutral': 3395},
#  'clicked': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'tbilistsi': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'adhanom': {'positive': 2, 'negative': 1, 'neutral': 6},
#  'lenkaran': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'inexpedient': {'positive': 0, 'negative': 4, 'neutral': 5},
#  'knol': {'positive': 2, 'negative': 0, 'neutral': 3},
#  'fikret': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'onjuly': {'positive': 5, 'negative': 0, 'neutral': 12},
#  'kore': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'approximately': {'positive': 39, 'negative': 37, 'neutral': 86},
#  'kahramanmaras': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'aparaj': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'russiansecurity': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'mkoyan': {'positive': 5, 'negative': 0, 'neutral': 17},
#  'roberto': {'positive': 4, 'negative': 4, 'neutral': 8},
#  'flyone': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'vazil': {'positive': 3, 'negative': 0, 'neutral': 3},
#  '524': {'positive': 0, 'negative': 4, 'neutral': 0},
#  'ever': {'positive': 380, 'negative': 257, 'neutral': 385},
#  'sinopec': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'magomedov': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'rubbles': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'rafah': {'positive': 4, 'negative': 2, 'neutral': 2},
#  'treat': {'positive': 47, 'negative': 44, 'neutral': 90},
#  'computers': {'positive': 9, 'negative': 33, 'neutral': 26},
#  'brittany': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'incorporate': {'positive': 3, 'negative': 3, 'neutral': 7},
#  'announcements': {'positive': 18, 'negative': 37, 'neutral': 62},
#  'spurning': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'ensured': {'positive': 81, 'negative': 15, 'neutral': 99},
#  'opportunityin': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'stairs': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'liloyan': {'positive': 1, 'negative': 0, 'neutral': 8},
#  'dpa': {'positive': 1, 'negative': 16, 'neutral': 25},
#  'pandemics': {'positive': 2, 'negative': 4, 'neutral': 1},
#  'arisen': {'positive': 7, 'negative': 12, 'neutral': 19},
#  'empress': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'elkus': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'heartening': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'theco': {'positive': 1, 'negative': 1, 'neutral': 8},
#  'cashing': {'positive': 0, 'negative': 6, 'neutral': 3},
#  '484': {'positive': 2, 'negative': 1, 'neutral': 2},
#  'insuring': {'positive': 0, 'negative': 4, 'neutral': 4},
#  'phonethons': {'positive': 0, 'negative': 0, 'neutral': 5},
#  'briquettes': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'bortnikov': {'positive': 7, 'negative': 12, 'neutral': 51},
#  'belligerent': {'positive': 18, 'negative': 92, 'neutral': 39},
#  'latrines': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'topromote': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'coopting': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'foundationcongratulates': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'sekeroglu': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'sakha': {'positive': 0, 'negative': 2, 'neutral': 2},
#  '78609': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'dehloran': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'squaring': {'positive': 0, 'negative': 0, 'neutral': 6},
#  'frontier': {'positive': 23, 'negative': 46, 'neutral': 86},
#  'fortified': {'positive': 2, 'negative': 10, 'neutral': 10},
#  'screening': {'positive': 40, 'negative': 25, 'neutral': 56},
#  'innokenty': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'stepson': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'forinspiration': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'homs': {'positive': 4, 'negative': 31, 'neutral': 48},
#  'sighed': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'circumstantial': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'toestablish': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'gases': {'positive': 2, 'negative': 3, 'neutral': 0},
#  'restrictionsof': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'debases': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'mod': {'positive': 70, 'negative': 56, 'neutral': 160},
#  'tovmasyan': {'positive': 25, 'negative': 12, 'neutral': 56},
#  '64621': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'unintegrated': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'mourchidates': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'artsakhian': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'sweeping': {'positive': 10, 'negative': 20, 'neutral': 28},
#  'brings': {'positive': 104, 'negative': 45, 'neutral': 60},
#  'juggernaut': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'plods': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'juris': {'positive': 2, 'negative': 0, 'neutral': 1},
#  'artier': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'assessment': {'positive': 157, 'negative': 146, 'neutral': 399},
#  'turashvili': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'fined': {'positive': 2, 'negative': 34, 'neutral': 27},
#  'newswalk': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'boyne': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'denazification': {'positive': 0, 'negative': 5, 'neutral': 2},
#  'ashotsk': {'positive': 5, 'negative': 0, 'neutral': 1},
#  'inpraguein': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'avakov': {'positive': 0, 'negative': 5, 'neutral': 7},
#  'outmaneuvered': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'precipice': {'positive': 0, 'negative': 7, 'neutral': 2},
#  'esail': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'altidore': {'positive': 1, 'negative': 0, 'neutral': 1},
#  '4thround': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'spongiform': {'positive': 0, 'negative': 0, 'neutral': 1},
#  '834': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'toponym': {'positive': 1, 'negative': 0, 'neutral': 4},
#  '007': {'positive': 2, 'negative': 0, 'neutral': 9},
#  'celik': {'positive': 2, 'negative': 5, 'neutral': 6},
#  'charts': {'positive': 6, 'negative': 0, 'neutral': 3},
#  'ascendant': {'positive': 1, 'negative': 3, 'neutral': 0},
#  'policy': {'positive': 1402, 'negative': 2016, 'neutral': 3274},
#  'guantánamo': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'stéphane': {'positive': 89, 'negative': 7, 'neutral': 278},
#  'unem': {'positive': 0, 'negative': 3, 'neutral': 2},
#  'dignitary': {'positive': 1, 'negative': 0, 'neutral': 4},
#  'resets': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'bayer': {'positive': 2, 'negative': 0, 'neutral': 8},
#  'sega': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'health': {'positive': 564, 'negative': 421, 'neutral': 640},
#  'broadening': {'positive': 17, 'negative': 6, 'neutral': 7},
#  'petrochina': {'positive': 0, 'negative': 0, 'neutral': 4},
#  'classics': {'positive': 6, 'negative': 0, 'neutral': 0},
#  'informally': {'positive': 1, 'negative': 1, 'neutral': 8},
#  'evgeniya': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'presence': {'positive': 622, 'negative': 784, 'neutral': 1390},
#  'kursat': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'employer': {'positive': 5, 'negative': 4, 'neutral': 8},
#  'exile': {'positive': 15, 'negative': 33, 'neutral': 21},
#  'sour': {'positive': 1, 'negative': 8, 'neutral': 4},
#  'nikel': {'positive': 0, 'negative': 8, 'neutral': 1},
#  'superstition': {'positive': 0, 'negative': 3, 'neutral': 2},
#  'tether': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'furesenko': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'unconstrained': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'hijacking': {'positive': 0, 'negative': 6, 'neutral': 0},
#  'consisted': {'positive': 5, 'negative': 8, 'neutral': 27},
#  'triumfalnaya': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'greatly': {'positive': 154, 'negative': 49, 'neutral': 114},
#  'nyzhnyk': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'intruders': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'abarahamyan': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'mahari': {'positive': 3, 'negative': 0, 'neutral': 1},
#  'tampered': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'deplorable': {'positive': 1, 'negative': 26, 'neutral': 7},
#  'tuva': {'positive': 4, 'negative': 0, 'neutral': 0},
#  'gastarbeiters': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'rd': {'positive': 24, 'negative': 5, 'neutral': 24},
#  'sharkey': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'simmons': {'positive': 2, 'negative': 0, 'neutral': 8},
#  'gym': {'positive': 8, 'negative': 0, 'neutral': 2},
#  'legitimacy': {'positive': 24, 'negative': 71, 'neutral': 60},
#  'chapman': {'positive': 15, 'negative': 3, 'neutral': 38},
#  'locales': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'klingbeil': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'reconfiguration': {'positive': 1, 'negative': 1, 'neutral': 5},
#  'eucom': {'positive': 8, 'negative': 0, 'neutral': 3},
#  'travelling': {'positive': 26, 'negative': 39, 'neutral': 79},
#  'increasing': {'positive': 420, 'negative': 408, 'neutral': 498},
#  'ab': {'positive': 28, 'negative': 1, 'neutral': 18},
#  'vitality': {'positive': 16, 'negative': 5, 'neutral': 9},
#  'countrywoman': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'monetization': {'positive': 0, 'negative': 8, 'neutral': 2},
#  '1450': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'cincinnati': {'positive': 2, 'negative': 3, 'neutral': 1},
#  'lukasz': {'positive': 12, 'negative': 0, 'neutral': 8},
#  'honoered': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'hospitalized': {'positive': 12, 'negative': 97, 'neutral': 105},
#  'completing': {'positive': 50, 'negative': 20, 'neutral': 56},
#  'joviality': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'spike': {'positive': 1, 'negative': 15, 'neutral': 4},
#  'troupe': {'positive': 3, 'negative': 0, 'neutral': 0},
#  'frostbite': {'positive': 0, 'negative': 5, 'neutral': 1},
#  'tissue': {'positive': 3, 'negative': 1, 'neutral': 4},
#  'overtake': {'positive': 12, 'negative': 9, 'neutral': 17},
#  'magnum': {'positive': 21, 'negative': 0, 'neutral': 0},
#  'badges': {'positive': 3, 'negative': 2, 'neutral': 2},
#  'sasiwat': {'positive': 1, 'negative': 0, 'neutral': 3},
#  'villegas': {'positive': 18, 'negative': 2, 'neutral': 7},
#  'illusion': {'positive': 1, 'negative': 17, 'neutral': 17},
#  'obsessive': {'positive': 0, 'negative': 3, 'neutral': 2},
#  'stoltenbergduring': {'positive': 3, 'negative': 0, 'neutral': 1},
#  'cité': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'caixin': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'tutte': {'positive': 2, 'negative': 0, 'neutral': 2},
#  'refinement': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'pyrotechnicians': {'positive': 5, 'negative': 0, 'neutral': 5},
#  'wilkins': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'alien': {'positive': 9, 'negative': 5, 'neutral': 3},
#  'uboweja': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'presidentdonald': {'positive': 1, 'negative': 3, 'neutral': 1},
#  'gigafactory': {'positive': 4, 'negative': 0, 'neutral': 0},
#  'automat': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'peninsula': {'positive': 86, 'negative': 199, 'neutral': 308},
#  'pisheh': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'ssm': {'positive': 0, 'negative': 1, 'neutral': 3},
#  'gavan': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'causes': {'positive': 57, 'negative': 94, 'neutral': 123},
#  'toderail': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'telegrams': {'positive': 3, 'negative': 2, 'neutral': 2},
#  'asala': {'positive': 0, 'negative': 1, 'neutral': 4},
#  'jetting': {'positive': 0, 'negative': 0, 'neutral': 3},
#  '10340': {'positive': 0, 'negative': 6, 'neutral': 0},
#  'accounting': {'positive': 40, 'negative': 28, 'neutral': 34},
#  'lago': {'positive': 1, 'negative': 2, 'neutral': 4},
#  'intoforce': {'positive': 2, 'negative': 0, 'neutral': 2},
#  'macfarlaine': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'candies': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'omissions': {'positive': 4, 'negative': 6, 'neutral': 4},
#  'treatywith': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'viva': {'positive': 3, 'negative': 0, 'neutral': 3},
#  'ttj10': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'andtransport': {'positive': 2, 'negative': 0, 'neutral': 2},
#  'persisting': {'positive': 3, 'negative': 1, 'neutral': 4},
#  'peacceful': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'reich': {'positive': 0, 'negative': 3, 'neutral': 2},
#  'investment': {'positive': 1079, 'negative': 199, 'neutral': 582},
#  '23rd': {'positive': 56, 'negative': 10, 'neutral': 40},
#  'rongcheng': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'cransodar': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'cardinal': {'positive': 5, 'negative': 0, 'neutral': 11},
#  'swimmer': {'positive': 4, 'negative': 0, 'neutral': 4},
#  'kafrnaha': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'rosiyskaya': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'ipad': {'positive': 19, 'negative': 11, 'neutral': 19},
#  'sarkisov': {'positive': 31, 'negative': 0, 'neutral': 36},
#  'liners': {'positive': 1, 'negative': 2, 'neutral': 6},
#  'pediatric': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'uncertainties': {'positive': 8, 'negative': 37, 'neutral': 45},
#  'decedents': {'positive': 2, 'negative': 2, 'neutral': 0},
#  'nikolov': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'cica': {'positive': 2, 'negative': 0, 'neutral': 4},
#  'creatures': {'positive': 4, 'negative': 0, 'neutral': 2},
#  'mammadyraov': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'assistant': {'positive': 529, 'negative': 116, 'neutral': 800},
#  'serbians': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'armacad': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'inmonday': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'harmonious': {'positive': 3, 'negative': 0, 'neutral': 0},
#  'devésa': {'positive': 2, 'negative': 0, 'neutral': 0},
#  '370': {'positive': 3, 'negative': 4, 'neutral': 6},
#  'rostvertol': {'positive': 1, 'negative': 0, 'neutral': 10},
#  'pocket': {'positive': 1, 'negative': 10, 'neutral': 4},
#  'redford': {'positive': 2, 'negative': 0, 'neutral': 0},
#  'sublimate': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'husbands': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'chicken': {'positive': 2, 'negative': 3, 'neutral': 1},
#  '14456': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'correct': {'positive': 22, 'negative': 27, 'neutral': 70},
#  'kovelenko': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'footholds': {'positive': 1, 'negative': 0, 'neutral': 4},
#  'which26': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'indebtedness': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'ozkan': {'positive': 0, 'negative': 0, 'neutral': 5},
#  'eapfrogging': {'positive': 1, 'negative': 1, 'neutral': 0},
#  'elder': {'positive': 10, 'negative': 9, 'neutral': 43},
#  'theregional': {'positive': 3, 'negative': 0, 'neutral': 0},
#  'jonhuntsman': {'positive': 3, 'negative': 0, 'neutral': 2},
#  'vartkes': {'positive': 6, 'negative': 3, 'neutral': 3},
#  'manhattan': {'positive': 10, 'negative': 13, 'neutral': 19},
#  'bach': {'positive': 9, 'negative': 5, 'neutral': 10},
#  'hotline': {'positive': 4, 'negative': 7, 'neutral': 9},
#  'linchpin': {'positive': 0, 'negative': 2, 'neutral': 3},
#  'replied': {'positive': 16, 'negative': 48, 'neutral': 85},
#  'sation': {'positive': 0, 'negative': 2, 'neutral': 0},
#  'firsty': {'positive': 0, 'negative': 0, 'neutral': 5},
#  'presents': {'positive': 132, 'negative': 99, 'neutral': 936},
#  '18077': {'positive': 0, 'negative': 2, 'neutral': 6},
#  'nikolay': {'positive': 163, 'negative': 30, 'neutral': 232},
#  'cloudless': {'positive': 0, 'negative': 0, 'neutral': 3},
#  'withnorth': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'restraints': {'positive': 0, 'negative': 5, 'neutral': 2},
#  'kilicdaroglu': {'positive': 1, 'negative': 2, 'neutral': 1},
#  'overheating': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'khalaf': {'positive': 0, 'negative': 2, 'neutral': 8},
#  'annexes': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'freeze': {'positive': 22, 'negative': 77, 'neutral': 94},
#  'instigated': {'positive': 2, 'negative': 25, 'neutral': 13},
#  'ap': {'positive': 86, 'negative': 211, 'neutral': 271},
#  '1899': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'avtandil': {'positive': 0, 'negative': 1, 'neutral': 1},
#  'galmarini': {'positive': 1, 'negative': 0, 'neutral': 0},
#  'drastic': {'positive': 8, 'negative': 31, 'neutral': 39},
#  'lagrange': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'itsfiscal': {'positive': 4, 'negative': 0, 'neutral': 2},
#  'doped': {'positive': 0, 'negative': 3, 'neutral': 1},
#  'bushy': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'pluralistic': {'positive': 3, 'negative': 2, 'neutral': 1},
#  'generations': {'positive': 72, 'negative': 18, 'neutral': 41},
#  'failingnew': {'positive': 0, 'negative': 3, 'neutral': 0},
#  'submersibles': {'positive': 0, 'negative': 2, 'neutral': 6},
#  'gogol': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'koka': {'positive': 0, 'negative': 0, 'neutral': 5},
#  'burgeoning': {'positive': 2, 'negative': 6, 'neutral': 3},
#  'throes': {'positive': 1, 'negative': 3, 'neutral': 0},
#  'cursor': {'positive': 0, 'negative': 3, 'neutral': 1},
#  'melts': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'moralityand': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'smokey': {'positive': 1, 'negative': 0, 'neutral': 4},
#  '42000': {'positive': 1, 'negative': 0, 'neutral': 1},
#  'calling': {'positive': 602, 'negative': 757, 'neutral': 931},
#  'aiming': {'positive': 91, 'negative': 42, 'neutral': 103},
#  'segments': {'positive': 10, 'negative': 6, 'neutral': 16},
#  'waned': {'positive': 1, 'negative': 2, 'neutral': 2},
#  'absorber': {'positive': 0, 'negative': 1, 'neutral': 2},
#  'groundlessness': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'dynamic': {'positive': 125, 'negative': 12, 'neutral': 52},
#  'bydmitry': {'positive': 7, 'negative': 0, 'neutral': 0},
#  'infirmary': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'programmed': {'positive': 1, 'negative': 0, 'neutral': 2},
#  'camera': {'positive': 15, 'negative': 8, 'neutral': 16},
#  'mmr': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'needy': {'positive': 22, 'negative': 2, 'neutral': 10},
#  'darkest': {'positive': 6, 'negative': 12, 'neutral': 7},
#  'subtlety': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'uiyanov': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'unfavorably': {'positive': 0, 'negative': 15, 'neutral': 2},
#  'valuables': {'positive': 1, 'negative': 2, 'neutral': 0},
#  'ceases': {'positive': 4, 'negative': 8, 'neutral': 5},
#  'assassinating': {'positive': 0, 'negative': 3, 'neutral': 2},
#  'tripling': {'positive': 0, 'negative': 2, 'neutral': 0},
#  '18435096': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'kolerov': {'positive': 4, 'negative': 23, 'neutral': 47},
#  'lester': {'positive': 2, 'negative': 0, 'neutral': 0},
#  '9249': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'fatalities': {'positive': 1, 'negative': 105, 'neutral': 24},
#  'pitch': {'positive': 7, 'negative': 8, 'neutral': 8},
#  'madzhumder': {'positive': 0, 'negative': 0, 'neutral': 1},
#  'claus': {'positive': 2, 'negative': 3, 'neutral': 4},
#  'outside': {'positive': 173, 'negative': 416, 'neutral': 541},
#  'porter': {'positive': 9, 'negative': 28, 'neutral': 12},
#  'distracting': {'positive': 2, 'negative': 3, 'neutral': 9},
#  'lvova': {'positive': 0, 'negative': 3, 'neutral': 5},
#  'guenter': {'positive': 0, 'negative': 2, 'neutral': 1},
#  'flats': {'positive': 5, 'negative': 2, 'neutral': 1},
#  'sial': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'inistry': {'positive': 0, 'negative': 1, 'neutral': 0},
#  'news': {'positive': 4991, 'negative': 3251, 'neutral': 12368},
#  'oncological': {'positive': 0, 'negative': 0, 'neutral': 2},
#  'goals': {'positive': 284, 'negative': 117, 'neutral': 259},
#  ...}

# %%
df_feedback
# Out:
#                      time                                           feedback  \
# 0     2009-06-08 00:00:00  {'entities': [{'name': 'Serzh Sargsyan', 'sent...
# 1     2009-06-08 00:00:00  {'entities': [{'name': 'David Hakhverdyan', 's...
# 2     2009-06-04 00:00:00  {'entities': [{'name': 'World Bank', 'sentimen...
# 3     2008-12-30 00:00:00  {'entities': [{'name': 'CoE Congress of Local ...
# 4     2009-06-01 00:00:00  {'entities': [{'name': 'Matthew Bryza', 'senti...
# ...                   ...                                                ...
# 84103 2022-01-20 13:03:00  {'entities': [{'name': 'EBRD', 'sentiment': 'p...
# 84114 2022-03-10 16:40:00  {'entities': [{'name': 'Dmytro Kuleba', 'senti...
# 84204 2022-11-17 13:23:00  {'entities': [{'name': 'Philip Reeker', 'senti...
# 84216 2022-12-13 13:48:00  {'entities': [{'name': 'Arayik Harutyunyan', '...
# 84376 2023-11-23 15:16:00  {'entities': [{'name': 'Yershova', 'sentiment'...
#
#                                                  content
# 0      YEREVAN, JUNE 9, ARMENPRESS:Armenian President...
# 1      YEREVAN, JUNE 9, ARMENPRESS:Director of the Co...
# 2      YEREVAN, JUNE 5, ARMENPRESS:The credit agreeme...
# 3      YEREVAN, JUNE 1, ARMENPRESS:The observing miss...
# 4      BAKU, JUNE 1, ARMENPRESS:OSCE Minsk group is o...
# ...                                                  ...
# 84103  The European Bank for Reconstruction and Devel...
# 84114  Ukrainian Foreign Minister Dmytro Kuleba says ...
# 84204  U.S. Secretary of State's adviser on Caucasus ...
# 84216  On December 13, President of the Artsakh Repub...
# 84376  At the beginning of November, Tert.am reported...
#
# [36610 rows x 3 columns]

# %%
# def predict(content, entity_names)

out = []

for i, row in tqdm(df_feedback.iterrows()):
    article_sents = {}
    for ent in row.feedback["entities"]:
        if any([k not in ent for k in ["name", "sentiment"]]):
            continue

        name = ent["name"].lower()
        actual_sentiment = ent["sentiment"].lower()

        article_sentences = list(chain.from_iterable(
            [partition.split(".") for partition in row.content.lower().split(":")]
        ))
        article_sentences = [s.replace(",", "").lower() for s in article_sentences]
        
        # selecting relevant sentences
        relevant_sentances = [
            sent
            for sent
            in article_sentences
            if name in sent
        ]

        # Splitting into words
        relevant_words = list(
            chain.from_iterable(
                [re.findall(r"\w+", sent) for sent in relevant_sentances]
            )
        )

        # filtering stopwords and entity names
        relevant_words = [
            w for w in relevant_words
            if (w not in english_stopwords) and (
                w not in name
            )
        ]

        counts = [Counter(term_sentiment[w]) for w in relevant_words if w in term_sentiment]
        counter = Counter()
        for count in counts:
            counter += count
        
        article_sents[name] = counter
    out.append(article_sents)
# Out:
# 0it [00:00, ?it/s]
# 36610it [01:08, 536.25it/s]

# %%
df_feedback = df_feedback.copy()
df_feedback["predictions_raw"] = out
df_feedback
# Out:
#                      time                                           feedback  \
# 0     2009-06-08 00:00:00  {'entities': [{'name': 'Serzh Sargsyan', 'sent...
# 1     2009-06-08 00:00:00  {'entities': [{'name': 'David Hakhverdyan', 's...
# 2     2009-06-04 00:00:00  {'entities': [{'name': 'World Bank', 'sentimen...
# 3     2008-12-30 00:00:00  {'entities': [{'name': 'CoE Congress of Local ...
# 4     2009-06-01 00:00:00  {'entities': [{'name': 'Matthew Bryza', 'senti...
# ...                   ...                                                ...
# 84103 2022-01-20 13:03:00  {'entities': [{'name': 'EBRD', 'sentiment': 'p...
# 84114 2022-03-10 16:40:00  {'entities': [{'name': 'Dmytro Kuleba', 'senti...
# 84204 2022-11-17 13:23:00  {'entities': [{'name': 'Philip Reeker', 'senti...
# 84216 2022-12-13 13:48:00  {'entities': [{'name': 'Arayik Harutyunyan', '...
# 84376 2023-11-23 15:16:00  {'entities': [{'name': 'Yershova', 'sentiment'...
#
#                                                  content  \
# 0      YEREVAN, JUNE 9, ARMENPRESS:Armenian President...
# 1      YEREVAN, JUNE 9, ARMENPRESS:Director of the Co...
# 2      YEREVAN, JUNE 5, ARMENPRESS:The credit agreeme...
# 3      YEREVAN, JUNE 1, ARMENPRESS:The observing miss...
# 4      BAKU, JUNE 1, ARMENPRESS:OSCE Minsk group is o...
# ...                                                  ...
# 84103  The European Bank for Reconstruction and Devel...
# 84114  Ukrainian Foreign Minister Dmytro Kuleba says ...
# 84204  U.S. Secretary of State's adviser on Caucasus ...
# 84216  On December 13, President of the Artsakh Repub...
# 84376  At the beginning of November, Tert.am reported...
#
#                                          predictions_raw
# 0      {'serzh sargsyan': {'positive': 151383, 'negat...
# 1      {'david hakhverdyan': {'positive': 118572, 'ne...
# 2      {'world bank': {'positive': 46029, 'negative':...
# 3      {'coe congress of local and regional authoriti...
# 4      {'matthew bryza': {'positive': 66399, 'negativ...
# ...                                                  ...
# 84103  {'ebrd': {'positive': 231898, 'negative': 1515...
# 84114  {'dmytro kuleba': {'positive': 80926, 'negativ...
# 84204  {'philip reeker': {'positive': 86325, 'negativ...
# 84216  {'arayik harutyunyan': {'positive': 31357, 'ne...
# 84376  {'yershova': {'positive': 28165, 'negative': 3...
#
# [36610 rows x 4 columns]

# %%
(pred_tuples := df_feedback.apply(lambda x: [x.predictions_raw[ent["name"].lower()] for ent in x.feedback["entities"] if ("name" in ent) and ("sentiment" in ent)], axis=1))
# Out:
# 0        [{'positive': 151383, 'negative': 79200, 'neut...
# 1        [{'positive': 118572, 'negative': 57729, 'neut...
# 2        [{'positive': 46029, 'negative': 20284, 'neutr...
# 3        [{'positive': 20142, 'negative': 11838, 'neutr...
# 4        [{'positive': 66399, 'negative': 39051, 'neutr...
#                                ...
# 84103    [{'positive': 231898, 'negative': 151592, 'neu...
# 84114    [{'positive': 80926, 'negative': 57119, 'neutr...
# 84204    [{'positive': 86325, 'negative': 61237, 'neutr...
# 84216    [{'positive': 31357, 'negative': 21230, 'neutr...
# 84376    [{'positive': 28165, 'negative': 30966, 'neutr...
# Length: 36610, dtype: object

# %%
pred_tuples.iloc[0]
# Out:
# [Counter({'neutral': 235799, 'positive': 151383, 'negative': 79200}),
#  Counter({'neutral': 261583, 'positive': 168584, 'negative': 80362}),
#  Counter({'neutral': 130661, 'positive': 87477, 'negative': 38540}),
#  Counter({'neutral': 338797, 'positive': 233735, 'negative': 105654}),
#  Counter({'neutral': 129424, 'positive': 83159, 'negative': 42867}),
#  Counter({'neutral': 161330, 'positive': 113752, 'negative': 50056}),
#  Counter({'neutral': 89991, 'positive': 48603, 'negative': 26690})]

# %%
naive_method = pred_tuples.apply(lambda row: [ent.most_common(1)[0][0] if len(ent.most_common(1)) else None for ent in row])
df_feedback["naive_method"] = naive_method
df_feedback["naive_accuracy"] = df_feedback.apply(
    lambda row: np.sum(
        [
            (row.feedback["entities"][i]["sentiment"].lower() == row.naive_method[i])
            if ("entities" in row.feedback) and ("sentiment" in row.feedback["entities"][i])
            else False for i in range(len(row.naive_method))
        ]) / len(row.naive_method)
    , axis=1
)
# Out:
# C:\Users\mherm\AppData\Local\Temp\ipykernel_7932\1470111273.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   lambda row: np.sum(

# %%
df_feedback.naive_accuracy.mean()
# Out:
# 0.5092995121201346

# %%
total_sentiments = Counter()
for term, counts in term_sentiment.items():
    total_sentiments += counts

total_sentiments
# Out:
# Counter({'neutral': 3789399, 'positive': 1910713, 'negative': 1663099})

# %%
df_feedback["weighted_method"] = pred_tuples.apply(lambda row: [
    ["positive", "negative", "neutral"][np.argmax([
        int(ent["positive"]*730 / total_sentiments["positive"]),
        int(ent["negative"]*730 / total_sentiments["negative"]),
        int(ent["neutral"]*1000 / total_sentiments["neutral"])
    ])] for ent in row
]) 

df_feedback["weighted_accuracy"] = df_feedback.apply(
    lambda row: np.sum(
        [
            (row.feedback["entities"][i]["sentiment"].lower() == row.weighted_method[i])
            if ("entities" in row.feedback) and ("sentiment" in row.feedback["entities"][i])
            else False for i in range(len(row.weighted_method))
        ]) / len(row.weighted_method)
    , axis=1
)

df_feedback
# Out:
# C:\Users\mherm\AppData\Local\Temp\ipykernel_7932\2957623647.py:10: RuntimeWarning: invalid value encountered in scalar divide
#   lambda row: np.sum(
#                      time                                           feedback  \
# 0     2009-06-08 00:00:00  {'entities': [{'name': 'Serzh Sargsyan', 'sent...
# 1     2009-06-08 00:00:00  {'entities': [{'name': 'David Hakhverdyan', 's...
# 2     2009-06-04 00:00:00  {'entities': [{'name': 'World Bank', 'sentimen...
# 3     2008-12-30 00:00:00  {'entities': [{'name': 'CoE Congress of Local ...
# 4     2009-06-01 00:00:00  {'entities': [{'name': 'Matthew Bryza', 'senti...
# ...                   ...                                                ...
# 84103 2022-01-20 13:03:00  {'entities': [{'name': 'EBRD', 'sentiment': 'p...
# 84114 2022-03-10 16:40:00  {'entities': [{'name': 'Dmytro Kuleba', 'senti...
# 84204 2022-11-17 13:23:00  {'entities': [{'name': 'Philip Reeker', 'senti...
# 84216 2022-12-13 13:48:00  {'entities': [{'name': 'Arayik Harutyunyan', '...
# 84376 2023-11-23 15:16:00  {'entities': [{'name': 'Yershova', 'sentiment'...
#
#                                                  content  \
# 0      YEREVAN, JUNE 9, ARMENPRESS:Armenian President...
# 1      YEREVAN, JUNE 9, ARMENPRESS:Director of the Co...
# 2      YEREVAN, JUNE 5, ARMENPRESS:The credit agreeme...
# 3      YEREVAN, JUNE 1, ARMENPRESS:The observing miss...
# 4      BAKU, JUNE 1, ARMENPRESS:OSCE Minsk group is o...
# ...                                                  ...
# 84103  The European Bank for Reconstruction and Devel...
# 84114  Ukrainian Foreign Minister Dmytro Kuleba says ...
# 84204  U.S. Secretary of State's adviser on Caucasus ...
# 84216  On December 13, President of the Artsakh Repub...
# 84376  At the beginning of November, Tert.am reported...
#
#                                          predictions_raw  \
# 0      {'serzh sargsyan': {'positive': 151383, 'negat...
# 1      {'david hakhverdyan': {'positive': 118572, 'ne...
# 2      {'world bank': {'positive': 46029, 'negative':...
# 3      {'coe congress of local and regional authoriti...
# 4      {'matthew bryza': {'positive': 66399, 'negativ...
# ...                                                  ...
# 84103  {'ebrd': {'positive': 231898, 'negative': 1515...
# 84114  {'dmytro kuleba': {'positive': 80926, 'negativ...
# 84204  {'philip reeker': {'positive': 86325, 'negativ...
# 84216  {'arayik harutyunyan': {'positive': 31357, 'ne...
# 84376  {'yershova': {'positive': 28165, 'negative': 3...
#
#                                             naive_method  naive_accuracy  \
# 0      [neutral, neutral, neutral, neutral, neutral, ...        0.571429
# 1             [neutral, neutral, None, neutral, neutral]        0.200000
# 2      [neutral, neutral, neutral, neutral, neutral, ...        0.117647
# 3      [neutral, neutral, neutral, neutral, neutral, ...        0.076923
# 4                      [neutral, neutral, None, neutral]        0.250000
# ...                                                  ...             ...
# 84103  [neutral, neutral, neutral, None, neutral, neu...        0.000000
# 84114               [neutral, neutral, neutral, neutral]        0.500000
# 84204  [neutral, neutral, neutral, neutral, neutral, ...        0.300000
# 84216               [neutral, neutral, neutral, neutral]        0.750000
# 84376                                    [neutral, None]        0.000000
#
#                                          weighted_method  weighted_accuracy
# 0      [neutral, neutral, neutral, positive, neutral,...           0.571429
# 1        [neutral, neutral, positive, positive, neutral]           0.400000
# 2      [positive, positive, neutral, neutral, positiv...           0.588235
# 3      [neutral, neutral, neutral, neutral, neutral, ...           0.076923
# 4                  [neutral, neutral, positive, neutral]           0.250000
# ...                                                  ...                ...
# 84103  [neutral, neutral, positive, positive, neutral...           0.428571
# 84114               [neutral, neutral, neutral, neutral]           0.500000
# 84204  [neutral, neutral, neutral, neutral, neutral, ...           0.300000
# 84216               [neutral, neutral, neutral, neutral]           0.750000
# 84376                                [neutral, positive]           0.000000
#
# [36610 rows x 8 columns]

# %%
df_feedback.weighted_accuracy.mean()
# Out:
# 0.5308964166340528

# %% [markdown]
# ### Estimating sentiment for all articles

# %%
(entity_names := pd.read_pickle(Path("cache") / "top_10k_names.series.pkl").iloc[:500])
# Out:
# 0                         russia
# 1                        armenia
# 2                  united states
# 3                     azerbaijan
# 4                         turkey
#                  ...
# 495    president bashar al-assad
# 496             russian language
# 497                    krasnodar
# 498              serzh sarkisian
# 499             shakhtar donetsk
# Length: 500, dtype: object

# %%
df.content = df.content.str.lower()
df["pred"] = [(lambda x: [])(_) for _ in range(len(df))]

# %%
df
# Out:
#                      time                                           feedback  \
# 0     2009-06-08 00:00:00  {\n  "entities": [\n    {\n      "name": "Serz...
# 1     2009-06-08 00:00:00  {\n  "entities": [\n    {\n      "name": "Davi...
# 2     2009-06-04 00:00:00  {"entities": [\n  {"name": "World Bank", "sent...
# 3     2008-12-30 00:00:00  {\n  "entities": [\n    {"name": "CoE Congress...
# 4     2009-06-01 00:00:00  {\n  "entities": [\n    {\n      "name": "Matt...
# ...                   ...                                                ...
# 84375 2023-11-20 18:58:00                                               None
# 84376 2023-11-23 15:16:00  {\n  "entities": [\n    {\n      "name": "Yers...
# 84377 2023-11-24 21:44:00                                               None
# 84378 2023-11-24 16:00:00                                               None
# 84379 2023-11-24 14:50:00                                               None
#
#                                                  content pred
# 0      yerevan, june 9, armenpress:armenian president...   []
# 1      yerevan, june 9, armenpress:director of the co...   []
# 2      yerevan, june 5, armenpress:the credit agreeme...   []
# 3      yerevan, june 1, armenpress:the observing miss...   []
# 4      baku, june 1, armenpress:osce minsk group is o...   []
# ...                                                  ...  ...
# 84375  ucom now offers the fastest home internet and ...   []
# 84376  at the beginning of november, tert.am reported...   []
# 84377  yesterday tert.am  wrote  that the zangezur co...   []
# 84378  after the coronavirus and the war situation, t...   []
# 84379  within the “black friday” promotion the most a...   []
#
# [447920 rows x 4 columns]

# %%
total_found = Counter()

for i, content in enumerate(df.content.to_list()):
    if (i % 100) == 0:
        print(str(total_found) + f"  {i}/{len(df)}", end="\r")
    entities = [
        ent for ent in entity_names.to_list()
        if content is not None and ent in content
    ]

    for entity_name in entities:
        article_sentences = list(chain.from_iterable(
            [partition.split(".") for partition in content.lower().split(":")]
        ))
        article_sentences = [s.replace(",", "").lower() for s in article_sentences]
    
        # selecting relevant sentences
        relevant_sentances = [
            sent
            for sent
            in article_sentences
            if entity_name in sent
        ]


        # Splitting into words
        relevant_words = list(
            chain.from_iterable(
                [re.findall(r"\w+", sent) for sent in relevant_sentances]
            )
        )

        # filtering stopwords and entity names
        relevant_words = [
            w for w in relevant_words
            if (w not in english_stopwords) and (
                w not in entity_name
            )
        ]

        counts = [Counter(term_sentiment[w]) for w in relevant_words if w in term_sentiment]
        counter = Counter()
        for count in counts:
            counter += count
        
        if len(counter.most_common(1)):
            prediction = ["positive", "negative", "neutral"][np.argmax([
                int(counter["positive"]*730 / total_sentiments["positive"]),
                int(counter["negative"]*730 / total_sentiments["negative"]),
                int(counter["neutral"]*1000 / total_sentiments["neutral"])
            ])]
            total_found += {prediction: 1}

            df.iloc[i, 3].append((entity_name, prediction))
# Out:
# Counter({'neutral': 3537606, 'positive': 545721, 'negative': 115134})  447900/447920

# %%
df.to_pickle(Path("cache") / "total_inference.df.pkl")
