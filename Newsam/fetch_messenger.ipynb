# %% [markdown]
# # Telling scraper to scrape articles

# %%
import numpy as np
import pandas as pd
import requests
import re
import sqlite3
import time
import openai
import redis
import datetime
import json

# %%
r = redis.Redis("localhost", 5211, decode_responses=True)

# %%
db = sqlite3.connect("scraping.db")
def create_article_table(db):
    db.execute("drop table if exists article")

    db.commit()
    db.execute("""
    create table if not exists article (id integer primary key, headline varchar(255), time timestamp, content text, feedback text, region varchar(255), theme varchar(128));
    """);

    db.commit()

# %%
# create_article_table(db)

# %%
initial_date = datetime.datetime(2009, 6, 25)
on_date = initial_date

while on_date <= datetime.datetime.now():
    print(on_date.year, end="\r")
    r.lpush("to_fetch_list_newsam", f"{on_date.year}/{on_date.month}/{on_date.day}/")
    on_date += datetime.timedelta(1)
# Out:
# 2023

# %%
while r.llen("to_fetch_list_newsam"): # Continue execution of notebook only after all article lists have been scraped
    time.sleep(1)

# %%
r.llen("to_fetch_list_newsam"), r.llen("to_store_list_newsam")
# Out:
# (0, 219417)

# %% [markdown]
# ## Storing scraped list of articles to scrape

# %%
# datetime.datetime.now().strftime("%z")
datetext = json.loads(r.rpoplpush("to_store_list_newsam", "to_store_list_newsam"))["date"]
datetime.datetime.strptime(datetext[:10] + " " + datetext[13:], "%Y-%m-%d %H:%M:%S")
# Out:
# datetime.datetime(2009, 6, 30, 7, 46)

# %%
n = 104000
while True:
    if (data := r.rpop("to_store_list_newsam")) is None:
        print(f"{n} Nothing to store, breaking", end="\r")
        break
    else:
        if n % 1000 == 0:
            print(datetime.datetime.now(), " -- ", n)
        data = json.loads(data)
        # print(data, end="\r")
        if len(data["headline"]) == 0:
            print("ERROR, NO HEADLINE")
            continue
        if len(str(data["id"])) == 0:
            print("ERROR, NO CONTENT")
            continue
        n += 1
        try:
            db.execute(f'insert into article (id, headline, time) values (?, ?, ?)', (int(data["id"]), data["headline"], datetime.datetime.strptime(data["date"][:10] + " " + data["date"][13:], "%Y-%m-%d %H:%M:%S")))
        except sqlite3.IntegrityError as e:
            db.commit()
            print(data["id"], " not unique", end="\r")
# Out:
# 2023-11-23 20:13:23.615981  --  104000
# 2023-11-23 20:13:24.188400  --  105000
# 2023-11-23 20:13:24.741999  --  106000
# 2023-11-23 20:13:25.329674  --  107000
# 2023-11-23 20:13:25.924828  --  108000
# 2023-11-23 20:13:26.460388  --  109000
# 2023-11-23 20:13:27.147735  --  110000
# 2023-11-23 20:13:27.884745  --  111000
# 2023-11-23 20:13:28.607982  --  112000
# 2023-11-23 20:13:29.342927  --  113000
# 2023-11-23 20:13:30.074355  --  114000
# 2023-11-23 20:13:30.867951  --  115000
# 2023-11-23 20:13:31.655613  --  116000
# 2023-11-23 20:13:32.404609  --  117000
# 2023-11-23 20:13:33.238939  --  118000
# 2023-11-23 20:13:34.267479  --  119000
# 2023-11-23 20:13:35.705320  --  120000
# 2023-11-23 20:13:36.978071  --  121000
# 2023-11-23 20:13:37.818651  --  122000
# 2023-11-23 20:13:38.567000  --  123000
# 2023-11-23 20:13:39.357232  --  124000
# 2023-11-23 20:13:40.178906  --  125000
# 2023-11-23 20:13:41.086391  --  126000
# 2023-11-23 20:13:41.915410  --  127000
# 2023-11-23 20:13:43.063907  --  128000
# 2023-11-23 20:13:44.116880  --  129000
# 2023-11-23 20:13:45.159679  --  130000
# 2023-11-23 20:13:48.141812  --  131000
# 2023-11-23 20:13:50.882178  --  132000
# 2023-11-23 20:13:52.640830  --  133000
# 2023-11-23 20:13:53.606199  --  134000
# 2023-11-23 20:13:54.488823  --  135000
# 2023-11-23 20:13:55.386995  --  136000
# 2023-11-23 20:13:56.358042  --  137000
# 2023-11-23 20:13:57.383613  --  138000
# 2023-11-23 20:13:59.072204  --  139000
# 2023-11-23 20:14:00.975921  --  140000
# 2023-11-23 20:14:02.528913  --  141000
# 2023-11-23 20:14:03.455538  --  142000
# 2023-11-23 20:14:04.471427  --  143000
# 2023-11-23 20:14:05.457859  --  144000
# 2023-11-23 20:14:06.339191  --  145000
# 2023-11-23 20:14:07.243014  --  146000
# 2023-11-23 20:14:08.847993  --  147000
# 2023-11-23 20:14:11.124174  --  148000
# 2023-11-23 20:14:12.681891  --  149000
# 149115 Nothing to store, idling...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Projects\NewsEntityTracking\Newsam\fetch_messenger.ipynb Cell 10 line 5
#       <a href='vscode-notebook-cell:/c%3A/Projects/NewsEntityTracking/Newsam/fetch_messenger.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> if (data := r.rpop("to_store_list_newsam")) is None:
#       <a href='vscode-notebook-cell:/c%3A/Projects/NewsEntityTracking/Newsam/fetch_messenger.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>     print(f"{n} Nothing to store, idling...", end="\r")
# ----> <a href='vscode-notebook-cell:/c%3A/Projects/NewsEntityTracking/Newsam/fetch_messenger.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>     time.sleep(3)
#       <a href='vscode-notebook-cell:/c%3A/Projects/NewsEntityTracking/Newsam/fetch_messenger.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> else:
#       <a href='vscode-notebook-cell:/c%3A/Projects/NewsEntityTracking/Newsam/fetch_messenger.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>     if n % 1000 == 0:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Telling scraper to scrape content now

# %%
while True:
    if r.llen("to_fetch_newsam") < 2048:
        cur = db.execute("select id, content from article where content is null order by RANDOM() limit 1024")
        db.commit()
    
        if len((cur := list(cur))) == 0:
            print("No more articles to fetch")
            break

        for row in cur:
            r.lpush("to_fetch_newsam", int(row[0]))
    else:
        time.sleep(1)
        print(f"Waiting for it to fetch ({r.llen('to_fetch_newsam')}), idling...", end="\r")
# Out:
# Waiting for it to fetch (2749), idling...

# %%
cur = db.execute("select count(*) from article")
db.commit()

(l := list(cur))
# Out:
# [(219401,)]

# %%
# db.execute("update article set headline = 'None'")
# db.commit()

# %%
# r.lpop("to_fetch_list_newsam", r.llen("to_fetch_list_newsam"))
# r.lpop("to_store_list_newsam", r.llen("to_store_list_newsam"))
# Out:
# ['[{"id": 169, "headline": "War not over for Azerbaijan", "date": "2009-06-25+0513:16:00"}, {"id": 166, "headline": "Armenians no more move abroad for an employment, but do not rush back either", "date": "2009-06-25+0512:37:00"}]']

# %%
# cur = db.execute("select * from article limit 100")
# db.commit()

# (l := list(cur))
# Out:
# [(166,
#   'Armenians no more move abroad for an employment, but do not rush back either',
#   '2009-06-25 12:37:00',
#   None,
#   None,
#   None,
#   None),
#  (169,
#   'War not over for Azerbaijan',
#   '2009-06-25 13:16:00',
#   None,
#   None,
#   None,
#   None),
#  (178,
#   'Armenian authorities forgot about World Refugee Day',
#   '2009-06-26 07:02:00',
#   None,
#   None,
#   None,
#   None),
#  (187,
#   'Mad scramble rather than a brawl',
#   '2009-06-26 10:02:00',
#   None,
#   None,
#   None,
#   None),
#  (193,
#   'Expert: Armenian Government makes crisis worse',
#   '2009-06-26 10:50:00',
#   None,
#   None,
#   None,
#   None),
#  (198,
#   'Spending Russian money',
#   '2009-06-26 11:52:00',
#   None,
#   None,
#   None,
#   None),
#  (213,
#   'Marie Yovanovitch: Genocide denial White House’s policy',
#   '2009-06-27 06:52:00',
#   None,
#   None,
#   None,
#   None),
#  (219,
#   'Relatives of sentenced for life addressed the President of Armenia',
#   '2009-06-27 10:05:00',
#   None,
#   None,
#   None,
#   None),
#  (226,
#   'Young athletes from Armenia and Nagorno-Karabakh competing for RA Parliament Cup',
#   '2009-06-27 12:25:00',
#   None,
#   None,
#   None,
#   None),
#  (229,
#   'Injuriousness of overdone hospitality and Saakashvili, as holder of an Order',
#   '2009-06-27 13:12:00',
#   None,
#   None,
#   None,
#   None),
#  (243,
#   'Charles Aznavour presents credentials to Director-General of the United Nations',
#   '2009-06-29 05:44:00',
#   None,
#   None,
#   None,
#   None),
#  (244,
#   '“Caucasus-2009” military maneuvers launched',
#   '2009-06-29 05:49:00',
#   None,
#   None,
#   None,
#   None),
#  (247,
#   'Russian leader to visit Baku: gas, Caspian region and Karabakh negotiations on a',
#   '2009-06-29 06:43:00',
#   None,
#   None,
#   None,
#   None),
#  (251,
#   'Turkish FM: “positive psychological atmosphere” in Middle East',
#   '2009-06-29 07:47:00',
#   None,
#   None,
#   None,
#   None),
#  (252,
#   'Partial recount of votes to start in Iran',
#   '2009-06-29 07:54:00',
#   None,
#   None,
#   None,
#   None),
#  (255,
#   'Iranian Azeris protest against Peres to arrive in Baku',
#   '2009-06-29 08:28:00',
#   None,
#   None,
#   None,
#   None),
#  (258,
#   'Armenian environmental organizations to sue Armenian authorities',
#   '2009-06-29 08:45:00',
#   None,
#   None,
#   None,
#   None),
#  (259,
#   'Whether Russian loan stabilizes Armenian industry',
#   '2009-06-29 09:31:00',
#   None,
#   None,
#   None,
#   None),
#  (260,
#   'Azeri journalists are racketeering',
#   '2009-06-29 10:03:00',
#   None,
#   None,
#   None,
#   None),
#  (262,
#   'Turkey to open a Greek seminary',
#   '2009-06-29 10:50:00',
#   None,
#   None,
#   None,
#   None),
#  (263,
#   'Participants of Karabakh liberating war defend their rights',
#   '2009-06-29 10:59:00',
#   None,
#   None,
#   None,
#   None),
#  (264,
#   'YouTube changes its design',
#   '2009-06-29 11:03:00',
#   None,
#   None,
#   None,
#   None),
#  (269,
#   'Residents of Kapan transported opium in live-containers',
#   '2009-06-29 12:46:00',
#   None,
#   None,
#   None,
#   None),
#  (272,
#   'Armenia, Austria hit on transportation agreement',
#   '2009-06-29 13:03:00',
#   None,
#   None,
#   None,
#   None),
#  (274,
#   'Vatican and Armenian Apostolic Church — best cooperation pattern: Vatican repres',
#   '2009-06-29 14:06:00',
#   None,
#   None,
#   None,
#   None),
#  (278,
#   'Vladimir Kazimirov: Armenians, Azerbaijanis need ways to historic reconciliation',
#   '2009-06-30 06:48:00',
#   None,
#   None,
#   None,
#   None),
#  (280,
#   'Recount of ballots in Iran — nothing changed',
#   '2009-06-30 07:03:00',
#   None,
#   None,
#   None,
#   None),
#  (284,
#   'Muslim women fate in France',
#   '2009-06-30 07:46:00',
#   None,
#   None,
#   None,
#   None),
#  (299,
#   'Expert: Armenia poses as political support for Georgian Government',
#   '2009-07-01 05:13:00',
#   None,
#   None,
#   None,
#   None),
#  (301,
#   'Azerbaijanis to pay twice as much for gas',
#   '2009-07-01 05:28:00',
#   None,
#   None,
#   None,
#   None),
#  (303,
#   'Vladimir Putin is amid the most unpopular politicians',
#   '2009-07-01 05:37:00',
#   None,
#   None,
#   None,
#   None),
#  (315,
#   'Pashinyan went out of the undergound',
#   '2009-07-01 10:25:00',
#   None,
#   None,
#   None,
#   None),
#  (320,
#   'Pashinyan yielded. Details.',
#   '2009-07-01 11:10:00',
#   None,
#   None,
#   None,
#   None),
#  (336,
#   'Expert: Opening of Upper Lars equally beneficial for Georgia and Armenia',
#   '2009-07-01 13:39:00',
#   None,
#   None,
#   None,
#   None),
#  (346,
#   'Ankara not jealous of Baku-Moscow relations',
#   '2009-07-02 05:12:00',
#   None,
#   None,
#   None,
#   None),
#  (350,
#   'Serzh Sargsyan and Ilham Aliyev to meet at horserace',
#   '2009-07-02 07:25:00',
#   None,
#   None,
#   None,
#   None),
#  (364,
#   'Turkish-Russian problems proceed',
#   '2009-07-02 12:28:00',
#   None,
#   None,
#   None,
#   None),
#  (366,
#   'Poland for Azerbaijan’s territorial integrity',
#   '2009-07-02 12:38:00',
#   None,
#   None,
#   None,
#   None),
#  (379,
#   'Amnestied oppositionists make passions run high',
#   '2009-07-02 19:33:00',
#   None,
#   None,
#   None,
#   None),
#  (380,
#   'Armenia’s leading Marxist forecasts early elections',
#   '2009-07-03 04:41:00',
#   None,
#   None,
#   None,
#   None),
#  (387,
#   'US Congresswoman considers Russia and Iran Azerbaijan’s unsafe neighbors',
#   '2009-07-03 07:23:00',
#   None,
#   None,
#   None,
#   None),
#  (420,
#   'Turkey, Romania, Poland pick up foul smell of Azerbaijan’s gas policy',
#   '2009-07-03 18:14:00',
#   None,
#   None,
#   None,
#   None),
#  (423,
#   'Azerbaijani President meets Armenian, Azerbaijani Ambassadors to Russia',
#   '2009-07-04 06:44:00',
#   None,
#   None,
#   None,
#   None),
#  (427,
#   'European Commission: democracy situation in Armenia worsened',
#   '2009-07-04 07:05:00',
#   None,
#   None,
#   None,
#   None),
#  (430,
#   'Armenian MPs meet OSCE Chairperson-in-Office',
#   '2009-07-04 07:21:00',
#   None,
#   None,
#   None,
#   None),
#  (431,
#   'The RA Defense Minister Seyran Ohanyan invited to Iran',
#   '2009-07-04 08:09:00',
#   None,
#   None,
#   None,
#   None),
#  (442,
#   'Buyers await, sellers are nervous: the real estate market in Yerevan goes down',
#   '2009-07-04 18:56:00',
#   None,
#   None,
#   None,
#   None),
#  (443,
#   'Presidents of US, Turkey discussed Karabakh issues on the phone',
#   '2009-07-06 04:22:00',
#   None,
#   None,
#   None,
#   None),
#  (444,
#   'President of Cyprus to arrive in Yerevan',
#   '2009-07-06 04:26:00',
#   None,
#   None,
#   None,
#   None),
#  (449,
#   'President of Nagorno Karabakh congratulated Obama',
#   '2009-07-06 04:53:00',
#   None,
#   None,
#   None,
#   None),
#  (450,
#   '10.5 percent decline in Armenian industry',
#   '2009-07-06 04:57:00',
#   None,
#   None,
#   None,
#   None),
#  (452,
#   'Mediators in Karabakh peace process coming to region',
#   '2009-07-06 05:19:00',
#   None,
#   None,
#   None,
#   None),
#  (453,
#   'Crisis and high prices disable Armenians to rest: situation in tourism market',
#   '2009-07-06 05:57:00',
#   None,
#   None,
#   None,
#   None),
#  (456,
#   'Israeli attack on Iran impossible without USA’s permission',
#   '2009-07-06 06:19:00',
#   None,
#   None,
#   None,
#   None),
#  (457,
#   'Syrian President stands “test of parity”',
#   '2009-07-06 06:28:00',
#   None,
#   None,
#   None,
#   None),
#  (463,
#   'Ilham Aliyev reveals essence of Madrid principles',
#   '2009-07-06 07:46:00',
#   None,
#   None,
#   None,
#   None),
#  (464,
#   'Oppositionist detained for his own beating up',
#   '2009-07-06 07:48:00',
#   None,
#   None,
#   None,
#   None),
#  (466,
#   'Armenia to leave Georgia behind in joining NATO',
#   '2009-07-06 08:11:00',
#   None,
#   None,
#   None,
#   None),
#  (470,
#   'Gagik Melikyan: the guilty of the March 1-2, 2008 events will be exposed',
#   '2009-07-06 09:42:00',
#   None,
#   None,
#   None,
#   None),
#  (478,
#   'People no more support opposition: the ruling party MP',
#   '2009-07-06 11:46:00',
#   None,
#   None,
#   None,
#   None),
#  (486,
#   'Armenia, Cyprus discuss Karabakh, Cypriot peace processes',
#   '2009-07-06 14:36:00',
#   None,
#   None,
#   None,
#   None),
#  (490,
#   'Baku wants to communicate with Stepanakert without mediators',
#   '2009-07-06 15:32:00',
#   None,
#   None,
#   None,
#   None),
#  (501,
#   'Japanese specialists get to grips with Yerevan’s “dirtiest” problem',
#   '2009-07-07 05:22:00',
#   None,
#   None,
#   None,
#   None),
#  (502,
#   'Slowing down Karabakh process is in Russia’s interests',
#   '2009-07-07 05:35:00',
#   None,
#   None,
#   None,
#   None),
#  (506,
#   'Aliyev for Azerbaijan’s territorial integity',
#   '2009-07-07 06:47:00',
#   None,
#   None,
#   None,
#   None),
#  (507,
#   'Detained oppositionist on hunger strike',
#   '2009-07-07 07:38:00',
#   None,
#   None,
#   None,
#   None),
#  (509,
#   'Diplomatic climate in Nagorno-Karabakh radically differs from weather conditions',
#   '2009-07-07 07:56:00',
#   None,
#   None,
#   None,
#   None),
#  (517,
#   'Ad hoc commission for March 1-2 events to present report ahead of schedule',
#   '2009-07-07 09:51:00',
#   None,
#   None,
#   None,
#   None),
#  (519,
#   'Sometimes Europe itself prefers to be cheated',
#   '2009-07-07 09:59:00',
#   None,
#   None,
#   None,
#   None),
#  (521,
#   'Stepan Safaryan: Armenian-Turkish border to open by October',
#   '2009-07-07 10:18:00',
#   None,
#   None,
#   None,
#   None),
#  (536,
#   'It’s time to pressure Turkey: Richard Giragosian',
#   '2009-07-07 13:26:00',
#   None,
#   None,
#   None,
#   None),
#  (538,
#   'Obama better refrain from speaking of territorial integrity in Nagorno Karabakh',
#   '2009-07-07 13:49:00',
#   None,
#   None,
#   None,
#   None),
#  (543,
#   'The sooner Armenia suspends the negotiations with Turkey, the more it wins',
#   '2009-07-07 16:07:00',
#   None,
#   None,
#   None,
#   None),
#  (544,
#   'Vartan Oskanian: Turkey gains, Armenia no better off than before',
#   '2009-07-07 16:31:00',
#   None,
#   None,
#   None,
#   None),
#  (545,
#   'Aliyev is sitting on the oil barrel',
#   '2009-07-07 16:37:00',
#   None,
#   None,
#   None,
#   None),
#  (557,
#   'Levon Ter-Petrosyan discussed democratic issues in Armenia with Commissioner for',
#   '2009-07-08 06:06:00',
#   None,
#   None,
#   None,
#   None),
#  (558,
#   'Azerbaijan puts 90 years on its diplomacy',
#   '2009-07-08 06:10:00',
#   None,
#   None,
#   None,
#   None),
#  (560,
#   'Grigor Arakelyan – new Armenian Ambassador to Iran',
#   '2009-07-08 06:44:00',
#   None,
#   None,
#   None,
#   None),
#  (564,
#   'CBA cuts the refinancing rate to 5, 5%',
#   '2009-07-08 07:30:00',
#   None,
#   None,
#   None,
#   None),
#  (565,
#   'Armenal exceeded the H1 nominal design capacity',
#   '2009-07-08 07:34:00',
#   None,
#   None,
#   None,
#   None),
#  (580,
#   'Whether the Prime Minister is responsible for the explosion at Nairit',
#   '2009-07-08 11:11:00',
#   None,
#   None,
#   None,
#   None),
#  (583,
#   'Edward Nalbandyan: Nagorno-Karabakh to determine its status itself',
#   '2009-07-08 11:36:00',
#   None,
#   None,
#   None,
#   None),
#  (584,
#   'The RA President received OSCE Minsk Group Co-chairmen',
#   '2009-07-08 11:39:00',
#   None,
#   None,
#   None,
#   None),
#  (588,
#   'Armenia exported half billion dollars’ worth of molybdenum and copper in 2008',
#   '2009-07-08 12:07:00',
#   None,
#   None,
#   None,
#   None),
#  (606,
#   'Nalbandyan to leave for Europe',
#   '2009-07-08 14:47:00',
#   None,
#   None,
#   None,
#   None),
#  (610,
#   'Bernard Fassiers’s arithmetic',
#   '2009-07-08 15:26:00',
#   None,
#   None,
#   None,
#   None),
#  (614,
#   'Aliyev’s rhetoric changed for peace: OSCE MG co-chairmen',
#   '2009-07-08 16:08:00',
#   None,
#   None,
#   None,
#   None),
#  (620,
#   'The World Bank allocates Armenia $100 mln of total $550 mln credit',
#   '2009-07-09 05:43:00',
#   None,
#   None,
#   None,
#   None),
#  (621,
#   'Aliyev recalled Bashar al-Asad of UN SC failed resolutions',
#   '2009-07-09 06:08:00',
#   None,
#   None,
#   None,
#   None),
#  (624,
#   'Complicated situation should urge Armenia on the reforms',
#   '2009-07-09 06:47:00',
#   None,
#   None,
#   None,
#   None),
#  (634,
#   'Azerbaijani Foreign Minister contradicts Aliyev',
#   '2009-07-09 08:53:00',
#   None,
#   None,
#   None,
#   None),
#  (650,
#   'Armenia always hoped the world is aware it is right: Bulgarian cameraman Cvetana',
#   '2009-07-09 10:58:00',
#   None,
#   None,
#   None,
#   None),
#  (664,
#   'Asian Development Bank: There is a large immigration to Armenia and Tajikistan',
#   '2009-07-09 13:48:00',
#   None,
#   None,
#   None,
#   None),
#  (665,
#   'Disclosing details of Turkish special services’ struggle against “ASALA” pregnan',
#   '2009-07-09 14:00:00',
#   None,
#   None,
#   None,
#   None),
#  (678,
#   'Fassier’s statement is unacceptable: Vladimir Karapetyan',
#   '2009-07-10 05:19:00',
#   None,
#   None,
#   None,
#   None),
#  (683,
#   'I won’t be surprised if our economy decline reaches 20%: Ara Nranyan',
#   '2009-07-10 06:37:00',
#   None,
#   None,
#   None,
#   None),
#  (687,
#   '$30mln US aid to Armenia versus $22mln to Azerbaijan',
#   '2009-07-10 08:03:00',
#   None,
#   None,
#   None,
#   None),
#  (691,
#   'Arbitrary rule of the officials in Armenia: Ombudsman',
#   '2009-07-10 08:36:00',
#   None,
#   None,
#   None,
#   None),
#  (692,
#   'Armen Harutyunyan: PACE Resolution unbiased',
#   '2009-07-10 08:41:00',
#   None,
#   None,
#   None,
#   None),
#  (694,
#   'Armenia brought victory to FC Universisad in Chile soccer championship',
#   '2009-07-10 08:48:00',
#   None,
#   None,
#   None,
#   None)]
