# %% [markdown]
# # Scraping article content

# %%
import numpy as np
import pandas as pd
import requests
import re
import time
import openai
import redis
import json
import sqlite3
import scrapy
from scrapy.crawler import CrawlerProcess
from datetime import datetime
import bs4

# %%
class TertamListCrawler(scrapy.Spider):
    name = "MovsisyansNewsCrawler"

    custom_settings=dict(
        # set a download delay to avoid DOSing
        DOWNLOAD_DELAY = 0.08
    )
    
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.domain = r"https://www.tert.am/en/news/"
        self.r = redis.Redis("localhost", 5211, decode_responses=True)

    def start_requests(self):
        while (to_fetch := self.r.rpop("to_fetch_list_tertam")) is not None:
            yield scrapy.Request(url=self.domain + to_fetch, callback=self.parse_article)

    def parse_article(self, response):
        resp_text = " ".join(response.text.split())
        
        # print(f"SCRAPING {response.url}")
        soup = bs4.BeautifulSoup(resp_text)

        articles = soup.findAll("li", {"class": "list__item"})

        titles = [article.find('span', {"class": "list__title db fb fs15"}).find(string=True) for article in articles]
        dates = [datetime.strptime(article.find("span", {"class": "list__date ver-top-box fb fs12"}).find(string=True), "%H:%M • %d.%m.%y").strftime("%Y/%m/%d %H:%M:%S") for article in articles]
        categories = [", ".join([d for d in ["".join(t.findAll(string=True)) for t in article.findAll("a", {"class": "list__category fb fs12 ver-top-box tu"})] if len(d) > 0]) for article in articles]
        links = [article.find("a", {"class": "list__link db"}).attrs["href"].lstrip("/en/news/") for article in articles]

        links, categories, dates, titles

        [self.r.lpush("to_store_list_tertam", json.dumps({"id": links[i], "headline": titles[i], "date": dates[i], "categories": categories[i]})) for i in range(len(links))]

# %%
proc = CrawlerProcess()
proc.crawl(TertamListCrawler)
proc.start()
# Out:
# 2023-11-25 14:19:35 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2023-11-25 14:19:35 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.22621-SP0
# 2023-11-25 14:19:35 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-25 14:19:35 [py.warnings] WARNING: c:\Projects\NewsEntityTracking\.venv\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-11-25 14:19:35 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-11-25 14:19:35 [scrapy.extensions.telnet] INFO: Telnet Password: 213c944f4ffd87b9
# 2023-11-25 14:19:36 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-11-25 14:19:36 [scrapy.crawler] INFO: Overridden settings:
# {'DOWNLOAD_DELAY': 0.08}
# 2023-11-25 14:19:36 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-11-25 14:19:36 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-11-25 14:19:36 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-11-25 14:19:36 [scrapy.core.engine] INFO: Spider opened
# 2023-11-25 14:19:36 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-11-25 14:19:36 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-11-25 14:19:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/02> (referer: None)
# 2023-11-25 14:19:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/03> (referer: None)
# 2023-11-25 14:19:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/04> (referer: None)
# 2023-11-25 14:19:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/05> (referer: None)
# 2023-11-25 14:19:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/06> (referer: None)
# 2023-11-25 14:19:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/07> (referer: None)
# 2023-11-25 14:19:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/08> (referer: None)
# 2023-11-25 14:19:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/09> (referer: None)
# 2023-11-25 14:19:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/10> (referer: None)
# 2023-11-25 14:19:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/11> (referer: None)
# 2023-11-25 14:19:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/12> (referer: None)
# 2023-11-25 14:19:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/13> (referer: None)
# 2023-11-25 14:19:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/14> (referer: None)
# 2023-11-25 14:19:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/15> (referer: None)
# 2023-11-25 14:19:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/16> (referer: None)
# 2023-11-25 14:19:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/17> (referer: None)
# 2023-11-25 14:19:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/18> (referer: None)
# 2023-11-25 14:19:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/19> (referer: None)
# 2023-11-25 14:19:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/20> (referer: None)
# 2023-11-25 14:19:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/21> (referer: None)
# 2023-11-25 14:19:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/22> (referer: None)
# 2023-11-25 14:19:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/23> (referer: None)
# 2023-11-25 14:19:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/24> (referer: None)
# 2023-11-25 14:19:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/25> (referer: None)
# 2023-11-25 14:19:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/26> (referer: None)
# 2023-11-25 14:19:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/27> (referer: None)
# 2023-11-25 14:19:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/28> (referer: None)
# 2023-11-25 14:19:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/29> (referer: None)
# 2023-11-25 14:19:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/30> (referer: None)
# 2023-11-25 14:19:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/03/31> (referer: None)
# 2023-11-25 14:19:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/01> (referer: None)
# 2023-11-25 14:19:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/02> (referer: None)
# 2023-11-25 14:19:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/03> (referer: None)
# 2023-11-25 14:19:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/04> (referer: None)
# 2023-11-25 14:19:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/05> (referer: None)
# 2023-11-25 14:19:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/06> (referer: None)
# 2023-11-25 14:19:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/07> (referer: None)
# 2023-11-25 14:19:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/08> (referer: None)
# 2023-11-25 14:19:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/09> (referer: None)
# 2023-11-25 14:19:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/10> (referer: None)
# 2023-11-25 14:19:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/11> (referer: None)
# 2023-11-25 14:19:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/12> (referer: None)
# 2023-11-25 14:19:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/13> (referer: None)
# 2023-11-25 14:19:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/14> (referer: None)
# 2023-11-25 14:19:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/15> (referer: None)
# 2023-11-25 14:19:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/16> (referer: None)
# 2023-11-25 14:19:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/17> (referer: None)
# 2023-11-25 14:19:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/18> (referer: None)
# 2023-11-25 14:19:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/19> (referer: None)
# 2023-11-25 14:19:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/20> (referer: None)
# 2023-11-25 14:19:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/21> (referer: None)
# 2023-11-25 14:19:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/22> (referer: None)
# 2023-11-25 14:19:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/23> (referer: None)
# 2023-11-25 14:19:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/24> (referer: None)
# 2023-11-25 14:19:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/25> (referer: None)
# 2023-11-25 14:19:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/26> (referer: None)
# 2023-11-25 14:19:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/27> (referer: None)
# 2023-11-25 14:19:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/28> (referer: None)
# 2023-11-25 14:19:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/29> (referer: None)
# 2023-11-25 14:19:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/04/30> (referer: None)
# 2023-11-25 14:19:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/01> (referer: None)
# 2023-11-25 14:19:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/02> (referer: None)
# 2023-11-25 14:19:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/03> (referer: None)
# 2023-11-25 14:19:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/04> (referer: None)
# 2023-11-25 14:19:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/05> (referer: None)
# 2023-11-25 14:19:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/06> (referer: None)
# 2023-11-25 14:19:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/07> (referer: None)
# 2023-11-25 14:19:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/08> (referer: None)
# 2023-11-25 14:19:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/09> (referer: None)
# 2023-11-25 14:19:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/10> (referer: None)
# 2023-11-25 14:19:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/11> (referer: None)
# 2023-11-25 14:19:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/12> (referer: None)
# 2023-11-25 14:19:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/13> (referer: None)
# 2023-11-25 14:19:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/14> (referer: None)
# 2023-11-25 14:19:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/15> (referer: None)
# 2023-11-25 14:19:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/16> (referer: None)
# 2023-11-25 14:19:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/17> (referer: None)
# 2023-11-25 14:19:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/18> (referer: None)
# 2023-11-25 14:19:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/19> (referer: None)
# 2023-11-25 14:19:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/20> (referer: None)
# 2023-11-25 14:19:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/22> (referer: None)
# 2023-11-25 14:19:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/21> (referer: None)
# 2023-11-25 14:19:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/23> (referer: None)
# 2023-11-25 14:19:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/24> (referer: None)
# 2023-11-25 14:19:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/25> (referer: None)
# 2023-11-25 14:19:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/26> (referer: None)
# 2023-11-25 14:19:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/27> (referer: None)
# 2023-11-25 14:19:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/28> (referer: None)
# 2023-11-25 14:19:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/29> (referer: None)
# 2023-11-25 14:19:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/30> (referer: None)
# 2023-11-25 14:19:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/05/31> (referer: None)
# 2023-11-25 14:19:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/01> (referer: None)
# 2023-11-25 14:19:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/02> (referer: None)
# 2023-11-25 14:19:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/03> (referer: None)
# 2023-11-25 14:19:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/04> (referer: None)
# 2023-11-25 14:19:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/05> (referer: None)
# 2023-11-25 14:19:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/06> (referer: None)
# 2023-11-25 14:19:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/07> (referer: None)
# 2023-11-25 14:19:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/08> (referer: None)
# 2023-11-25 14:19:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/09> (referer: None)
# 2023-11-25 14:19:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/10> (referer: None)
# 2023-11-25 14:19:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/11> (referer: None)
# 2023-11-25 14:19:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/12> (referer: None)
# 2023-11-25 14:19:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/13> (referer: None)
# 2023-11-25 14:19:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/14> (referer: None)
# 2023-11-25 14:19:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/15> (referer: None)
# 2023-11-25 14:19:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/16> (referer: None)
# 2023-11-25 14:19:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/17> (referer: None)
# 2023-11-25 14:19:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/18> (referer: None)
# 2023-11-25 14:19:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/19> (referer: None)
# 2023-11-25 14:19:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/20> (referer: None)
# 2023-11-25 14:19:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/21> (referer: None)
# 2023-11-25 14:19:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/22> (referer: None)
# 2023-11-25 14:19:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/23> (referer: None)
# 2023-11-25 14:19:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/24> (referer: None)
# 2023-11-25 14:19:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/25> (referer: None)
# 2023-11-25 14:19:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/26> (referer: None)
# 2023-11-25 14:19:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/27> (referer: None)
# 2023-11-25 14:19:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/28> (referer: None)
# 2023-11-25 14:19:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/29> (referer: None)
# 2023-11-25 14:19:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/06/30> (referer: None)
# 2023-11-25 14:19:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/01> (referer: None)
# 2023-11-25 14:19:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/02> (referer: None)
# 2023-11-25 14:19:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/03> (referer: None)
# 2023-11-25 14:19:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/04> (referer: None)
# 2023-11-25 14:19:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/05> (referer: None)
# 2023-11-25 14:19:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/06> (referer: None)
# 2023-11-25 14:19:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/07> (referer: None)
# 2023-11-25 14:19:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/08> (referer: None)
# 2023-11-25 14:19:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/09> (referer: None)
# 2023-11-25 14:19:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/10> (referer: None)
# 2023-11-25 14:19:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/11> (referer: None)
# 2023-11-25 14:19:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/12> (referer: None)
# 2023-11-25 14:19:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/13> (referer: None)
# 2023-11-25 14:19:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/14> (referer: None)
# 2023-11-25 14:19:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/15> (referer: None)
# 2023-11-25 14:19:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/16> (referer: None)
# 2023-11-25 14:19:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/17> (referer: None)
# 2023-11-25 14:19:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/18> (referer: None)
# 2023-11-25 14:19:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/19> (referer: None)
# 2023-11-25 14:19:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/20> (referer: None)
# 2023-11-25 14:19:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/22> (referer: None)
# 2023-11-25 14:19:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/23> (referer: None)
# 2023-11-25 14:19:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/21> (referer: None)
# 2023-11-25 14:19:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/25> (referer: None)
# 2023-11-25 14:19:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/24> (referer: None)
# 2023-11-25 14:19:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/26> (referer: None)
# 2023-11-25 14:19:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/27> (referer: None)
# 2023-11-25 14:19:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/28> (referer: None)
# 2023-11-25 14:19:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/29> (referer: None)
# 2023-11-25 14:19:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/31> (referer: None)
# 2023-11-25 14:19:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/01> (referer: None)
# 2023-11-25 14:19:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/07/30> (referer: None)
# 2023-11-25 14:19:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/02> (referer: None)
# 2023-11-25 14:19:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/03> (referer: None)
# 2023-11-25 14:19:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/04> (referer: None)
# 2023-11-25 14:19:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/05> (referer: None)
# 2023-11-25 14:19:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/06> (referer: None)
# 2023-11-25 14:19:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/07> (referer: None)
# 2023-11-25 14:19:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/08> (referer: None)
# 2023-11-25 14:19:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/09> (referer: None)
# 2023-11-25 14:19:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/10> (referer: None)
# 2023-11-25 14:19:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/11> (referer: None)
# 2023-11-25 14:19:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/12> (referer: None)
# 2023-11-25 14:19:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/13> (referer: None)
# 2023-11-25 14:19:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/15> (referer: None)
# 2023-11-25 14:19:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/14> (referer: None)
# 2023-11-25 14:19:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/16> (referer: None)
# 2023-11-25 14:19:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/17> (referer: None)
# 2023-11-25 14:19:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/18> (referer: None)
# 2023-11-25 14:19:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/19> (referer: None)
# 2023-11-25 14:19:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/20> (referer: None)
# 2023-11-25 14:19:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/21> (referer: None)
# 2023-11-25 14:19:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/22> (referer: None)
# 2023-11-25 14:19:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/23> (referer: None)
# 2023-11-25 14:19:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/24> (referer: None)
# 2023-11-25 14:19:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/25> (referer: None)
# 2023-11-25 14:19:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/26> (referer: None)
# 2023-11-25 14:19:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/27> (referer: None)
# 2023-11-25 14:19:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/28> (referer: None)
# 2023-11-25 14:19:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/29> (referer: None)
# 2023-11-25 14:19:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/30> (referer: None)
# 2023-11-25 14:19:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/08/31> (referer: None)
# 2023-11-25 14:19:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/01> (referer: None)
# 2023-11-25 14:19:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/02> (referer: None)
# 2023-11-25 14:19:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/03> (referer: None)
# 2023-11-25 14:19:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/04> (referer: None)
# 2023-11-25 14:19:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/05> (referer: None)
# 2023-11-25 14:19:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/06> (referer: None)
# 2023-11-25 14:19:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/07> (referer: None)
# 2023-11-25 14:19:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/08> (referer: None)
# 2023-11-25 14:19:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/09> (referer: None)
# 2023-11-25 14:19:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/10> (referer: None)
# 2023-11-25 14:19:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/11> (referer: None)
# 2023-11-25 14:19:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/12> (referer: None)
# 2023-11-25 14:19:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/13> (referer: None)
# 2023-11-25 14:19:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/14> (referer: None)
# 2023-11-25 14:19:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/15> (referer: None)
# 2023-11-25 14:19:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/16> (referer: None)
# 2023-11-25 14:19:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/17> (referer: None)
# 2023-11-25 14:19:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/18> (referer: None)
# 2023-11-25 14:19:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/19> (referer: None)
# 2023-11-25 14:19:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/20> (referer: None)
# 2023-11-25 14:19:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/21> (referer: None)
# 2023-11-25 14:19:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/22> (referer: None)
# 2023-11-25 14:19:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/23> (referer: None)
# 2023-11-25 14:19:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/24> (referer: None)
# 2023-11-25 14:19:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/25> (referer: None)
# 2023-11-25 14:19:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/26> (referer: None)
# 2023-11-25 14:19:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/27> (referer: None)
# 2023-11-25 14:19:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/28> (referer: None)
# 2023-11-25 14:19:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/29> (referer: None)
# 2023-11-25 14:19:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/09/30> (referer: None)
# 2023-11-25 14:19:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/01> (referer: None)
# 2023-11-25 14:19:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/02> (referer: None)
# 2023-11-25 14:19:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/03> (referer: None)
# 2023-11-25 14:19:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/04> (referer: None)
# 2023-11-25 14:19:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/05> (referer: None)
# 2023-11-25 14:19:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/06> (referer: None)
# 2023-11-25 14:20:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/07> (referer: None)
# 2023-11-25 14:20:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/08> (referer: None)
# 2023-11-25 14:20:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/09> (referer: None)
# 2023-11-25 14:20:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/10> (referer: None)
# 2023-11-25 14:20:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/11> (referer: None)
# 2023-11-25 14:20:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/12> (referer: None)
# 2023-11-25 14:20:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/13> (referer: None)
# 2023-11-25 14:20:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/14> (referer: None)
# 2023-11-25 14:20:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/15> (referer: None)
# 2023-11-25 14:20:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/16> (referer: None)
# 2023-11-25 14:20:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/17> (referer: None)
# 2023-11-25 14:20:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/18> (referer: None)
# 2023-11-25 14:20:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/19> (referer: None)
# 2023-11-25 14:20:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/20> (referer: None)
# 2023-11-25 14:20:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/21> (referer: None)
# 2023-11-25 14:20:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/22> (referer: None)
# 2023-11-25 14:20:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/23> (referer: None)
# 2023-11-25 14:20:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/24> (referer: None)
# 2023-11-25 14:20:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/25> (referer: None)
# 2023-11-25 14:20:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/26> (referer: None)
# 2023-11-25 14:20:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/27> (referer: None)
# 2023-11-25 14:20:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/28> (referer: None)
# 2023-11-25 14:20:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/29> (referer: None)
# 2023-11-25 14:20:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/30> (referer: None)
# 2023-11-25 14:20:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/10/31> (referer: None)
# 2023-11-25 14:20:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/01> (referer: None)
# 2023-11-25 14:20:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/02> (referer: None)
# 2023-11-25 14:20:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/03> (referer: None)
# 2023-11-25 14:20:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/04> (referer: None)
# 2023-11-25 14:20:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/05> (referer: None)
# 2023-11-25 14:20:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/06> (referer: None)
# 2023-11-25 14:20:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/07> (referer: None)
# 2023-11-25 14:20:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/08> (referer: None)
# 2023-11-25 14:20:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/09> (referer: None)
# 2023-11-25 14:20:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/10> (referer: None)
# 2023-11-25 14:20:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/11> (referer: None)
# 2023-11-25 14:20:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/12> (referer: None)
# 2023-11-25 14:20:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/13> (referer: None)
# 2023-11-25 14:20:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/14> (referer: None)
# 2023-11-25 14:20:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/16> (referer: None)
# 2023-11-25 14:20:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/15> (referer: None)
# 2023-11-25 14:20:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/17> (referer: None)
# 2023-11-25 14:20:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/18> (referer: None)
# 2023-11-25 14:20:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/19> (referer: None)
# 2023-11-25 14:20:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/20> (referer: None)
# 2023-11-25 14:20:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/21> (referer: None)
# 2023-11-25 14:20:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/22> (referer: None)
# 2023-11-25 14:20:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/23> (referer: None)
# 2023-11-25 14:20:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/24> (referer: None)
# 2023-11-25 14:20:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/25> (referer: None)
# 2023-11-25 14:20:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/26> (referer: None)
# 2023-11-25 14:20:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/27> (referer: None)
# 2023-11-25 14:20:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/28> (referer: None)
# 2023-11-25 14:20:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/29> (referer: None)
# 2023-11-25 14:20:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/11/30> (referer: None)
# 2023-11-25 14:20:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/01> (referer: None)
# 2023-11-25 14:20:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/02> (referer: None)
# 2023-11-25 14:20:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/03> (referer: None)
# 2023-11-25 14:20:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/04> (referer: None)
# 2023-11-25 14:20:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/05> (referer: None)
# 2023-11-25 14:20:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/06> (referer: None)
# 2023-11-25 14:20:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/07> (referer: None)
# 2023-11-25 14:20:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/08> (referer: None)
# 2023-11-25 14:20:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/09> (referer: None)
# 2023-11-25 14:20:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/10> (referer: None)
# 2023-11-25 14:20:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/11> (referer: None)
# 2023-11-25 14:20:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/12> (referer: None)
# 2023-11-25 14:20:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/13> (referer: None)
# 2023-11-25 14:20:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/14> (referer: None)
# 2023-11-25 14:20:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/15> (referer: None)
# 2023-11-25 14:20:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/16> (referer: None)
# 2023-11-25 14:20:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/17> (referer: None)
# 2023-11-25 14:20:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/19> (referer: None)
# 2023-11-25 14:20:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/18> (referer: None)
# 2023-11-25 14:20:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/20> (referer: None)
# 2023-11-25 14:20:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/21> (referer: None)
# 2023-11-25 14:20:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/22> (referer: None)
# 2023-11-25 14:20:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/23> (referer: None)
# 2023-11-25 14:20:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/24> (referer: None)
# 2023-11-25 14:20:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/25> (referer: None)
# 2023-11-25 14:20:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/26> (referer: None)
# 2023-11-25 14:20:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/27> (referer: None)
# 2023-11-25 14:20:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/28> (referer: None)
# 2023-11-25 14:20:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/29> (referer: None)
# 2023-11-25 14:20:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/31> (referer: None)
# 2023-11-25 14:20:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2010/12/30> (referer: None)
# 2023-11-25 14:20:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/01> (referer: None)
# 2023-11-25 14:20:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/02> (referer: None)
# 2023-11-25 14:20:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/03> (referer: None)
# 2023-11-25 14:20:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/04> (referer: None)
# 2023-11-25 14:20:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/05> (referer: None)
# 2023-11-25 14:20:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/06> (referer: None)
# 2023-11-25 14:20:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/07> (referer: None)
# 2023-11-25 14:20:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/08> (referer: None)
# 2023-11-25 14:20:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/09> (referer: None)
# 2023-11-25 14:20:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/10> (referer: None)
# 2023-11-25 14:20:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/11> (referer: None)
# 2023-11-25 14:20:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/12> (referer: None)
# 2023-11-25 14:20:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/13> (referer: None)
# 2023-11-25 14:20:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/14> (referer: None)
# 2023-11-25 14:20:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/15> (referer: None)
# 2023-11-25 14:20:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/16> (referer: None)
# 2023-11-25 14:20:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/17> (referer: None)
# 2023-11-25 14:20:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/18> (referer: None)
# 2023-11-25 14:20:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/19> (referer: None)
# 2023-11-25 14:20:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/20> (referer: None)
# 2023-11-25 14:20:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/21> (referer: None)
# 2023-11-25 14:20:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/22> (referer: None)
# 2023-11-25 14:20:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/23> (referer: None)
# 2023-11-25 14:20:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/24> (referer: None)
# 2023-11-25 14:20:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/25> (referer: None)
# 2023-11-25 14:20:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/26> (referer: None)
# 2023-11-25 14:20:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/27> (referer: None)
# 2023-11-25 14:20:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/28> (referer: None)
# 2023-11-25 14:20:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/29> (referer: None)
# 2023-11-25 14:20:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/30> (referer: None)
# 2023-11-25 14:20:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/01/31> (referer: None)
# 2023-11-25 14:20:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/01> (referer: None)
# 2023-11-25 14:20:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/03> (referer: None)
# 2023-11-25 14:20:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/02> (referer: None)
# 2023-11-25 14:20:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/04> (referer: None)
# 2023-11-25 14:20:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/05> (referer: None)
# 2023-11-25 14:20:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/06> (referer: None)
# 2023-11-25 14:20:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/07> (referer: None)
# 2023-11-25 14:20:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/08> (referer: None)
# 2023-11-25 14:20:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/09> (referer: None)
# 2023-11-25 14:20:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/10> (referer: None)
# 2023-11-25 14:20:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/11> (referer: None)
# 2023-11-25 14:20:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/12> (referer: None)
# 2023-11-25 14:20:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/13> (referer: None)
# 2023-11-25 14:20:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/14> (referer: None)
# 2023-11-25 14:20:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/15> (referer: None)
# 2023-11-25 14:20:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/16> (referer: None)
# 2023-11-25 14:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/17> (referer: None)
# 2023-11-25 14:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/18> (referer: None)
# 2023-11-25 14:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/19> (referer: None)
# 2023-11-25 14:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/20> (referer: None)
# 2023-11-25 14:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/21> (referer: None)
# 2023-11-25 14:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/22> (referer: None)
# 2023-11-25 14:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/23> (referer: None)
# 2023-11-25 14:20:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/24> (referer: None)
# 2023-11-25 14:20:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/25> (referer: None)
# 2023-11-25 14:20:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/26> (referer: None)
# 2023-11-25 14:20:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/27> (referer: None)
# 2023-11-25 14:20:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/02/28> (referer: None)
# 2023-11-25 14:20:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2011/03/01> (referer: None)
# ...
# 2023-11-25 14:29:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/07/28> (referer: None)
# 2023-11-25 14:29:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/07/29> (referer: None)
# 2023-11-25 14:29:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/07/30> (referer: None)
# 2023-11-25 14:29:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/07/31> (referer: None)
# 2023-11-25 14:29:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/01> (referer: None)
# 2023-11-25 14:29:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/02> (referer: None)
# 2023-11-25 14:29:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/03> (referer: None)
# 2023-11-25 14:29:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/04> (referer: None)
# 2023-11-25 14:30:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/05> (referer: None)
# 2023-11-25 14:30:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/06> (referer: None)
# 2023-11-25 14:30:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/07> (referer: None)
# 2023-11-25 14:30:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/08> (referer: None)
# 2023-11-25 14:30:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/09> (referer: None)
# 2023-11-25 14:30:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/10> (referer: None)
# 2023-11-25 14:30:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/11> (referer: None)
# 2023-11-25 14:30:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/12> (referer: None)
# 2023-11-25 14:30:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/13> (referer: None)
# 2023-11-25 14:30:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/14> (referer: None)
# 2023-11-25 14:30:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/15> (referer: None)
# 2023-11-25 14:30:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/16> (referer: None)
# 2023-11-25 14:30:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/17> (referer: None)
# 2023-11-25 14:30:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/18> (referer: None)
# 2023-11-25 14:30:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/19> (referer: None)
# 2023-11-25 14:30:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/20> (referer: None)
# 2023-11-25 14:30:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/21> (referer: None)
# 2023-11-25 14:30:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/22> (referer: None)
# 2023-11-25 14:30:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/23> (referer: None)
# 2023-11-25 14:30:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/24> (referer: None)
# 2023-11-25 14:30:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/25> (referer: None)
# 2023-11-25 14:30:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/26> (referer: None)
# 2023-11-25 14:30:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/27> (referer: None)
# 2023-11-25 14:30:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/28> (referer: None)
# 2023-11-25 14:30:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/29> (referer: None)
# 2023-11-25 14:30:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/30> (referer: None)
# 2023-11-25 14:30:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/08/31> (referer: None)
# 2023-11-25 14:30:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/01> (referer: None)
# 2023-11-25 14:30:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/02> (referer: None)
# 2023-11-25 14:30:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/03> (referer: None)
# 2023-11-25 14:30:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/04> (referer: None)
# 2023-11-25 14:30:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/05> (referer: None)
# 2023-11-25 14:30:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/06> (referer: None)
# 2023-11-25 14:30:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/07> (referer: None)
# 2023-11-25 14:30:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/08> (referer: None)
# 2023-11-25 14:30:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/09> (referer: None)
# 2023-11-25 14:30:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/10> (referer: None)
# 2023-11-25 14:30:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/11> (referer: None)
# 2023-11-25 14:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/12> (referer: None)
# 2023-11-25 14:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/13> (referer: None)
# 2023-11-25 14:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/14> (referer: None)
# 2023-11-25 14:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/15> (referer: None)
# 2023-11-25 14:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/16> (referer: None)
# 2023-11-25 14:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/17> (referer: None)
# 2023-11-25 14:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/18> (referer: None)
# 2023-11-25 14:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/19> (referer: None)
# 2023-11-25 14:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/20> (referer: None)
# 2023-11-25 14:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/21> (referer: None)
# 2023-11-25 14:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/22> (referer: None)
# 2023-11-25 14:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/23> (referer: None)
# 2023-11-25 14:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/24> (referer: None)
# 2023-11-25 14:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/25> (referer: None)
# 2023-11-25 14:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/26> (referer: None)
# 2023-11-25 14:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/27> (referer: None)
# 2023-11-25 14:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/28> (referer: None)
# 2023-11-25 14:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/29> (referer: None)
# 2023-11-25 14:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/09/30> (referer: None)
# 2023-11-25 14:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/01> (referer: None)
# 2023-11-25 14:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/02> (referer: None)
# 2023-11-25 14:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/03> (referer: None)
# 2023-11-25 14:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/04> (referer: None)
# 2023-11-25 14:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/05> (referer: None)
# 2023-11-25 14:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/06> (referer: None)
# 2023-11-25 14:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/07> (referer: None)
# 2023-11-25 14:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/08> (referer: None)
# 2023-11-25 14:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/09> (referer: None)
# 2023-11-25 14:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/10> (referer: None)
# 2023-11-25 14:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/11> (referer: None)
# 2023-11-25 14:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/12> (referer: None)
# 2023-11-25 14:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/13> (referer: None)
# 2023-11-25 14:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/14> (referer: None)
# 2023-11-25 14:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/15> (referer: None)
# 2023-11-25 14:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/16> (referer: None)
# 2023-11-25 14:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/17> (referer: None)
# 2023-11-25 14:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/18> (referer: None)
# 2023-11-25 14:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/19> (referer: None)
# 2023-11-25 14:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/20> (referer: None)
# 2023-11-25 14:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/21> (referer: None)
# 2023-11-25 14:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/22> (referer: None)
# 2023-11-25 14:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/23> (referer: None)
# 2023-11-25 14:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/24> (referer: None)
# 2023-11-25 14:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/25> (referer: None)
# 2023-11-25 14:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/26> (referer: None)
# 2023-11-25 14:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/27> (referer: None)
# 2023-11-25 14:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/28> (referer: None)
# 2023-11-25 14:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/29> (referer: None)
# 2023-11-25 14:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/30> (referer: None)
# 2023-11-25 14:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/10/31> (referer: None)
# 2023-11-25 14:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/01> (referer: None)
# 2023-11-25 14:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/02> (referer: None)
# 2023-11-25 14:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/03> (referer: None)
# 2023-11-25 14:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/04> (referer: None)
# 2023-11-25 14:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/05> (referer: None)
# 2023-11-25 14:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/06> (referer: None)
# 2023-11-25 14:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/07> (referer: None)
# 2023-11-25 14:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/08> (referer: None)
# 2023-11-25 14:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/09> (referer: None)
# 2023-11-25 14:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/10> (referer: None)
# 2023-11-25 14:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/11> (referer: None)
# 2023-11-25 14:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/12> (referer: None)
# 2023-11-25 14:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/13> (referer: None)
# 2023-11-25 14:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/14> (referer: None)
# 2023-11-25 14:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/15> (referer: None)
# 2023-11-25 14:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/16> (referer: None)
# 2023-11-25 14:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/17> (referer: None)
# 2023-11-25 14:30:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/18> (referer: None)
# 2023-11-25 14:30:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/19> (referer: None)
# 2023-11-25 14:30:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/20> (referer: None)
# 2023-11-25 14:30:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/21> (referer: None)
# 2023-11-25 14:30:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/22> (referer: None)
# 2023-11-25 14:30:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/23> (referer: None)
# 2023-11-25 14:30:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/24> (referer: None)
# 2023-11-25 14:30:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tert.am/en/news/2023/11/25> (referer: None)
# 2023-11-25 14:30:11 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-11-25 14:30:11 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1153910,
#  'downloader/request_count': 5017,
#  'downloader/request_method_count/GET': 5017,
#  'downloader/response_bytes': 45560557,
#  'downloader/response_count': 5017,
#  'downloader/response_status_count/200': 5017,
#  'elapsed_time_seconds': 635.782416,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 25, 10, 30, 11, 967444, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 169097869,
#  'httpcompression/response_count': 5017,
#  'log_count/DEBUG': 5018,
#  'log_count/INFO': 20,
#  'log_count/WARNING': 1,
#  'response_received_count': 5017,
#  'scheduler/dequeued': 5017,
#  'scheduler/dequeued/memory': 5017,
#  'scheduler/enqueued': 5017,
#  'scheduler/enqueued/memory': 5017,
#  'start_time': datetime.datetime(2023, 11, 25, 10, 19, 36, 185028, tzinfo=datetime.timezone.utc)}
# 2023-11-25 14:30:11 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
response = requests.get("https://www.tert.am/en/news/2010/03/04/")
resp_text = " ".join(response.text.split())
soup = bs4.BeautifulSoup(resp_text)

articles = soup.findAll("li", {"class": "list__item"})

titles = [article.find('span', {"class": "list__title db fb fs15"}).find(string=True) for article in articles]
dates = [datetime.strptime(article.find("span", {"class": "list__date ver-top-box fb fs12"}).find(string=True), "%H:%M • %d.%m.%y").strftime("%Y/%m/%d %H:%M:%S") for article in articles]
categories = [", ".join([d for d in ["".join(t.findAll(string=True)) for t in article.findAll("a", {"class": "list__category fb fs12 ver-top-box tu"})] if len(d) > 0]) for article in articles]
links = [article.find("a", {"class": "list__link db"}).attrs["href"].lstrip("/en/news/") for article in articles]

links, categories, dates, titles
# Out:
# (['2010/03/04/water/114537',
#   '2010/03/04/disabled/114558',
#   '2010/03/04/aliyev/114641',
#   '2010/03/04/100steps/114488',
#   '2010/03/04/energy/114607',
#   '2010/03/04/armanmusinyan/114534',
#   '2010/03/04/petrol/114565',
#   '2010/03/04/pashinyan/114458',
#   '2010/03/04/imam/114524',
#   '2010/03/04/voting/114512',
#   '2010/03/04/evarivas/114454',
#   '2010/03/04/ancrally/114445',
#   '2010/03/04/shiff/114440',
#   '2010/03/04/olympics/114430',
#   '2010/03/04/lgbtwashington/1258869',
#   '2010/03/04/oneline/114413',
#   '2010/03/04/e-govt/1258864',
#   '2010/03/04/compilation/1258857',
#   '2010/03/04/rubenhayrapetyan/114420',
#   '2010/03/04/statement/1258848',
#   '2010/03/04/belarus/114396',
#   '2010/03/04/dalailama/1258839',
#   '2010/03/04/genocide/114380',
#   '2010/03/04/obamagul/114335',
#   '2010/03/04/protocols/1258829',
#   '2010/03/04/delegation/1258815',
#   '2010/03/04/obamahealthcare/1258813',
#   '2010/03/04/auction/114337'],
#  ['Economy',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Economy',
#   'Event',
#   'Event',
#   'Event',
#   'Culture',
#   'Event',
#   '',
#   'Event, Sports',
#   'Event',
#   'Culture',
#   '',
#   '',
#   '',
#   '',
#   'Sports',
#   'Science/tech',
#   '',
#   '',
#   '',
#   'Event',
#   '',
#   'Culture'],
#  ['2010/03/04 16:58:00',
#   '2010/03/04 16:48:00',
#   '2010/03/04 16:47:00',
#   '2010/03/04 16:29:00',
#   '2010/03/04 16:27:00',
#   '2010/03/04 16:14:00',
#   '2010/03/04 15:55:00',
#   '2010/03/04 15:48:00',
#   '2010/03/04 15:30:00',
#   '2010/03/04 15:20:00',
#   '2010/03/04 14:47:00',
#   '2010/03/04 14:31:00',
#   '2010/03/04 14:15:00',
#   '2010/03/04 14:02:00',
#   '2010/03/04 13:54:00',
#   '2010/03/04 13:47:00',
#   '2010/03/04 13:37:00',
#   '2010/03/04 13:26:00',
#   '2010/03/04 13:18:00',
#   '2010/03/04 13:11:00',
#   '2010/03/04 12:53:00',
#   '2010/03/04 12:46:00',
#   '2010/03/04 12:14:00',
#   '2010/03/04 11:52:00',
#   '2010/03/04 11:21:00',
#   '2010/03/04 11:10:00',
#   '2010/03/04 11:00:00',
#   '2010/03/04 10:56:00'],
#  ['Cost of Drinking Water Goes Up in Armenia',
#   'State Gives Three-Bedroom Apartment to Person with Disability in Armenia',
#   'No Solution to NKR Unless it is Represented in Negotiations',
#   'Armenian Authorities Subject Armenians to “Economic Terror”: ANC',
#   'Armenian Brandy Sells More in Ukraine than in Armenia: Ukrainian Ambassador',
#   'Armenian Government Gave Genocide as a Gift to Turks: Armenian National Congress',
#   'Gasoline Prices to Go Up Again in Armenia',
#   'Pashinyan’s Lawyers File 78-Page Complaint to Court of Appeal',
#   'Muslim Chaplain from Turkey Delivers Prayer for US House of Representatives',
#   '105-Year-Old Armenian Genocide Survivor, Among Others, to be Present During Vote on H.Res.252 Today',
#   'Eva Rivas: Singing and Planting Apricot Trees Abroad',
#   'ANC Rally and March Disappointed Armenian Authorities ',
#   'US Congressman Adam Schiff Commemorates 22nd Anniversary of Sumgait Pogroms',
#   'Russian Olympic Committee Says its Chief Will Be Resigning',
#   'Washington, D.C., Gays and Lesbians Finally Get to Tie the Knot',
#   'Nobel Prize Buka for One-Phrase Novel',
#   'New E-Government System to Improve Governance Transparency: Armenian PM',
#   'New Publication Discussed Violence and Legal Cases Against Journalists in Armenia ',
#   'Genocide Must be Left to Historians, Says Armenian Football Federation President',
#   'US Will Have to Prove on March 4 that it is a Pioneer of Justice: Armenian Student Union',
#   'Armenia Loses to Belarus (1-3) in Football Match',
#   'Dalai Lama Joins Other Religious Leaders on Twitter, ‘Tweets’ for a Better World',
#   'Has Obama Already Recognized the Armenian Genocide?',
#   'Abdullah Gül Urges Obama to Prevent Adopting Armenian Genocide Bill ',
#   'Turkish Parliament Law Allows Protocols Ratification to be Delayed by 10 Months',
#   'Armenian National Congress Meets with Visiting EU Delegation',
#   'Obama Urges Vote on Healthcare Reform ',
#   'Available for Sale: Michael Jackson Handwritten Lyrics, Nude Madonna Photographs'])

# %%
articles[0].find("span", {"class": "list__date ver-top-box fb fs12"}).find(string=True)
# Out:
# '16:12 • 03.03.10'

# %%
response.css('span[itemprop="articleBody"].last-child')
